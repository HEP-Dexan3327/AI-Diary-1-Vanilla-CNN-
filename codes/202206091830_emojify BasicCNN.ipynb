# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
root = "/content/drive/MyDrive/Colab/"
version = "202206091830"

# %%
# Import data source
from zipfile import ZipFile
file_name = root+"emojify.zip"

with ZipFile(file_name, 'r') as zip:
  zip.extractall()
  print("Done")
# Out:
# Done

# %%
import numpy as np
import cv2
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D
from keras.layers import BatchNormalization
from tensorflow.keras.optimizers import Adam
from keras.layers import MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# <h2>Importing Data</h2>

# %%
train_dir = 'train'
val_dir = 'test'
train_datagen = ImageDataGenerator(
        rotation_range=30,## data augmentation, able to increase the accuracy of the training.
        zoom_range=0.2,
        rescale=1./255,
        fill_mode='nearest') # Split 0.2 of the train data to validation data
val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(48,48),
        batch_size=64,
        color_mode="grayscale",
        class_mode='categorical')

validation_generator = val_datagen.flow_from_directory(
        val_dir,
        target_size=(48,48),
        batch_size=64,
        color_mode="grayscale",
        class_mode='categorical')
# Out:
# Found 25269 images belonging to 6 classes.
# Found 7067 images belonging to 6 classes.

# %% [markdown]
# <h2>Defining the Model</h2>

# %%
emotion_model = Sequential()
emotion_model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48,48,1)))
emotion_model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
emotion_model.add(MaxPooling2D(pool_size=(2, 2)))
emotion_model.add(Dropout(0.25))
emotion_model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
emotion_model.add(MaxPooling2D(pool_size=(2, 2)))
emotion_model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
emotion_model.add(MaxPooling2D(pool_size=(2, 2)))
emotion_model.add(Dropout(0.25))
emotion_model.add(Flatten())
emotion_model.add(Dense(1024, activation='relu'))
emotion_model.add(Dropout(0.25))
emotion_model.add(Dense(6, activation='softmax'))

# %% [markdown]
# <h3>F1 Score: a method for evaluating the accuracy of a model</h3>
# The block below should be runned before loading the model.

# %%
import keras.backend as K
def f1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %% [markdown]
# <h3>Training the Model</h3>
# The accuracy of my model is around 60% only. The accuracy can be slightly improved by training with 200 iterations. Use Google Colab with a GPU to speed up the training to around 10~12s per epoch.
# Note that the accuracy of the model for random guessing is 16.67% (1/6); While the accuracy for a binary classification model for random guessing is 50% (1/2), so the accuracies of binary classification model and this kind of model cannot be compared directly.

# %%
emotion_model.compile(loss='categorical_crossentropy',optimizer=Adam(learning_rate=0.001, decay=1e-6),
      metrics=['accuracy',tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),f1_score])
emotion_model_info = emotion_model.fit(
        train_generator,
        steps_per_epoch=12000 // 64,
        epochs=50,
        validation_data=validation_generator,
        validation_steps=7000 // 64)
# Out:
# Epoch 1/50
# 187/187 [==============================] - 25s 57ms/step - loss: 1.7746 - accuracy: 0.2033 - precision: 0.0800 - recall: 1.6727e-04 - auc: 0.5582 - f1_score: 2.9037e-04 - val_loss: 1.7205 - val_accuracy: 0.2715 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6486 - val_f1_score: 0.0000e+00
# Epoch 2/50
# 187/187 [==============================] - 17s 93ms/step - loss: 1.7008 - accuracy: 0.2692 - precision: 0.5548 - recall: 0.0135 - auc: 0.6398 - f1_score: 0.0258 - val_loss: 1.6622 - val_accuracy: 0.3013 - val_precision: 0.5740 - val_recall: 0.0373 - val_auc: 0.6709 - val_f1_score: 0.0692
# Epoch 3/50
# 187/187 [==============================] - 10s 54ms/step - loss: 1.6655 - accuracy: 0.2885 - precision: 0.5898 - recall: 0.0242 - auc: 0.6648 - f1_score: 0.0454 - val_loss: 1.6358 - val_accuracy: 0.2982 - val_precision: 0.7937 - val_recall: 0.0215 - val_auc: 0.6809 - val_f1_score: 0.0412
# Epoch 4/50
# 187/187 [==============================] - 10s 53ms/step - loss: 1.6232 - accuracy: 0.3174 - precision: 0.6488 - recall: 0.0385 - auc: 0.6890 - f1_score: 0.0714 - val_loss: 1.4781 - val_accuracy: 0.4138 - val_precision: 0.7668 - val_recall: 0.1145 - val_auc: 0.7606 - val_f1_score: 0.1973
# Epoch 5/50
# 187/187 [==============================] - 10s 54ms/step - loss: 1.5757 - accuracy: 0.3494 - precision: 0.6658 - recall: 0.0634 - auc: 0.7143 - f1_score: 0.1140 - val_loss: 1.4635 - val_accuracy: 0.4292 - val_precision: 0.8171 - val_recall: 0.0999 - val_auc: 0.7710 - val_f1_score: 0.1764
# Epoch 6/50
# 187/187 [==============================] - 10s 53ms/step - loss: 1.5356 - accuracy: 0.3722 - precision: 0.6431 - recall: 0.0866 - auc: 0.7344 - f1_score: 0.1505 - val_loss: 1.3930 - val_accuracy: 0.4503 - val_precision: 0.7848 - val_recall: 0.1511 - val_auc: 0.7912 - val_f1_score: 0.2510
# Epoch 7/50
# 187/187 [==============================] - 10s 52ms/step - loss: 1.4962 - accuracy: 0.3921 - precision: 0.6753 - recall: 0.1149 - auc: 0.7499 - f1_score: 0.1939 - val_loss: 1.3620 - val_accuracy: 0.4636 - val_precision: 0.7684 - val_recall: 0.1902 - val_auc: 0.8013 - val_f1_score: 0.3028
# Epoch 8/50
# 187/187 [==============================] - 10s 53ms/step - loss: 1.4784 - accuracy: 0.4029 - precision: 0.6687 - recall: 0.1211 - auc: 0.7593 - f1_score: 0.2025 - val_loss: 1.3321 - val_accuracy: 0.4749 - val_precision: 0.7876 - val_recall: 0.1892 - val_auc: 0.8128 - val_f1_score: 0.3034
# Epoch 9/50
# 187/187 [==============================] - 10s 52ms/step - loss: 1.4466 - accuracy: 0.4153 - precision: 0.6892 - recall: 0.1403 - auc: 0.7710 - f1_score: 0.2308 - val_loss: 1.2841 - val_accuracy: 0.5009 - val_precision: 0.7584 - val_recall: 0.2268 - val_auc: 0.8269 - val_f1_score: 0.3473
# Epoch 10/50
# 187/187 [==============================] - 10s 51ms/step - loss: 1.4252 - accuracy: 0.4254 - precision: 0.6782 - recall: 0.1507 - auc: 0.7800 - f1_score: 0.2444 - val_loss: 1.2677 - val_accuracy: 0.5033 - val_precision: 0.7697 - val_recall: 0.2567 - val_auc: 0.8315 - val_f1_score: 0.3826
# Epoch 11/50
# 187/187 [==============================] - 10s 52ms/step - loss: 1.3931 - accuracy: 0.4406 - precision: 0.6829 - recall: 0.1731 - auc: 0.7911 - f1_score: 0.2742 - val_loss: 1.2584 - val_accuracy: 0.5179 - val_precision: 0.7818 - val_recall: 0.2440 - val_auc: 0.8366 - val_f1_score: 0.3699
# Epoch 12/50
# 187/187 [==============================] - 10s 52ms/step - loss: 1.3887 - accuracy: 0.4455 - precision: 0.6814 - recall: 0.1704 - auc: 0.7932 - f1_score: 0.2699 - val_loss: 1.2315 - val_accuracy: 0.5281 - val_precision: 0.7962 - val_recall: 0.2549 - val_auc: 0.8448 - val_f1_score: 0.3837
# Epoch 13/50
# 187/187 [==============================] - 10s 52ms/step - loss: 1.3617 - accuracy: 0.4591 - precision: 0.6733 - recall: 0.1961 - auc: 0.8029 - f1_score: 0.3009 - val_loss: 1.2028 - val_accuracy: 0.5400 - val_precision: 0.8003 - val_recall: 0.2699 - val_auc: 0.8526 - val_f1_score: 0.4015
# Epoch 14/50
# 187/187 [==============================] - 10s 52ms/step - loss: 1.3501 - accuracy: 0.4592 - precision: 0.6838 - recall: 0.1975 - auc: 0.8057 - f1_score: 0.3043 - val_loss: 1.2082 - val_accuracy: 0.5373 - val_precision: 0.7951 - val_recall: 0.2709 - val_auc: 0.8518 - val_f1_score: 0.4026
# Epoch 15/50
# 187/187 [==============================] - 10s 52ms/step - loss: 1.3398 - accuracy: 0.4718 - precision: 0.7024 - recall: 0.2120 - auc: 0.8101 - f1_score: 0.3230 - val_loss: 1.2005 - val_accuracy: 0.5400 - val_precision: 0.7477 - val_recall: 0.3178 - val_auc: 0.8512 - val_f1_score: 0.4441
# Epoch 16/50
# 187/187 [==============================] - 10s 53ms/step - loss: 1.3377 - accuracy: 0.4710 - precision: 0.6900 - recall: 0.2170 - auc: 0.8105 - f1_score: 0.3276 - val_loss: 1.1975 - val_accuracy: 0.5403 - val_precision: 0.7885 - val_recall: 0.2821 - val_auc: 0.8544 - val_f1_score: 0.4132
# Epoch 17/50
# 187/187 [==============================] - 10s 52ms/step - loss: 1.3065 - accuracy: 0.4822 - precision: 0.6899 - recall: 0.2311 - auc: 0.8200 - f1_score: 0.3434 - val_loss: 1.1991 - val_accuracy: 0.5399 - val_precision: 0.7505 - val_recall: 0.3088 - val_auc: 0.8519 - val_f1_score: 0.4362
# Epoch 18/50
# 187/187 [==============================] - 10s 51ms/step - loss: 1.2940 - accuracy: 0.4883 - precision: 0.7037 - recall: 0.2457 - auc: 0.8245 - f1_score: 0.3618 - val_loss: 1.1635 - val_accuracy: 0.5530 - val_precision: 0.7849 - val_recall: 0.3144 - val_auc: 0.8614 - val_f1_score: 0.4475
# Epoch 19/50
# 187/187 [==============================] - 10s 52ms/step - loss: 1.2859 - accuracy: 0.4896 - precision: 0.6983 - recall: 0.2491 - auc: 0.8263 - f1_score: 0.3650 - val_loss: 1.1712 - val_accuracy: 0.5526 - val_precision: 0.7664 - val_recall: 0.3179 - val_auc: 0.8598 - val_f1_score: 0.4482
# Epoch 20/50
# 187/187 [==============================] - 11s 56ms/step - loss: 1.2763 - accuracy: 0.4975 - precision: 0.6975 - recall: 0.2567 - auc: 0.8293 - f1_score: 0.3731 - val_loss: 1.1583 - val_accuracy: 0.5603 - val_precision: 0.7911 - val_recall: 0.3116 - val_auc: 0.8644 - val_f1_score: 0.4455
# Epoch 21/50
# 187/187 [==============================] - 10s 51ms/step - loss: 1.2701 - accuracy: 0.4952 - precision: 0.7066 - recall: 0.2637 - auc: 0.8313 - f1_score: 0.3815 - val_loss: 1.1727 - val_accuracy: 0.5499 - val_precision: 0.7761 - val_recall: 0.3171 - val_auc: 0.8587 - val_f1_score: 0.4478
# Epoch 22/50
# 187/187 [==============================] - 10s 51ms/step - loss: 1.2695 - accuracy: 0.5059 - precision: 0.7066 - recall: 0.2624 - auc: 0.8314 - f1_score: 0.3802 - val_loss: 1.1621 - val_accuracy: 0.5578 - val_precision: 0.7679 - val_recall: 0.3406 - val_auc: 0.8623 - val_f1_score: 0.4697
# Epoch 23/50
# 187/187 [==============================] - 10s 51ms/step - loss: 1.2515 - accuracy: 0.5123 - precision: 0.7058 - recall: 0.2768 - auc: 0.8364 - f1_score: 0.3959 - val_loss: 1.1320 - val_accuracy: 0.5661 - val_precision: 0.7882 - val_recall: 0.3383 - val_auc: 0.8701 - val_f1_score: 0.4714
# Epoch 24/50
# 187/187 [==============================] - 10s 52ms/step - loss: 1.2539 - accuracy: 0.5052 - precision: 0.6993 - recall: 0.2752 - auc: 0.8366 - f1_score: 0.3924 - val_loss: 1.1296 - val_accuracy: 0.5626 - val_precision: 0.8061 - val_recall: 0.3201 - val_auc: 0.8710 - val_f1_score: 0.4558
# Epoch 25/50
# 187/187 [==============================] - 11s 58ms/step - loss: 1.2460 - accuracy: 0.5099 - precision: 0.7021 - recall: 0.2781 - auc: 0.8383 - f1_score: 0.3956 - val_loss: 1.1269 - val_accuracy: 0.5618 - val_precision: 0.7625 - val_recall: 0.3419 - val_auc: 0.8706 - val_f1_score: 0.4701
# Epoch 26/50
# 187/187 [==============================] - 10s 52ms/step - loss: 1.2365 - accuracy: 0.5193 - precision: 0.7124 - recall: 0.2869 - auc: 0.8429 - f1_score: 0.4067 - val_loss: 1.1185 - val_accuracy: 0.5721 - val_precision: 0.7724 - val_recall: 0.3697 - val_auc: 0.8728 - val_f1_score: 0.4983
# Epoch 27/50
# 187/187 [==============================] - 10s 53ms/step - loss: 1.2314 - accuracy: 0.5143 - precision: 0.7020 - recall: 0.2909 - auc: 0.8431 - f1_score: 0.4093 - val_loss: 1.1170 - val_accuracy: 0.5765 - val_precision: 0.7849 - val_recall: 0.3535 - val_auc: 0.8740 - val_f1_score: 0.4855
# Epoch 28/50
# 187/187 [==============================] - 10s 52ms/step - loss: 1.2238 - accuracy: 0.5241 - precision: 0.7053 - recall: 0.3044 - auc: 0.8456 - f1_score: 0.4234 - val_loss: 1.1410 - val_accuracy: 0.5625 - val_precision: 0.7739 - val_recall: 0.3479 - val_auc: 0.8679 - val_f1_score: 0.4782
# Epoch 29/50
# 187/187 [==============================] - 10s 51ms/step - loss: 1.2172 - accuracy: 0.5249 - precision: 0.7063 - recall: 0.3015 - auc: 0.8472 - f1_score: 0.4205 - val_loss: 1.1145 - val_accuracy: 0.5757 - val_precision: 0.7703 - val_recall: 0.3638 - val_auc: 0.8742 - val_f1_score: 0.4925
# Epoch 30/50
# 187/187 [==============================] - 10s 52ms/step - loss: 1.1991 - accuracy: 0.5257 - precision: 0.7146 - recall: 0.3137 - auc: 0.8516 - f1_score: 0.4338 - val_loss: 1.1105 - val_accuracy: 0.5774 - val_precision: 0.7844 - val_recall: 0.3551 - val_auc: 0.8758 - val_f1_score: 0.4872
# Epoch 31/50
# 187/187 [==============================] - 10s 52ms/step - loss: 1.2142 - accuracy: 0.5262 - precision: 0.7056 - recall: 0.3026 - auc: 0.8477 - f1_score: 0.4216 - val_loss: 1.1190 - val_accuracy: 0.5705 - val_precision: 0.7734 - val_recall: 0.3499 - val_auc: 0.8729 - val_f1_score: 0.4799
# Epoch 32/50
# 187/187 [==============================] - 10s 51ms/step - loss: 1.2057 - accuracy: 0.5273 - precision: 0.7139 - recall: 0.3094 - auc: 0.8497 - f1_score: 0.4296 - val_loss: 1.1323 - val_accuracy: 0.5635 - val_precision: 0.7499 - val_recall: 0.3761 - val_auc: 0.8693 - val_f1_score: 0.4994
# Epoch 33/50
# 187/187 [==============================] - 10s 51ms/step - loss: 1.1967 - accuracy: 0.5309 - precision: 0.7117 - recall: 0.3150 - auc: 0.8522 - f1_score: 0.4348 - val_loss: 1.1068 - val_accuracy: 0.5728 - val_precision: 0.7902 - val_recall: 0.3498 - val_auc: 0.8764 - val_f1_score: 0.4825
# Epoch 34/50
# 187/187 [==============================] - 10s 51ms/step - loss: 1.1895 - accuracy: 0.5334 - precision: 0.7129 - recall: 0.3149 - auc: 0.8548 - f1_score: 0.4346 - val_loss: 1.0924 - val_accuracy: 0.5791 - val_precision: 0.7807 - val_recall: 0.3740 - val_auc: 0.8799 - val_f1_score: 0.5043
# Epoch 35/50
# 187/187 [==============================] - 10s 52ms/step - loss: 1.1798 - accuracy: 0.5388 - precision: 0.7184 - recall: 0.3285 - auc: 0.8565 - f1_score: 0.4489 - val_loss: 1.1355 - val_accuracy: 0.5661 - val_precision: 0.7570 - val_recall: 0.3564 - val_auc: 0.8692 - val_f1_score: 0.4826
# Epoch 36/50
# 187/187 [==============================] - 12s 65ms/step - loss: 1.1761 - accuracy: 0.5419 - precision: 0.7156 - recall: 0.3340 - auc: 0.8579 - f1_score: 0.4532 - val_loss: 1.0960 - val_accuracy: 0.5854 - val_precision: 0.7622 - val_recall: 0.3773 - val_auc: 0.8786 - val_f1_score: 0.5032
# Epoch 37/50
# 187/187 [==============================] - 14s 74ms/step - loss: 1.1771 - accuracy: 0.5409 - precision: 0.7082 - recall: 0.3356 - auc: 0.8576 - f1_score: 0.4532 - val_loss: 1.0780 - val_accuracy: 0.5882 - val_precision: 0.7726 - val_recall: 0.3949 - val_auc: 0.8822 - val_f1_score: 0.5207
# Epoch 38/50
# 187/187 [==============================] - 10s 52ms/step - loss: 1.1798 - accuracy: 0.5461 - precision: 0.7143 - recall: 0.3326 - auc: 0.8571 - f1_score: 0.4518 - val_loss: 1.0699 - val_accuracy: 0.5880 - val_precision: 0.7700 - val_recall: 0.4037 - val_auc: 0.8840 - val_f1_score: 0.5280
# Epoch 39/50
# 187/187 [==============================] - 10s 52ms/step - loss: 1.1723 - accuracy: 0.5425 - precision: 0.7149 - recall: 0.3354 - auc: 0.8588 - f1_score: 0.4543 - val_loss: 1.0926 - val_accuracy: 0.5819 - val_precision: 0.7671 - val_recall: 0.3853 - val_auc: 0.8797 - val_f1_score: 0.5104
# Epoch 40/50
# 187/187 [==============================] - 10s 51ms/step - loss: 1.1700 - accuracy: 0.5430 - precision: 0.7168 - recall: 0.3375 - auc: 0.8591 - f1_score: 0.4569 - val_loss: 1.0847 - val_accuracy: 0.5915 - val_precision: 0.7768 - val_recall: 0.3792 - val_auc: 0.8816 - val_f1_score: 0.5079
# Epoch 41/50
# 187/187 [==============================] - 10s 53ms/step - loss: 1.1562 - accuracy: 0.5485 - precision: 0.7102 - recall: 0.3457 - auc: 0.8630 - f1_score: 0.4635 - val_loss: 1.0756 - val_accuracy: 0.5872 - val_precision: 0.7812 - val_recall: 0.3869 - val_auc: 0.8830 - val_f1_score: 0.5152
# Epoch 42/50
# 187/187 [==============================] - 10s 52ms/step - loss: 1.1480 - accuracy: 0.5516 - precision: 0.7194 - recall: 0.3483 - auc: 0.8652 - f1_score: 0.4679 - val_loss: 1.0833 - val_accuracy: 0.5857 - val_precision: 0.7666 - val_recall: 0.3918 - val_auc: 0.8813 - val_f1_score: 0.5168
# Epoch 43/50
# 187/187 [==============================] - 10s 51ms/step - loss: 1.1672 - accuracy: 0.5423 - precision: 0.7214 - recall: 0.3378 - auc: 0.8605 - f1_score: 0.4582 - val_loss: 1.0747 - val_accuracy: 0.5919 - val_precision: 0.7587 - val_recall: 0.4107 - val_auc: 0.8834 - val_f1_score: 0.5314
# Epoch 44/50
# 187/187 [==============================] - 12s 65ms/step - loss: 1.1468 - accuracy: 0.5547 - precision: 0.7207 - recall: 0.3557 - auc: 0.8655 - f1_score: 0.4745 - val_loss: 1.0643 - val_accuracy: 0.5909 - val_precision: 0.7938 - val_recall: 0.3890 - val_auc: 0.8858 - val_f1_score: 0.5211
# Epoch 45/50
# 187/187 [==============================] - 10s 52ms/step - loss: 1.1313 - accuracy: 0.5592 - precision: 0.7245 - recall: 0.3599 - auc: 0.8694 - f1_score: 0.4792 - val_loss: 1.0591 - val_accuracy: 0.5969 - val_precision: 0.7600 - val_recall: 0.4312 - val_auc: 0.8869 - val_f1_score: 0.5485
# Epoch 46/50
# 187/187 [==============================] - 10s 51ms/step - loss: 1.1351 - accuracy: 0.5597 - precision: 0.7140 - recall: 0.3596 - auc: 0.8686 - f1_score: 0.4768 - val_loss: 1.0815 - val_accuracy: 0.5936 - val_precision: 0.7638 - val_recall: 0.3997 - val_auc: 0.8819 - val_f1_score: 0.5230
# Epoch 47/50
# 187/187 [==============================] - 10s 52ms/step - loss: 1.1400 - accuracy: 0.5552 - precision: 0.7173 - recall: 0.3577 - auc: 0.8667 - f1_score: 0.4755 - val_loss: 1.0610 - val_accuracy: 0.5989 - val_precision: 0.7672 - val_recall: 0.4124 - val_auc: 0.8859 - val_f1_score: 0.5352
# Epoch 48/50
# 187/187 [==============================] - 10s 53ms/step - loss: 1.1384 - accuracy: 0.5581 - precision: 0.7148 - recall: 0.3559 - auc: 0.8673 - f1_score: 0.4733 - val_loss: 1.0827 - val_accuracy: 0.5879 - val_precision: 0.7804 - val_recall: 0.3942 - val_auc: 0.8820 - val_f1_score: 0.5226
# Epoch 49/50
# 187/187 [==============================] - 10s 55ms/step - loss: 1.1332 - accuracy: 0.5604 - precision: 0.7251 - recall: 0.3688 - auc: 0.8688 - f1_score: 0.4868 - val_loss: 1.0546 - val_accuracy: 0.6003 - val_precision: 0.7674 - val_recall: 0.4114 - val_auc: 0.8874 - val_f1_score: 0.5336
# Epoch 50/50
# 187/187 [==============================] - 11s 58ms/step - loss: 1.1216 - accuracy: 0.5648 - precision: 0.7189 - recall: 0.3707 - auc: 0.8718 - f1_score: 0.4873 - val_loss: 1.0664 - val_accuracy: 0.5913 - val_precision: 0.7778 - val_recall: 0.3909 - val_auc: 0.8853 - val_f1_score: 0.5187

# %% [markdown]
# <h2>Saving the Model</h2>

# %%
# !mkdir git
# %cd git 
# create the git folder
# !git init
# !git config --global user.email "samkht3327@gmail.com"
# !git config --global user.name "Ash3327"
# !git remote add origin "https://HEP-Dexan3327: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@github.com/HEP-Dexan3327/AI-Diary-1-Vanilla-CNN-"
# !git pull origin main
# Out:
# /content/git
# Initialized empty Git repository in /content/git/.git/
# remote: Enumerating objects: 61, done.
# remote: Counting objects: 100% (61/61), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 61 (delta 17), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (61/61), done.
# From https://github.com/HEP-Dexan3327/AI-Diary-1-Vanilla-CNN-
#  * branch            main       -> FETCH_HEAD
#  * [new branch]      main       -> origin/main

# %%
# %cd models
# navigate to git/models
# Out:
# /content/git/models

# %%
#Saving the visualization of model
visualfile = version+"_shape.png"
# !pip install visualkeras
import visualkeras
from tensorflow.keras.layers import BatchNormalization, ZeroPadding2D, Activation, MaxPool2D

# Visualizing our model architecture
visualkeras.layered_view(emotion_model, 
                         legend=True, 
                         to_file=visualfile,
                         type_ignore=[MaxPool2D,Activation,ZeroPadding2D,BatchNormalization,Dropout,Flatten])  # font is optional!
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting visualkeras
#   Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
# Collecting aggdraw>=1.3.11
#   Downloading aggdraw-1.3.14-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (992 kB)
#      |████████████████████████████████| 992 kB 21.4 MB/s
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from visualkeras) (7.1.2)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.7/dist-packages (from visualkeras) (1.21.6)
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.14 visualkeras-0.0.2
# <PIL.Image.Image image mode=RGBA size=312x282 at 0x7F40AA16D050>

# %%
#Saving the model
modelfile = version+'_model.h5'
emotion_model.save(modelfile)

# %%
# pushing back to git repo
# !git add $visualfile
# !git add $modelfile
# !git commit -m $version
# !git push -u origin master
# Out:
# On branch master
# nothing to commit, working tree clean
# Counting objects: 5, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 34.44 MiB | 4.47 MiB/s, done.
# Total 5 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# remote: warning: See http://git.io/iEPt8g for more information.
# remote: warning: File models/202206091830_model.h5 is 52.58 MB; this is larger than GitHub's recommended maximum file size of 50.00 MB
# remote: warning: GH001: Large files detected. You may want to try Git Large File Storage - https://git-lfs.github.com.
# remote:
# remote: Create a pull request for 'master' on GitHub by visiting:
# remote:      https://github.com/HEP-Dexan3327/AI-Diary-1-Vanilla-CNN-/pull/new/master
# remote:
# To https://github.com/HEP-Dexan3327/AI-Diary-1-Vanilla-CNN-
#  * [new branch]      master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.

# %%
# %cd ../..

# %%
def plt_acc_loss(model,num_epochs):
    acc = model.history['accuracy'] # new change for TF changes
    val_acc = model.history['val_accuracy'] # new change for TF changes

    loss = model.history['loss']
    val_loss = model.history['val_loss']

    epochs_range = range(num_epochs)

    plt.figure(figsize=(8, 8))
    plt.subplot(1, 2, 1)
    plt.ylim(0.3,1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.show()

# %%
import matplotlib.pyplot as plt
plt_acc_loss(emotion_model_info,50)

# %% [markdown]
# <h2>Loading the Model</h2>
# Loading the model named "model.h5". If you don't have enough time to train, just use the file I gave.
# The accuracy of my model is around 60% only. The accuracy can be slightly improved by training with 200 iterations.

# %%
#from keras.models import load_model
#emotion_model = load_model('model.h5',custom_objects={'f1_score':f1_score})

# %% [markdown]
# <h2>Live Identifying Emotions</h2>
# (Not very accurate, maybe due to the third-party face detection algorithm), 有時候認唔到人<br>
# 建議 open in PyCharm (唔好 open in Google Colab, 會 run 唔到 ; - ;)

# %%
"""
import cv2
import numpy as np


emotion_dict = {0: "Angry",  1: "Fearful", 2: "Happy", 3: "Neutral", 4: "Sad", 5: "Surprised"}


# start the webcam feed
#cap = cv2.VideoCapture(0)

# pass here your video path
# you may download one from here : https://www.pexels.com/video/three-girls-laughing-5273028/
cap = cv2.VideoCapture("pexels-gabby-k-5273028.mp4")

while True:
    # Find haar cascade to draw bounding box around face
    ret, frame = cap.read()
    frame = cv2.resize(frame, (1280, 720))
    if not ret:
        break
    face_detector = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # detect faces available on camera
    num_faces = face_detector.detectMultiScale(gray_frame, scaleFactor=1.3, minNeighbors=5)

    # take each face available on the camera and Preprocess it
    for (x, y, w, h) in num_faces:
        cv2.rectangle(frame, (x, y-50), (x+w, y+h+10), (0, 255, 0), 4)
        roi_gray_frame = gray_frame[y:y + h, x:x + w]
        cropped_img = np.expand_dims(np.expand_dims(cv2.resize(roi_gray_frame, (48, 48)), -1), 0)

        # predict the emotions
        emotion_prediction = emotion_model.predict(cropped_img)
        maxindex = int(np.argmax(emotion_prediction))
        cv2.putText(frame, emotion_dict[maxindex], (x+5, y-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2, cv2.LINE_AA)

    cv2.imshow('Emotion Detection',frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
"""
# Out:
# '\nimport cv2\nimport numpy as np\n\n\nemotion_dict = {0: "Angry",  1: "Fearful", 2: "Happy", 3: "Neutral", 4: "Sad", 5: "Surprised"}\n\n\n# start the webcam feed\n#cap = cv2.VideoCapture(0)\n\n# pass here your video path\n# you may download one from here : https://www.pexels.com/video/three-girls-laughing-5273028/\ncap = cv2.VideoCapture("pexels-gabby-k-5273028.mp4")\n\nwhile True:\n    # Find haar cascade to draw bounding box around face\n    ret, frame = cap.read()\n    frame = cv2.resize(frame, (1280, 720))\n    if not ret:\n        break\n    face_detector = cv2.CascadeClassifier(cv2.data.haarcascades + \'haarcascade_frontalface_default.xml\')\n    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)\n\n    # detect faces available on camera\n    num_faces = face_detector.detectMultiScale(gray_frame, scaleFactor=1.3, minNeighbors=5)\n\n    # take each face available on the camera and Preprocess it\n    for (x, y, w, h) in num_faces:\n        cv2.rectangle(frame, (x, y-50), (x+w, y+h+10), (0, 255, 0), 4)\n        roi_gray_frame = gray_frame[y:y + h, x:x + w]\n        cropped_img = np.expand_dims(np.expand_dims(cv2.resize(roi_gray_frame, (48, 48)), -1), 0)\n\n        # predict the emotions\n        emotion_prediction = emotion_model.predict(cropped_img)\n        maxindex = int(np.argmax(emotion_prediction))\n        cv2.putText(frame, emotion_dict[maxindex], (x+5, y-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2, cv2.LINE_AA)\n\n    cv2.imshow(\'Emotion Detection\',frame)\n    if cv2.waitKey(1) & 0xFF == ord(\'q\'):\n        break\n\ncap.release()\ncv2.destroyAllWindows()\n'

# %% [markdown]
# <h2>Confusion Matrix</h2>

# %%
import tensorflow as tf
import numpy as np
from keras.models import model_from_json
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report,ConfusionMatrixDisplay


emotion_dict = {0: "Angry", 1: "Fear", 2: "Happy", 3: "Neutral", 4: "Sad", 5: "Surprised"}

# do prediction on test data


predictions = np.array([])
labels =  np.array([])

I = 0
for x, y in validation_generator:
  predictions = np.concatenate([predictions, np.argmax(emotion_model.predict(x),axis=-1)])
  labels = np.concatenate([labels, np.argmax(y,axis=-1)])
  I += 1
  if I > 100:
    break
ConfusionMatrixDisplay(
    confusion_matrix=tf.math.confusion_matrix(
        labels=labels, predictions=predictions)
    .numpy(), display_labels=emotion_dict).plot(cmap=plt.cm.Blues)
plt.show()
print(tf.math.confusion_matrix(labels=labels, predictions=predictions).numpy())
# Out:
# [[ 372  119   51  117  201   25]
#  [  85  344   29  110  267   96]
#  [  49   54 1321   75   87   28]
#  [  45   88   87  623  267   26]
#  [  85  137   53  190  638   21]
#  [  27  119   35   41   30  522]]

# %%
# Classification report
print("-----------------------------------------------------------------")
print(classification_report(labels, predictions))
# Out:
# -----------------------------------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.42      0.48       885
#          1.0       0.40      0.37      0.38       931
#          2.0       0.84      0.82      0.83      1614
#          3.0       0.54      0.55      0.54      1136
#          4.0       0.43      0.57      0.49      1124
#          5.0       0.73      0.67      0.70       774
#
#     accuracy                           0.59      6464
#    macro avg       0.58      0.57      0.57      6464
# weighted avg       0.60      0.59      0.59      6464

# %% [markdown]
# <h2>Photo Emotion Analysis</h2>

# %%
def emotion_analysis(emotions):
    objects = ('Angry', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise')
    y_pos = np.arange(len(objects))
    
    plt.bar(y_pos, emotions, align='center', alpha=0.5)
    plt.xticks(y_pos, objects)
    plt.ylabel('percentage')
    plt.title('emotion')
    
    plt.show()

# %% [markdown]
# <h3>Capturing Image using Laptop Camera in Google Colab</h3>

# %%
"""
#CODE for Capturing an image on Colab from here: https://colab.research.google.com/notebook#fileId=1OnUy6eFE7XhdfGfAHDCqQxpwueTOj_NO

from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)
  data = eval_js('takePhoto({})'.format(quality))
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return filename
"""
# Out:
# "\n#CODE for Capturing an image on Colab from here: https://colab.research.google.com/notebook#fileId=1OnUy6eFE7XhdfGfAHDCqQxpwueTOj_NO\n\nfrom IPython.display import display, Javascript\nfrom google.colab.output import eval_js\nfrom base64 import b64decode\n\ndef take_photo(filename='photo.jpg', quality=0.8):\n  js = Javascript('''\n    async function takePhoto(quality) {\n      const div = document.createElement('div');\n      const capture = document.createElement('button');\n      capture.textContent = 'Capture';\n      div.appendChild(capture);\n\n      const video = document.createElement('video');\n      video.style.display = 'block';\n      const stream = await navigator.mediaDevices.getUserMedia({video: true});\n\n      document.body.appendChild(div);\n      div.appendChild(video);\n      video.srcObject = stream;\n      await video.play();\n\n      // Resize the output to fit the video element.\n      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);\n\n      // Wait for Capture to be clicked.\n      await new Promise((resolve) => capture.onclick = resolve);\n\n      const canvas = document.createElement('canvas');\n      canvas.width = video.videoWidth;\n      canvas.height = video.videoHeight;\n      canvas.getContext('2d').drawImage(video, 0, 0);\n      stream.getVideoTracks()[0].stop();\n      div.remove();\n      return canvas.toDataURL('image/jpeg', quality);\n    }\n    ''')\n  display(js)\n  data = eval_js('takePhoto({})'.format(quality))\n  binary = b64decode(data.split(',')[1])\n  with open(filename, 'wb') as f:\n    f.write(binary)\n  return filename\n"

# %%
#take_photo()

# %% [markdown]
# <h3>Defining the Face-cropping Algorithm (third-party)</h3>

# %%
import cv2
            
def facecrop(image):  
    facedata = cv2.data.haarcascades + 'haarcascade_frontalface_alt.xml'
    cascade = cv2.CascadeClassifier(facedata)

    img = cv2.imread(image)

    try:
    
        minisize = (img.shape[1],img.shape[0])
        miniframe = cv2.resize(img, minisize)

        faces = cascade.detectMultiScale(miniframe)

        for f in faces:
            x, y, w, h = [ v for v in f ]
            cv2.rectangle(img, (x,y), (x+w,y+h), (0,255,0), 2)

            sub_face = img[y:y+h, x:x+w]

            
            cv2.imwrite('capture.jpg', sub_face)
            print ("Writing: " + image)

    except Exception as e:
        print (e)

   


if __name__ == '__main__':
    facecrop(root+"fear.jpg") ###############the file path here is your image

#Testing a file.

from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator

import numpy as np
import matplotlib.pyplot as plt


file = 'capture.jpg'
true_image = image.load_img(file)
img = image.load_img(file, color_mode="grayscale", target_size=(48, 48))

x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)

x /= 255

custom = emotion_model.predict(x)
emotion_analysis(custom[0])

x = np.array(x, 'float32')
x = x.reshape([48, 48])


plt.imshow(true_image)
plt.show()
# Out:
# Writing: /content/drive/MyDrive/Colab/fear.jpg
