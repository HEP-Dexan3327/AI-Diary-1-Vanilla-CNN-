# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
root = "/content/drive/MyDrive/Colab/"
version = "202206111539"
name = "ResNet batch normalized 26-layers _ lr=0.001 6 x ResBlock4 _ 75 epochs"
dataset = "emojify"

# %%
# Import data source
from zipfile import ZipFile
file_name = root+"facialexpression/emojify.zip"

with ZipFile(file_name, 'r') as zip:
  zip.extractall()
  print("Done")
# Out:
# Done

# %%
import numpy as np
import cv2
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, BatchNormalization, MaxPooling2D, Add
from tensorflow.keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# <h2>Importing Data</h2>

# %%
from tensorflow import keras
# Model / data parameters
num_classes = 6
input_shape = (48, 48, 1)

train_dir = 'train'
val_dir = 'test'
train_datagen = ImageDataGenerator(
        rotation_range=30,## data augmentation, able to increase the accuracy of the training.
        zoom_range=0.2,
        rescale=1./255,
        fill_mode='nearest') # Split 0.2 of the train data to validation data
val_datagen = ImageDataGenerator(rescale=1./255)

train_data = train_datagen.flow_from_directory(
        train_dir,
        target_size=(48,48),
        batch_size=64,
        color_mode="grayscale",
        class_mode='categorical')

val_data = val_datagen.flow_from_directory(
        val_dir,
        target_size=(48,48),
        batch_size=64,
        color_mode="grayscale",
        class_mode='categorical')
# Out:
# Found 25269 images belonging to 6 classes.
# Found 7067 images belonging to 6 classes.

# %% [markdown]
# <h2>Defining the Model</h2>

# %%
from keras import initializers
def conv(filter: int, kernel_size: int, zero: bool, stride: int) -> Conv2D:
  if zero:
    return Conv2D(filters=filter, kernel_size=kernel_size, activation="relu", padding="same", strides=stride, kernel_initializer=initializers.Zeros())
  else:
    return Conv2D(filters=filter, kernel_size=kernel_size, activation="relu", padding="same", strides=stride)
class Residual(keras.layers.Layer):
  def __init__(self, downsample: bool, filters: int, zero: bool, kernel_size: int = 3):
    super(Residual, self).__init__()
    self.conv1 = conv(filters, kernel_size, zero, (1 if not downsample else 2))
    self.bn1 = BatchNormalization()
    self.conv2 = conv(filters, kernel_size, zero, 1)
    self.bn2 = BatchNormalization()
    self.conv3 = conv(filters, kernel_size, zero, 1)
    self.bn3 = BatchNormalization()
    self.conv4 = conv(filters, kernel_size, zero, 1)
    self.convx = Conv2D(kernel_size=1, strides=2, filters=filters, padding="same")
    self.downsample = downsample
    self.add = Add()
    self.bnO = BatchNormalization()

  def call(self, inputs):
    x = inputs
    y = self.bn1(self.conv1(x))
    y = self.bn2(self.conv2(y))
    y = self.bn3(self.conv3(y))
    y = self.conv4(y)
    if self.downsample:
      x = self.convx(x)
    out = self.add([x,y])
    out = self.bnO(out)
    return out

  def get_config(self):
    return {
        "downsample": self.downsample,
        "conv1": self.conv1,
        "bn1": self.bn1,
        "conv2": self.conv2,
        "bn2": self.bn2,
        "conv3": self.conv3,
        "bn3": self.bn3,
        "conv4": self.conv4,
        "convx": self.convx,
        "add": self.add,
        "bnO": self.bnO
    }

# %%
B1 = BatchNormalization()
C = Conv2D(filters=32, kernel_size=3, activation="relu", padding="same")
B2 = BatchNormalization()
R11 = Residual(False, 32, False, 3)
R12 = Residual(False, 32, False, 3)
R21 = Residual(True, 64, False, 3)
R22 = Residual(False, 64, False, 3)
R31 = Residual(True, 128, False, 3)
R32 = Residual(False, 128, False, 3)
F = Flatten()
D = Dense(num_classes, activation="softmax")

model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        B1,C,B2,
        R11,R12,
        R21,R22,
        R31,R32,
        F,
        D,
    ]
)

# %% [markdown]
# <h3>F1 Score: a method for evaluating the accuracy of a model</h3>
# The block below should be runned before loading the model.

# %%
import keras.backend as K
def f1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %% [markdown]
# <h3>Training the Model</h3>
# The accuracy of my model is around 60% only. The accuracy can be slightly improved by training with 200 iterations. Use Google Colab with a GPU to speed up the training to around 10~12s per epoch.
# Note that the accuracy of the model for random guessing is 16.67% (1/6); While the accuracy for a binary classification model for random guessing is 50% (1/2), so the accuracies of binary classification model and this kind of model cannot be compared directly.

# %%
model.compile(loss='categorical_crossentropy',optimizer=Adam(learning_rate=0.001, decay=1e-6),
      metrics=['accuracy',tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),f1_score])
batch_size = 128
model_info = model.fit(
        train_data, validation_data=val_data, batch_size=batch_size, epochs=75)
# Out:
# Epoch 1/75
# 395/395 [==============================] - 50s 87ms/step - loss: 3.1614 - accuracy: 0.2189 - precision: 0.2280 - recall: 0.0884 - auc: 0.5605 - f1_score: 0.1196 - val_loss: 304.4447 - val_accuracy: 0.1600 - val_precision: 0.1611 - val_recall: 0.1224 - val_auc: 0.4897 - val_f1_score: 0.1395
# Epoch 2/75
# 395/395 [==============================] - 34s 86ms/step - loss: 2.8594 - accuracy: 0.2044 - precision: 0.2188 - recall: 0.0501 - auc: 0.5536 - f1_score: 0.0797 - val_loss: 2.4228 - val_accuracy: 0.2074 - val_precision: 0.2147 - val_recall: 0.0649 - val_auc: 0.5571 - val_f1_score: 0.0987
# Epoch 3/75
# 395/395 [==============================] - 34s 86ms/step - loss: 2.2260 - accuracy: 0.2162 - precision: 0.2364 - recall: 0.0304 - auc: 0.5674 - f1_score: 0.0532 - val_loss: 2.1456 - val_accuracy: 0.2343 - val_precision: 0.2520 - val_recall: 0.0317 - val_auc: 0.5940 - val_f1_score: 0.0553
# Epoch 4/75
# 395/395 [==============================] - 34s 85ms/step - loss: 1.8767 - accuracy: 0.2479 - precision: 0.3176 - recall: 0.0315 - auc: 0.6054 - f1_score: 0.0567 - val_loss: 1.8755 - val_accuracy: 0.2779 - val_precision: 0.2856 - val_recall: 0.0477 - val_auc: 0.6301 - val_f1_score: 0.0811
# Epoch 5/75
# 395/395 [==============================] - 35s 88ms/step - loss: 1.7223 - accuracy: 0.2830 - precision: 0.4351 - recall: 0.0349 - auc: 0.6486 - f1_score: 0.0637 - val_loss: 1.6523 - val_accuracy: 0.3431 - val_precision: 0.5773 - val_recall: 0.0296 - val_auc: 0.6947 - val_f1_score: 0.0557
# Epoch 6/75
# 395/395 [==============================] - 34s 87ms/step - loss: 1.6344 - accuracy: 0.3247 - precision: 0.5729 - recall: 0.0498 - auc: 0.6879 - f1_score: 0.0903 - val_loss: 1.5906 - val_accuracy: 0.3665 - val_precision: 0.6954 - val_recall: 0.0869 - val_auc: 0.7096 - val_f1_score: 0.1525
# Epoch 7/75
# 395/395 [==============================] - 34s 86ms/step - loss: 1.5872 - accuracy: 0.3523 - precision: 0.6184 - recall: 0.0695 - auc: 0.7104 - f1_score: 0.1236 - val_loss: 1.5430 - val_accuracy: 0.3836 - val_precision: 0.6952 - val_recall: 0.1010 - val_auc: 0.7360 - val_f1_score: 0.1747
# Epoch 8/75
# 395/395 [==============================] - 34s 85ms/step - loss: 1.5406 - accuracy: 0.3758 - precision: 0.6438 - recall: 0.0914 - auc: 0.7326 - f1_score: 0.1584 - val_loss: 1.5429 - val_accuracy: 0.4138 - val_precision: 0.7116 - val_recall: 0.1375 - val_auc: 0.7630 - val_f1_score: 0.2289
# Epoch 9/75
# 395/395 [==============================] - 34s 86ms/step - loss: 1.5064 - accuracy: 0.3899 - precision: 0.6561 - recall: 0.1129 - auc: 0.7472 - f1_score: 0.1906 - val_loss: 1.4377 - val_accuracy: 0.4282 - val_precision: 0.7023 - val_recall: 0.1823 - val_auc: 0.7734 - val_f1_score: 0.2881
# Epoch 10/75
# 395/395 [==============================] - 34s 86ms/step - loss: 1.4611 - accuracy: 0.4118 - precision: 0.6789 - recall: 0.1436 - auc: 0.7655 - f1_score: 0.2351 - val_loss: 1.5322 - val_accuracy: 0.3997 - val_precision: 0.5726 - val_recall: 0.2026 - val_auc: 0.7505 - val_f1_score: 0.2978
# Epoch 11/75
# 395/395 [==============================] - 34s 87ms/step - loss: 1.4171 - accuracy: 0.4366 - precision: 0.6839 - recall: 0.1713 - auc: 0.7828 - f1_score: 0.2720 - val_loss: 1.3168 - val_accuracy: 0.4813 - val_precision: 0.7662 - val_recall: 0.2198 - val_auc: 0.8163 - val_f1_score: 0.3401
# Epoch 12/75
# 395/395 [==============================] - 34s 86ms/step - loss: 1.3696 - accuracy: 0.4560 - precision: 0.6904 - recall: 0.2009 - auc: 0.7994 - f1_score: 0.3095 - val_loss: 1.2897 - val_accuracy: 0.4963 - val_precision: 0.7309 - val_recall: 0.2771 - val_auc: 0.8265 - val_f1_score: 0.3997
# Epoch 13/75
# 395/395 [==============================] - 34s 86ms/step - loss: 1.3193 - accuracy: 0.4788 - precision: 0.6896 - recall: 0.2342 - auc: 0.8160 - f1_score: 0.3477 - val_loss: 1.2479 - val_accuracy: 0.5145 - val_precision: 0.6801 - val_recall: 0.3426 - val_auc: 0.8402 - val_f1_score: 0.4541
# Epoch 14/75
# 395/395 [==============================] - 34s 85ms/step - loss: 1.2801 - accuracy: 0.4921 - precision: 0.6990 - recall: 0.2639 - auc: 0.8281 - f1_score: 0.3812 - val_loss: 1.2113 - val_accuracy: 0.5258 - val_precision: 0.7342 - val_recall: 0.3182 - val_auc: 0.8475 - val_f1_score: 0.4424
# Epoch 15/75
# 395/395 [==============================] - 34s 86ms/step - loss: 1.2362 - accuracy: 0.5125 - precision: 0.7001 - recall: 0.2980 - auc: 0.8412 - f1_score: 0.4165 - val_loss: 1.1908 - val_accuracy: 0.5417 - val_precision: 0.7039 - val_recall: 0.3661 - val_auc: 0.8546 - val_f1_score: 0.4807
# Epoch 16/75
# 395/395 [==============================] - 34s 86ms/step - loss: 1.2058 - accuracy: 0.5262 - precision: 0.7056 - recall: 0.3181 - auc: 0.8497 - f1_score: 0.4368 - val_loss: 1.2174 - val_accuracy: 0.5289 - val_precision: 0.7043 - val_recall: 0.3444 - val_auc: 0.8468 - val_f1_score: 0.4611
# Epoch 17/75
# 395/395 [==============================] - 34s 86ms/step - loss: 1.1713 - accuracy: 0.5413 - precision: 0.7083 - recall: 0.3420 - auc: 0.8588 - f1_score: 0.4596 - val_loss: 1.2438 - val_accuracy: 0.5247 - val_precision: 0.6624 - val_recall: 0.3771 - val_auc: 0.8450 - val_f1_score: 0.4794
# Epoch 18/75
# 395/395 [==============================] - 34s 86ms/step - loss: 1.1451 - accuracy: 0.5540 - precision: 0.7130 - recall: 0.3640 - auc: 0.8654 - f1_score: 0.4804 - val_loss: 1.2569 - val_accuracy: 0.5146 - val_precision: 0.6333 - val_recall: 0.4040 - val_auc: 0.8447 - val_f1_score: 0.4925
# Epoch 19/75
# 395/395 [==============================] - 34s 86ms/step - loss: 1.1164 - accuracy: 0.5702 - precision: 0.7225 - recall: 0.3879 - auc: 0.8724 - f1_score: 0.5031 - val_loss: 1.1829 - val_accuracy: 0.5463 - val_precision: 0.6874 - val_recall: 0.3825 - val_auc: 0.8577 - val_f1_score: 0.4901
# Epoch 20/75
# 395/395 [==============================] - 34s 86ms/step - loss: 1.0893 - accuracy: 0.5746 - precision: 0.7227 - recall: 0.4027 - auc: 0.8791 - f1_score: 0.5159 - val_loss: 1.0877 - val_accuracy: 0.5896 - val_precision: 0.6905 - val_recall: 0.4762 - val_auc: 0.8838 - val_f1_score: 0.5615
# Epoch 21/75
# 395/395 [==============================] - 34s 86ms/step - loss: 1.0678 - accuracy: 0.5858 - precision: 0.7249 - recall: 0.4195 - auc: 0.8841 - f1_score: 0.5302 - val_loss: 1.1622 - val_accuracy: 0.5663 - val_precision: 0.6726 - val_recall: 0.4515 - val_auc: 0.8679 - val_f1_score: 0.5394
# Epoch 22/75
# 395/395 [==============================] - 34s 86ms/step - loss: 1.0447 - accuracy: 0.5967 - precision: 0.7315 - recall: 0.4402 - auc: 0.8893 - f1_score: 0.5484 - val_loss: 1.0423 - val_accuracy: 0.6046 - val_precision: 0.7187 - val_recall: 0.4773 - val_auc: 0.8904 - val_f1_score: 0.5725
# Epoch 23/75
# 395/395 [==============================] - 34s 86ms/step - loss: 1.0217 - accuracy: 0.6086 - precision: 0.7351 - recall: 0.4578 - auc: 0.8941 - f1_score: 0.5629 - val_loss: 1.0243 - val_accuracy: 0.6114 - val_precision: 0.7299 - val_recall: 0.4753 - val_auc: 0.8944 - val_f1_score: 0.5745
# Epoch 24/75
# 395/395 [==============================] - 34s 85ms/step - loss: 1.0032 - accuracy: 0.6123 - precision: 0.7372 - recall: 0.4670 - auc: 0.8981 - f1_score: 0.5707 - val_loss: 1.1224 - val_accuracy: 0.5813 - val_precision: 0.6815 - val_recall: 0.4612 - val_auc: 0.8768 - val_f1_score: 0.5494
# Epoch 25/75
# 395/395 [==============================] - 34s 86ms/step - loss: 0.9885 - accuracy: 0.6225 - precision: 0.7423 - recall: 0.4768 - auc: 0.9011 - f1_score: 0.5796 - val_loss: 1.0261 - val_accuracy: 0.6192 - val_precision: 0.7080 - val_recall: 0.5209 - val_auc: 0.8976 - val_f1_score: 0.5995
# Epoch 26/75
# 395/395 [==============================] - 34s 86ms/step - loss: 0.9657 - accuracy: 0.6304 - precision: 0.7424 - recall: 0.4958 - auc: 0.9057 - f1_score: 0.5935 - val_loss: 1.0374 - val_accuracy: 0.6113 - val_precision: 0.7000 - val_recall: 0.5144 - val_auc: 0.8944 - val_f1_score: 0.5918
# Epoch 27/75
# 395/395 [==============================] - 34s 85ms/step - loss: 0.9465 - accuracy: 0.6392 - precision: 0.7500 - recall: 0.5070 - auc: 0.9095 - f1_score: 0.6038 - val_loss: 1.0523 - val_accuracy: 0.6138 - val_precision: 0.6991 - val_recall: 0.5243 - val_auc: 0.8945 - val_f1_score: 0.5985
# Epoch 28/75
# 395/395 [==============================] - 34s 85ms/step - loss: 0.9283 - accuracy: 0.6464 - precision: 0.7501 - recall: 0.5188 - auc: 0.9131 - f1_score: 0.6124 - val_loss: 1.6696 - val_accuracy: 0.5779 - val_precision: 0.6699 - val_recall: 0.4859 - val_auc: 0.8677 - val_f1_score: 0.5620
# Epoch 29/75
# 395/395 [==============================] - 34s 86ms/step - loss: 0.9183 - accuracy: 0.6475 - precision: 0.7496 - recall: 0.5245 - auc: 0.9149 - f1_score: 0.6161 - val_loss: 1.0187 - val_accuracy: 0.6237 - val_precision: 0.7117 - val_recall: 0.5326 - val_auc: 0.8996 - val_f1_score: 0.6091
# Epoch 30/75
# 395/395 [==============================] - 34s 86ms/step - loss: 0.8940 - accuracy: 0.6580 - precision: 0.7560 - recall: 0.5398 - auc: 0.9193 - f1_score: 0.6290 - val_loss: 1.0672 - val_accuracy: 0.6113 - val_precision: 0.6908 - val_recall: 0.5330 - val_auc: 0.8939 - val_f1_score: 0.6013
# Epoch 31/75
# 395/395 [==============================] - 34s 86ms/step - loss: 0.8806 - accuracy: 0.6646 - precision: 0.7637 - recall: 0.5510 - auc: 0.9218 - f1_score: 0.6393 - val_loss: 1.0480 - val_accuracy: 0.6127 - val_precision: 0.6931 - val_recall: 0.5180 - val_auc: 0.8939 - val_f1_score: 0.5928
# Epoch 32/75
# 395/395 [==============================] - 34s 86ms/step - loss: 0.8691 - accuracy: 0.6712 - precision: 0.7649 - recall: 0.5619 - auc: 0.9238 - f1_score: 0.6470 - val_loss: 1.0071 - val_accuracy: 0.6362 - val_precision: 0.7094 - val_recall: 0.5588 - val_auc: 0.9051 - val_f1_score: 0.6253
# Epoch 33/75
# 395/395 [==============================] - 34s 86ms/step - loss: 0.8502 - accuracy: 0.6789 - precision: 0.7686 - recall: 0.5726 - auc: 0.9271 - f1_score: 0.6555 - val_loss: 1.0682 - val_accuracy: 0.6226 - val_precision: 0.6882 - val_recall: 0.5572 - val_auc: 0.8970 - val_f1_score: 0.6146
# Epoch 34/75
# 395/395 [==============================] - 35s 88ms/step - loss: 0.8310 - accuracy: 0.6823 - precision: 0.7693 - recall: 0.5855 - auc: 0.9304 - f1_score: 0.6642 - val_loss: 1.0340 - val_accuracy: 0.6277 - val_precision: 0.7015 - val_recall: 0.5530 - val_auc: 0.9002 - val_f1_score: 0.6170
# Epoch 35/75
# 395/395 [==============================] - 34s 86ms/step - loss: 0.8148 - accuracy: 0.6907 - precision: 0.7748 - recall: 0.5948 - auc: 0.9329 - f1_score: 0.6722 - val_loss: 1.0919 - val_accuracy: 0.6144 - val_precision: 0.6752 - val_recall: 0.5502 - val_auc: 0.8933 - val_f1_score: 0.6059
# Epoch 36/75
# 395/395 [==============================] - 34s 86ms/step - loss: 0.8043 - accuracy: 0.6952 - precision: 0.7747 - recall: 0.6038 - auc: 0.9348 - f1_score: 0.6778 - val_loss: 1.0629 - val_accuracy: 0.6220 - val_precision: 0.6960 - val_recall: 0.5499 - val_auc: 0.8960 - val_f1_score: 0.6142
# Epoch 37/75
# 395/395 [==============================] - 34s 86ms/step - loss: 0.7862 - accuracy: 0.7046 - precision: 0.7824 - recall: 0.6130 - auc: 0.9376 - f1_score: 0.6866 - val_loss: 1.0920 - val_accuracy: 0.6164 - val_precision: 0.6788 - val_recall: 0.5687 - val_auc: 0.8965 - val_f1_score: 0.6192
# Epoch 38/75
# 395/395 [==============================] - 34s 86ms/step - loss: 0.7671 - accuracy: 0.7090 - precision: 0.7849 - recall: 0.6238 - auc: 0.9405 - f1_score: 0.6945 - val_loss: 1.0443 - val_accuracy: 0.6348 - val_precision: 0.6952 - val_recall: 0.5704 - val_auc: 0.9016 - val_f1_score: 0.6269
# Epoch 39/75
# 395/395 [==============================] - 34s 85ms/step - loss: 0.7590 - accuracy: 0.7141 - precision: 0.7852 - recall: 0.6322 - auc: 0.9418 - f1_score: 0.6999 - val_loss: 1.0964 - val_accuracy: 0.6256 - val_precision: 0.6836 - val_recall: 0.5704 - val_auc: 0.8964 - val_f1_score: 0.6206
# Epoch 40/75
# 395/395 [==============================] - 34s 87ms/step - loss: 0.7464 - accuracy: 0.7225 - precision: 0.7915 - recall: 0.6420 - auc: 0.9437 - f1_score: 0.7084 - val_loss: 1.1067 - val_accuracy: 0.6307 - val_precision: 0.6841 - val_recall: 0.5769 - val_auc: 0.8959 - val_f1_score: 0.6253
# Epoch 41/75
# 395/395 [==============================] - 34s 86ms/step - loss: 0.7197 - accuracy: 0.7285 - precision: 0.7986 - recall: 0.6539 - auc: 0.9475 - f1_score: 0.7183 - val_loss: 1.0830 - val_accuracy: 0.6321 - val_precision: 0.6872 - val_recall: 0.5847 - val_auc: 0.9017 - val_f1_score: 0.6311
# Epoch 42/75
# 395/395 [==============================] - 34s 86ms/step - loss: 0.7150 - accuracy: 0.7311 - precision: 0.7978 - recall: 0.6580 - auc: 0.9481 - f1_score: 0.7206 - val_loss: 1.0894 - val_accuracy: 0.6321 - val_precision: 0.6849 - val_recall: 0.5824 - val_auc: 0.9004 - val_f1_score: 0.6290
# Epoch 43/75
# 395/395 [==============================] - 34s 86ms/step - loss: 0.7053 - accuracy: 0.7369 - precision: 0.7989 - recall: 0.6634 - auc: 0.9495 - f1_score: 0.7243 - val_loss: 1.1326 - val_accuracy: 0.6240 - val_precision: 0.6791 - val_recall: 0.5714 - val_auc: 0.8928 - val_f1_score: 0.6203
# Epoch 44/75
# 395/395 [==============================] - 34s 86ms/step - loss: 0.6847 - accuracy: 0.7457 - precision: 0.8075 - recall: 0.6781 - auc: 0.9523 - f1_score: 0.7365 - val_loss: 1.1693 - val_accuracy: 0.6187 - val_precision: 0.6697 - val_recall: 0.5763 - val_auc: 0.8913 - val_f1_score: 0.6189
# Epoch 45/75
# 395/395 [==============================] - 34s 85ms/step - loss: 0.6723 - accuracy: 0.7499 - precision: 0.8102 - recall: 0.6832 - auc: 0.9538 - f1_score: 0.7408 - val_loss: 1.1423 - val_accuracy: 0.6307 - val_precision: 0.6777 - val_recall: 0.5823 - val_auc: 0.8944 - val_f1_score: 0.6254
# Epoch 46/75
# 395/395 [==============================] - 34s 86ms/step - loss: 0.6557 - accuracy: 0.7547 - precision: 0.8139 - recall: 0.6960 - auc: 0.9560 - f1_score: 0.7499 - val_loss: 1.1089 - val_accuracy: 0.6434 - val_precision: 0.6847 - val_recall: 0.5995 - val_auc: 0.9007 - val_f1_score: 0.6384
# Epoch 47/75
# 395/395 [==============================] - 34s 86ms/step - loss: 0.6469 - accuracy: 0.7613 - precision: 0.8178 - recall: 0.6993 - auc: 0.9572 - f1_score: 0.7534 - val_loss: 1.0761 - val_accuracy: 0.6516 - val_precision: 0.7038 - val_recall: 0.6090 - val_auc: 0.9051 - val_f1_score: 0.6537
# Epoch 48/75
# 395/395 [==============================] - 34s 86ms/step - loss: 0.6327 - accuracy: 0.7641 - precision: 0.8177 - recall: 0.7041 - auc: 0.9590 - f1_score: 0.7563 - val_loss: 1.1504 - val_accuracy: 0.6382 - val_precision: 0.6740 - val_recall: 0.6032 - val_auc: 0.8990 - val_f1_score: 0.6363
# Epoch 49/75
# 395/395 [==============================] - 34s 86ms/step - loss: 0.6311 - accuracy: 0.7652 - precision: 0.8192 - recall: 0.7070 - auc: 0.9592 - f1_score: 0.7585 - val_loss: 1.1589 - val_accuracy: 0.6325 - val_precision: 0.6740 - val_recall: 0.5945 - val_auc: 0.8964 - val_f1_score: 0.6314
# Epoch 50/75
# 395/395 [==============================] - 34s 86ms/step - loss: 0.6134 - accuracy: 0.7709 - precision: 0.8197 - recall: 0.7163 - auc: 0.9614 - f1_score: 0.7642 - val_loss: 1.1245 - val_accuracy: 0.6441 - val_precision: 0.6869 - val_recall: 0.6055 - val_auc: 0.8999 - val_f1_score: 0.6438
# Epoch 51/75
# 395/395 [==============================] - 35s 88ms/step - loss: 0.5979 - accuracy: 0.7781 - precision: 0.8268 - recall: 0.7265 - auc: 0.9631 - f1_score: 0.7730 - val_loss: 1.1927 - val_accuracy: 0.6295 - val_precision: 0.6692 - val_recall: 0.5902 - val_auc: 0.8939 - val_f1_score: 0.6267
# Epoch 52/75
# 395/395 [==============================] - 34s 86ms/step - loss: 0.5855 - accuracy: 0.7841 - precision: 0.8300 - recall: 0.7338 - auc: 0.9644 - f1_score: 0.7786 - val_loss: 1.2044 - val_accuracy: 0.6450 - val_precision: 0.6766 - val_recall: 0.6124 - val_auc: 0.8971 - val_f1_score: 0.6425
# Epoch 53/75
# 395/395 [==============================] - 34s 86ms/step - loss: 0.5732 - accuracy: 0.7886 - precision: 0.8309 - recall: 0.7403 - auc: 0.9660 - f1_score: 0.7827 - val_loss: 1.2253 - val_accuracy: 0.6318 - val_precision: 0.6700 - val_recall: 0.6010 - val_auc: 0.8930 - val_f1_score: 0.6330
# Epoch 54/75
# 395/395 [==============================] - 34s 86ms/step - loss: 0.5755 - accuracy: 0.7875 - precision: 0.8305 - recall: 0.7383 - auc: 0.9655 - f1_score: 0.7813 - val_loss: 1.2193 - val_accuracy: 0.6359 - val_precision: 0.6701 - val_recall: 0.6042 - val_auc: 0.8945 - val_f1_score: 0.6345
# Epoch 55/75
# 395/395 [==============================] - 34s 86ms/step - loss: 0.5506 - accuracy: 0.7962 - precision: 0.8374 - recall: 0.7500 - auc: 0.9686 - f1_score: 0.7910 - val_loss: 1.2288 - val_accuracy: 0.6370 - val_precision: 0.6712 - val_recall: 0.6055 - val_auc: 0.8942 - val_f1_score: 0.6359
# Epoch 56/75
# 395/395 [==============================] - 34s 85ms/step - loss: 0.5474 - accuracy: 0.7973 - precision: 0.8373 - recall: 0.7537 - auc: 0.9688 - f1_score: 0.7930 - val_loss: 1.3081 - val_accuracy: 0.6130 - val_precision: 0.6508 - val_recall: 0.5795 - val_auc: 0.8838 - val_f1_score: 0.6134
# Epoch 57/75
# 395/395 [==============================] - 34s 86ms/step - loss: 0.5318 - accuracy: 0.8047 - precision: 0.8429 - recall: 0.7620 - auc: 0.9704 - f1_score: 0.8001 - val_loss: 1.2790 - val_accuracy: 0.6414 - val_precision: 0.6705 - val_recall: 0.6134 - val_auc: 0.8943 - val_f1_score: 0.6390
# Epoch 58/75
# 395/395 [==============================] - 34s 86ms/step - loss: 0.5286 - accuracy: 0.8038 - precision: 0.8453 - recall: 0.7636 - auc: 0.9708 - f1_score: 0.8021 - val_loss: 1.2314 - val_accuracy: 0.6375 - val_precision: 0.6690 - val_recall: 0.6068 - val_auc: 0.8942 - val_f1_score: 0.6360
# Epoch 59/75
# 395/395 [==============================] - 34s 86ms/step - loss: 0.5153 - accuracy: 0.8140 - precision: 0.8496 - recall: 0.7761 - auc: 0.9720 - f1_score: 0.8109 - val_loss: 1.2613 - val_accuracy: 0.6288 - val_precision: 0.6635 - val_recall: 0.6003 - val_auc: 0.8922 - val_f1_score: 0.6308
# Epoch 60/75
# 395/395 [==============================] - 34s 86ms/step - loss: 0.4993 - accuracy: 0.8138 - precision: 0.8508 - recall: 0.7767 - auc: 0.9738 - f1_score: 0.8117 - val_loss: 1.2965 - val_accuracy: 0.6345 - val_precision: 0.6641 - val_recall: 0.6056 - val_auc: 0.8911 - val_f1_score: 0.6335
# Epoch 61/75
# 395/395 [==============================] - 34s 86ms/step - loss: 0.4983 - accuracy: 0.8149 - precision: 0.8516 - recall: 0.7772 - auc: 0.9738 - f1_score: 0.8124 - val_loss: 1.2805 - val_accuracy: 0.6280 - val_precision: 0.6577 - val_recall: 0.5973 - val_auc: 0.8916 - val_f1_score: 0.6257
# Epoch 62/75
# 395/395 [==============================] - 34s 86ms/step - loss: 0.4862 - accuracy: 0.8200 - precision: 0.8528 - recall: 0.7860 - auc: 0.9750 - f1_score: 0.8177 - val_loss: 1.2974 - val_accuracy: 0.6317 - val_precision: 0.6658 - val_recall: 0.6039 - val_auc: 0.8900 - val_f1_score: 0.6331
# Epoch 63/75
# 395/395 [==============================] - 34s 87ms/step - loss: 0.4879 - accuracy: 0.8206 - precision: 0.8558 - recall: 0.7866 - auc: 0.9748 - f1_score: 0.8194 - val_loss: 1.3099 - val_accuracy: 0.6400 - val_precision: 0.6684 - val_recall: 0.6158 - val_auc: 0.8918 - val_f1_score: 0.6411
# Epoch 64/75
# 395/395 [==============================] - 34s 86ms/step - loss: 0.4757 - accuracy: 0.8268 - precision: 0.8591 - recall: 0.7922 - auc: 0.9760 - f1_score: 0.8240 - val_loss: 1.3287 - val_accuracy: 0.6242 - val_precision: 0.6550 - val_recall: 0.5974 - val_auc: 0.8865 - val_f1_score: 0.6239
# Epoch 65/75
# 395/395 [==============================] - 34s 86ms/step - loss: 0.4642 - accuracy: 0.8305 - precision: 0.8597 - recall: 0.7973 - auc: 0.9769 - f1_score: 0.8270 - val_loss: 1.3110 - val_accuracy: 0.6353 - val_precision: 0.6676 - val_recall: 0.6121 - val_auc: 0.8911 - val_f1_score: 0.6385
# Epoch 66/75
# 395/395 [==============================] - 34s 86ms/step - loss: 0.4500 - accuracy: 0.8325 - precision: 0.8637 - recall: 0.8025 - auc: 0.9783 - f1_score: 0.8317 - val_loss: 1.3223 - val_accuracy: 0.6489 - val_precision: 0.6728 - val_recall: 0.6269 - val_auc: 0.8945 - val_f1_score: 0.6489
# Epoch 67/75
# 395/395 [==============================] - 34s 86ms/step - loss: 0.4526 - accuracy: 0.8358 - precision: 0.8657 - recall: 0.8047 - auc: 0.9780 - f1_score: 0.8338 - val_loss: 1.4075 - val_accuracy: 0.6310 - val_precision: 0.6561 - val_recall: 0.6065 - val_auc: 0.8838 - val_f1_score: 0.6297
# Epoch 68/75
# 395/395 [==============================] - 34s 86ms/step - loss: 0.4428 - accuracy: 0.8375 - precision: 0.8672 - recall: 0.8080 - auc: 0.9789 - f1_score: 0.8364 - val_loss: 1.3170 - val_accuracy: 0.6366 - val_precision: 0.6670 - val_recall: 0.6127 - val_auc: 0.8905 - val_f1_score: 0.6383
# Epoch 69/75
# 395/395 [==============================] - 35s 87ms/step - loss: 0.4368 - accuracy: 0.8397 - precision: 0.8680 - recall: 0.8121 - auc: 0.9795 - f1_score: 0.8388 - val_loss: 1.3981 - val_accuracy: 0.6260 - val_precision: 0.6521 - val_recall: 0.6027 - val_auc: 0.8830 - val_f1_score: 0.6265
# Epoch 70/75
# 395/395 [==============================] - 34s 86ms/step - loss: 0.4351 - accuracy: 0.8394 - precision: 0.8664 - recall: 0.8093 - auc: 0.9798 - f1_score: 0.8366 - val_loss: 1.3657 - val_accuracy: 0.6461 - val_precision: 0.6707 - val_recall: 0.6274 - val_auc: 0.8902 - val_f1_score: 0.6482
# Epoch 71/75
# 395/395 [==============================] - 34s 86ms/step - loss: 0.4206 - accuracy: 0.8478 - precision: 0.8742 - recall: 0.8208 - auc: 0.9807 - f1_score: 0.8464 - val_loss: 1.3983 - val_accuracy: 0.6341 - val_precision: 0.6583 - val_recall: 0.6145 - val_auc: 0.8858 - val_f1_score: 0.6353
# Epoch 72/75
# 395/395 [==============================] - 34s 86ms/step - loss: 0.4217 - accuracy: 0.8440 - precision: 0.8726 - recall: 0.8197 - auc: 0.9807 - f1_score: 0.8452 - val_loss: 1.3575 - val_accuracy: 0.6419 - val_precision: 0.6671 - val_recall: 0.6195 - val_auc: 0.8903 - val_f1_score: 0.6421
# Epoch 73/75
# 395/395 [==============================] - 34s 86ms/step - loss: 0.4071 - accuracy: 0.8514 - precision: 0.8776 - recall: 0.8271 - auc: 0.9819 - f1_score: 0.8515 - val_loss: 1.4173 - val_accuracy: 0.6243 - val_precision: 0.6502 - val_recall: 0.6008 - val_auc: 0.8825 - val_f1_score: 0.6242
# Epoch 74/75
# 395/395 [==============================] - 34s 86ms/step - loss: 0.4083 - accuracy: 0.8511 - precision: 0.8766 - recall: 0.8266 - auc: 0.9817 - f1_score: 0.8507 - val_loss: 1.3574 - val_accuracy: 0.6604 - val_precision: 0.6839 - val_recall: 0.6409 - val_auc: 0.8946 - val_f1_score: 0.6615
# Epoch 75/75
# 395/395 [==============================] - 34s 87ms/step - loss: 0.4007 - accuracy: 0.8520 - precision: 0.8776 - recall: 0.8279 - auc: 0.9825 - f1_score: 0.8518 - val_loss: 1.4333 - val_accuracy: 0.6424 - val_precision: 0.6649 - val_recall: 0.6222 - val_auc: 0.8865 - val_f1_score: 0.6429

# %% [markdown]
# <h2>Saving the Model</h2>

# %%
# !mkdir /content/git5
# %cd /content/git5
# create the git folder
# !git init
# !git config --global user.email "samkht3327@gmail.com"
# !git config --global user.name "Ash3327"
# !git remote remove origin
# !git remote add origin "https://HEP-Dexan3327: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@github.com/HEP-Dexan3327/AI-Diary-1-Vanilla-CNN-"
# !git pull origin main
# Out:
# /content/git5
# Initialized empty Git repository in /content/git5/.git/
# fatal: No such remote: origin
# remote: Enumerating objects: 359, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 359 (delta 2), reused 2 (delta 0), pack-reused 347
# Receiving objects: 100% (359/359), 148.47 MiB | 27.35 MiB/s, done.
# Resolving deltas: 100% (172/172), done.
# From https://github.com/HEP-Dexan3327/AI-Diary-1-Vanilla-CNN-
#  * branch            main       -> FETCH_HEAD
#  * [new branch]      main       -> origin/main

# %%
# %cd models
# navigate to git/models
# Out:
# /content/git5/models

# %%
#Saving the visualization of model
visualfile = version+"_shape.png"
# !pip install visualkeras
import visualkeras
from tensorflow.keras.layers import BatchNormalization, ZeroPadding2D, Activation, MaxPool2D

# Visualizing our model architecture
visualkeras.layered_view(model, 
                         legend=True, 
                         to_file=visualfile,
                         type_ignore=[MaxPool2D,Activation,ZeroPadding2D,BatchNormalization,Dropout,Flatten])  # font is optional!
                         
# !git add $visualfile
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting visualkeras
#   Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.7/dist-packages (from visualkeras) (1.21.6)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from visualkeras) (7.1.2)
# Collecting aggdraw>=1.3.11
#   Downloading aggdraw-1.3.14-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (992 kB)
#      |████████████████████████████████| 992 kB 8.7 MB/s
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.14 visualkeras-0.0.2

# %%
#Saving the model
modelfile = version+'_model.h5'
model.save(modelfile)

# !git add $modelfile

# %%
errorrate = "0.6424"

# %%
# %cd /content/git5/_trials
mdfile = version+".md"
# navigate to git/_trials
nameline = "name: " + name
datetime = "datetime: " + version
errorate = "errorrate: " + errorrate
imagelin = "img: " + visualfile
datasetn = "dataset: " + dataset
# !echo --- > $mdfile
# !echo $nameline >> $mdfile
# !echo $datetime >> $mdfile
# !echo $errorate >> $mdfile
# !echo $imagelin >> $mdfile
# !echo $datasetn >> $mdfile
# !echo --- >> $mdfile

# !git add $mdfile
# Out:
# /content/git5/_trials

# %%
# pushing back to git repo
# %cd /content/git5
# !git commit -m $version
# Out:
# /content/git5
# [master 0db2dab] 202206111539
#  3 files changed, 7 insertions(+)
#  create mode 100644 _trials/202206111539.md
#  create mode 100644 models/202206111539_model.h5
#  create mode 100644 models/202206111539_shape.png

# %%
# !pwd
# Out:
# /content/git5

# %%
# !git push -u origin master
# Out:
# Counting objects: 6, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (6/6), 16.77 MiB | 6.81 MiB/s, done.
# Total 6 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/HEP-Dexan3327/AI-Diary-1-Vanilla-CNN-
#    058c471..0db2dab  master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.

# %%
def plt_acc_loss(model,num_epochs):
    acc = model.history['accuracy'] # new change for TF changes
    val_acc = model.history['val_accuracy'] # new change for TF changes

    loss = model.history['loss']
    val_loss = model.history['val_loss']

    epochs_range = range(num_epochs)

    plt.figure(figsize=(8, 8))
    plt.subplot(1, 2, 1)
    plt.ylim(0.3,1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.show()

# %%
import matplotlib.pyplot as plt
plt_acc_loss(model_info,75)

# %% [markdown]
# <h2>Loading the Model</h2>
# Loading the model named "model.h5". If you don't have enough time to train, just use the file I gave.
# The accuracy of my model is around 60% only. The accuracy can be slightly improved by training with 200 iterations.

# %%
#from keras.models import load_model
#emotion_model = load_model('model.h5',custom_objects={'f1_score':f1_score})

# %% [markdown]
# <h2>Confusion Matrix</h2>

# %%
# %cd /content
import tensorflow as tf
import numpy as np
from keras.models import model_from_json
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report,ConfusionMatrixDisplay


emotion_dict = {0: "Angry", 1: "Fear", 2: "Happy", 3: "Neutral", 4: "Sad", 5: "Surprised"}

# do prediction on test data


predictions = np.array([])
labels =  np.array([])

I = 0
for x, y in val_data:
  predictions = np.concatenate([predictions, np.argmax(model.predict(x),axis=-1)])
  labels = np.concatenate([labels, np.argmax(y,axis=-1)])
  I += 1
  if I > 200:
    break
ConfusionMatrixDisplay(
    confusion_matrix=tf.math.confusion_matrix(
        labels=labels, predictions=predictions)
    .numpy(), display_labels=emotion_dict).plot(cmap=plt.cm.Blues)
plt.show()
print(tf.math.confusion_matrix(labels=labels, predictions=predictions).numpy())
# Out:
# /content
# [[1104  139   30  194  255   32]
#  [ 335  748   38  226  411  101]
#  [ 163   65 2618  219  107   48]
#  [ 164   91   95 1434  418   29]
#  [ 316  148   65  423 1280   31]
#  [  91  180   81   57   30 1061]]

# %%
# Classification report
print("-----------------------------------------------------------------")
print(classification_report(labels, predictions))
# Out:
# -----------------------------------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.51      0.63      0.56      1754
#          1.0       0.55      0.40      0.46      1859
#          2.0       0.89      0.81      0.85      3220
#          3.0       0.56      0.64      0.60      2231
#          4.0       0.51      0.57      0.54      2263
#          5.0       0.81      0.71      0.76      1500
#
#     accuracy                           0.64     12827
#    macro avg       0.64      0.63      0.63     12827
# weighted avg       0.66      0.64      0.65     12827

# %% [markdown]
# <h1>Photo Emotion Analysis</h1>

# %%
def emotion_analysis(emotions):
    objects = ('Angry', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise')
    y_pos = np.arange(len(objects))
    
    plt.bar(y_pos, emotions, align='center', alpha=0.5)
    plt.xticks(y_pos, objects)
    plt.ylabel('percentage')
    plt.title('emotion')
    
    plt.show()

# %%
import cv2
            
def facecrop(image):  
    facedata = cv2.data.haarcascades + 'haarcascade_frontalface_alt.xml'
    cascade = cv2.CascadeClassifier(facedata)

    img = cv2.imread(image)

    try:
    
        minisize = (img.shape[1],img.shape[0])
        miniframe = cv2.resize(img, minisize)

        faces = cascade.detectMultiScale(miniframe)

        for f in faces:
            x, y, w, h = [ v for v in f ]
            cv2.rectangle(img, (x,y), (x+w,y+h), (0,255,0), 2)

            sub_face = img[y:y+h, x:x+w]

            
            cv2.imwrite('capture.jpg', sub_face)
            print ("Writing: " + image)

    except Exception as e:
        print (e)

   


if __name__ == '__main__':
    facecrop(root+"facialexpression/fear.jpg") ###############the file path here is your image

#Testing a file.

from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator

import numpy as np
import matplotlib.pyplot as plt


file = 'capture.jpg'
true_image = image.load_img(file)
img = image.load_img(file, color_mode="grayscale", target_size=(48, 48))

x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)

x /= 255

custom = model.predict(x)
emotion_analysis(custom[0])

x = np.array(x, 'float32')
x = x.reshape([48, 48])


plt.imshow(true_image)
plt.show()
# Out:
# Writing: /content/drive/MyDrive/Colab/facialexpression/fear.jpg
