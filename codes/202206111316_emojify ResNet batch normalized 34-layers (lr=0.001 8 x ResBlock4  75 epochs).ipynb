# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
root = "/content/drive/MyDrive/Colab/"
version = "202206111316"
name = "ResNet batch normalized 34-layers _ lr=0.001 8 x ResBlock4 _ 75 epochs"
dataset = "emojify"

# %%
# Import data source
from zipfile import ZipFile
file_name = root+"facialexpression/emojify.zip"

with ZipFile(file_name, 'r') as zip:
  zip.extractall()
  print("Done")
# Out:
# Done

# %%
import numpy as np
import cv2
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, BatchNormalization, MaxPooling2D, Add
from tensorflow.keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# <h2>Importing Data</h2>

# %%
from tensorflow import keras
# Model / data parameters
num_classes = 6
input_shape = (48, 48, 1)

train_dir = 'train'
val_dir = 'test'
train_datagen = ImageDataGenerator(
        rotation_range=30,## data augmentation, able to increase the accuracy of the training.
        zoom_range=0.2,
        rescale=1./255,
        fill_mode='nearest') # Split 0.2 of the train data to validation data
val_datagen = ImageDataGenerator(rescale=1./255)

train_data = train_datagen.flow_from_directory(
        train_dir,
        target_size=(48,48),
        batch_size=64,
        color_mode="grayscale",
        class_mode='categorical')

val_data = val_datagen.flow_from_directory(
        val_dir,
        target_size=(48,48),
        batch_size=64,
        color_mode="grayscale",
        class_mode='categorical')
# Out:
# Found 25269 images belonging to 6 classes.
# Found 7067 images belonging to 6 classes.

# %% [markdown]
# <h2>Defining the Model</h2>

# %%
from keras import initializers
def conv(filter: int, kernel_size: int, zero: bool, stride: int) -> Conv2D:
  if zero:
    return Conv2D(filters=filter, kernel_size=kernel_size, activation="relu", padding="same", strides=stride, kernel_initializer=initializers.Zeros())
  else:
    return Conv2D(filters=filter, kernel_size=kernel_size, activation="relu", padding="same", strides=stride)
class Residual(keras.layers.Layer):
  def __init__(self, downsample: bool, filters: int, zero: bool, kernel_size: int = 3):
    super(Residual, self).__init__()
    self.conv1 = conv(filters, kernel_size, zero, (1 if not downsample else 2))
    self.bn1 = BatchNormalization()
    self.conv2 = conv(filters, kernel_size, zero, 1)
    self.bn2 = BatchNormalization()
    self.conv3 = conv(filters, kernel_size, zero, 1)
    self.bn3 = BatchNormalization()
    self.conv4 = conv(filters, kernel_size, zero, 1)
    self.convx = Conv2D(kernel_size=1, strides=2, filters=filters, padding="same")
    self.downsample = downsample
    self.add = Add()
    self.bnO = BatchNormalization()

  def call(self, inputs):
    x = inputs
    y = self.bn1(self.conv1(x))
    y = self.bn2(self.conv2(y))
    y = self.bn3(self.conv3(y))
    y = self.conv4(y)
    if self.downsample:
      x = self.convx(x)
    out = self.add([x,y])
    out = self.bnO(out)
    return out

  def get_config(self):
    return {
        "downsample": self.downsample,
        "conv1": self.conv1,
        "bn1": self.bn1,
        "conv2": self.conv2,
        "bn2": self.bn2,
        "conv3": self.conv3,
        "bn3": self.bn3,
        "conv4": self.conv4,
        "convx": self.convx,
        "add": self.add,
        "bnO": self.bnO
    }

# %%
B1 = BatchNormalization()
C = Conv2D(filters=32, kernel_size=3, activation="relu", padding="same")
B2 = BatchNormalization()
R11 = Residual(False, 32, False, 3)
R12 = Residual(False, 32, False, 3)
R21 = Residual(True, 64, False, 3)
R22 = Residual(False, 64, False, 3)
R31 = Residual(True, 128, False, 3)
R32 = Residual(False, 128, False, 3)
R41 = Residual(True, 256, True, 3)
R42 = Residual(False, 256, True, 3)
F = Flatten()
D = Dense(num_classes, activation="softmax")

model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        B1,C,B2,
        R11,R12,
        R21,R22,
        R31,R32,
        R41,R42,
        F,
        D,
    ]
)

# %% [markdown]
# <h3>F1 Score: a method for evaluating the accuracy of a model</h3>
# The block below should be runned before loading the model.

# %%
import keras.backend as K
def f1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %% [markdown]
# <h3>Training the Model</h3>
# The accuracy of my model is around 60% only. The accuracy can be slightly improved by training with 200 iterations. Use Google Colab with a GPU to speed up the training to around 10~12s per epoch.
# Note that the accuracy of the model for random guessing is 16.67% (1/6); While the accuracy for a binary classification model for random guessing is 50% (1/2), so the accuracies of binary classification model and this kind of model cannot be compared directly.

# %%
model.compile(loss='categorical_crossentropy',optimizer=Adam(learning_rate=0.001, decay=1e-6),
      metrics=['accuracy',tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),f1_score])
batch_size = 128
model_info = model.fit(
        train_data, validation_data=val_data, batch_size=batch_size, epochs=75)
# Out:
# Epoch 1/75
# 395/395 [==============================] - 57s 103ms/step - loss: 2.5834 - accuracy: 0.2209 - precision: 0.2450 - recall: 0.0615 - auc: 0.5714 - f1_score: 0.0912 - val_loss: 1385.6927 - val_accuracy: 0.1578 - val_precision: 0.1513 - val_recall: 0.1214 - val_auc: 0.4919 - val_f1_score: 0.1338
# Epoch 2/75
# 395/395 [==============================] - 40s 101ms/step - loss: 2.5261 - accuracy: 0.2195 - precision: 0.2113 - recall: 0.0115 - auc: 0.5762 - f1_score: 0.0214 - val_loss: 166.6821 - val_accuracy: 0.1831 - val_precision: 0.1767 - val_recall: 0.0976 - val_auc: 0.5080 - val_f1_score: 0.1256
# Epoch 3/75
# 395/395 [==============================] - 40s 101ms/step - loss: 2.2240 - accuracy: 0.2217 - precision: 0.2174 - recall: 0.0179 - auc: 0.5784 - f1_score: 0.0321 - val_loss: 2.9717 - val_accuracy: 0.2400 - val_precision: 0.1935 - val_recall: 0.0201 - val_auc: 0.5930 - val_f1_score: 0.0359
# Epoch 4/75
# 395/395 [==============================] - 40s 102ms/step - loss: 1.9899 - accuracy: 0.2341 - precision: 0.2739 - recall: 0.0340 - auc: 0.5902 - f1_score: 0.0577 - val_loss: 1.7944 - val_accuracy: 0.2338 - val_precision: 0.1771 - val_recall: 0.0024 - val_auc: 0.5876 - val_f1_score: 0.0047
# Epoch 5/75
# 395/395 [==============================] - 40s 101ms/step - loss: 1.7435 - accuracy: 0.2631 - precision: 0.3889 - recall: 0.0169 - auc: 0.6271 - f1_score: 0.0317 - val_loss: 1.7020 - val_accuracy: 0.2707 - val_precision: 0.5000 - val_recall: 7.0751e-04 - val_auc: 0.6461 - val_f1_score: 0.0014
# Epoch 6/75
# 395/395 [==============================] - 40s 101ms/step - loss: 1.6894 - accuracy: 0.2882 - precision: 0.5462 - recall: 0.0185 - auc: 0.6523 - f1_score: 0.0352 - val_loss: 1.6678 - val_accuracy: 0.3000 - val_precision: 0.6018 - val_recall: 0.0096 - val_auc: 0.6637 - val_f1_score: 0.0186
# Epoch 7/75
# 395/395 [==============================] - 40s 101ms/step - loss: 1.6609 - accuracy: 0.3042 - precision: 0.5968 - recall: 0.0265 - auc: 0.6688 - f1_score: 0.0499 - val_loss: 1.6085 - val_accuracy: 0.3441 - val_precision: 0.6417 - val_recall: 0.0388 - val_auc: 0.6999 - val_f1_score: 0.0722
# Epoch 8/75
# 395/395 [==============================] - 40s 100ms/step - loss: 1.6387 - accuracy: 0.3221 - precision: 0.6037 - recall: 0.0351 - auc: 0.6827 - f1_score: 0.0653 - val_loss: 1.5555 - val_accuracy: 0.3850 - val_precision: 0.7512 - val_recall: 0.0675 - val_auc: 0.7260 - val_f1_score: 0.1217
# Epoch 9/75
# 395/395 [==============================] - 40s 100ms/step - loss: 1.6180 - accuracy: 0.3321 - precision: 0.6287 - recall: 0.0482 - auc: 0.6938 - f1_score: 0.0884 - val_loss: 1.5528 - val_accuracy: 0.3724 - val_precision: 0.6459 - val_recall: 0.1040 - val_auc: 0.7286 - val_f1_score: 0.1772
# Epoch 10/75
# 395/395 [==============================] - 40s 101ms/step - loss: 1.5942 - accuracy: 0.3435 - precision: 0.6174 - recall: 0.0633 - auc: 0.7060 - f1_score: 0.1133 - val_loss: 1.5581 - val_accuracy: 0.3639 - val_precision: 0.6753 - val_recall: 0.0889 - val_auc: 0.7243 - val_f1_score: 0.1553
# Epoch 11/75
# 395/395 [==============================] - 40s 101ms/step - loss: 1.5529 - accuracy: 0.3652 - precision: 0.6449 - recall: 0.0895 - auc: 0.7259 - f1_score: 0.1554 - val_loss: 1.7681 - val_accuracy: 0.3509 - val_precision: 0.4884 - val_recall: 0.1702 - val_auc: 0.6922 - val_f1_score: 0.2501
# Epoch 12/75
# 395/395 [==============================] - 40s 101ms/step - loss: 1.4955 - accuracy: 0.3879 - precision: 0.6611 - recall: 0.1198 - auc: 0.7512 - f1_score: 0.2006 - val_loss: 1.8043 - val_accuracy: 0.3927 - val_precision: 0.4849 - val_recall: 0.2710 - val_auc: 0.7300 - val_f1_score: 0.3463
# Epoch 13/75
# 395/395 [==============================] - 40s 101ms/step - loss: 1.4402 - accuracy: 0.4174 - precision: 0.6696 - recall: 0.1545 - auc: 0.7739 - f1_score: 0.2487 - val_loss: 1.4469 - val_accuracy: 0.4404 - val_precision: 0.6497 - val_recall: 0.2042 - val_auc: 0.7744 - val_f1_score: 0.3098
# Epoch 14/75
# 395/395 [==============================] - 40s 101ms/step - loss: 1.3800 - accuracy: 0.4451 - precision: 0.6758 - recall: 0.1908 - auc: 0.7958 - f1_score: 0.2950 - val_loss: 1.4311 - val_accuracy: 0.4637 - val_precision: 0.6145 - val_recall: 0.3137 - val_auc: 0.8027 - val_f1_score: 0.4131
# Epoch 15/75
# 395/395 [==============================] - 40s 101ms/step - loss: 1.3391 - accuracy: 0.4648 - precision: 0.6786 - recall: 0.2167 - auc: 0.8095 - f1_score: 0.3264 - val_loss: 1.4349 - val_accuracy: 0.4480 - val_precision: 0.5956 - val_recall: 0.3112 - val_auc: 0.7940 - val_f1_score: 0.4069
# Epoch 16/75
# 395/395 [==============================] - 40s 101ms/step - loss: 1.2919 - accuracy: 0.4872 - precision: 0.6898 - recall: 0.2494 - auc: 0.8247 - f1_score: 0.3643 - val_loss: 1.3497 - val_accuracy: 0.4919 - val_precision: 0.6389 - val_recall: 0.3417 - val_auc: 0.8190 - val_f1_score: 0.4450
# Epoch 17/75
# 395/395 [==============================] - 40s 101ms/step - loss: 1.2515 - accuracy: 0.5045 - precision: 0.6981 - recall: 0.2822 - auc: 0.8370 - f1_score: 0.4000 - val_loss: 1.1948 - val_accuracy: 0.5404 - val_precision: 0.6714 - val_recall: 0.4068 - val_auc: 0.8563 - val_f1_score: 0.5050
# Epoch 18/75
# 395/395 [==============================] - 40s 101ms/step - loss: 1.2144 - accuracy: 0.5230 - precision: 0.7008 - recall: 0.3122 - auc: 0.8469 - f1_score: 0.4299 - val_loss: 1.2641 - val_accuracy: 0.5168 - val_precision: 0.6459 - val_recall: 0.3830 - val_auc: 0.8390 - val_f1_score: 0.4799
# Epoch 19/75
# 395/395 [==============================] - 40s 101ms/step - loss: 1.1831 - accuracy: 0.5355 - precision: 0.7005 - recall: 0.3321 - auc: 0.8556 - f1_score: 0.4488 - val_loss: 1.1769 - val_accuracy: 0.5529 - val_precision: 0.6891 - val_recall: 0.3971 - val_auc: 0.8605 - val_f1_score: 0.5024
# Epoch 20/75
# 395/395 [==============================] - 40s 101ms/step - loss: 1.1608 - accuracy: 0.5455 - precision: 0.7036 - recall: 0.3521 - auc: 0.8613 - f1_score: 0.4679 - val_loss: 1.1406 - val_accuracy: 0.5568 - val_precision: 0.6895 - val_recall: 0.4101 - val_auc: 0.8694 - val_f1_score: 0.5128
# Epoch 21/75
# 395/395 [==============================] - 40s 101ms/step - loss: 1.1278 - accuracy: 0.5594 - precision: 0.7120 - recall: 0.3758 - auc: 0.8697 - f1_score: 0.4903 - val_loss: 1.1559 - val_accuracy: 0.5611 - val_precision: 0.6851 - val_recall: 0.4211 - val_auc: 0.8659 - val_f1_score: 0.5192
# Epoch 22/75
# 395/395 [==============================] - 40s 101ms/step - loss: 1.1043 - accuracy: 0.5721 - precision: 0.7179 - recall: 0.3944 - auc: 0.8755 - f1_score: 0.5076 - val_loss: 1.1578 - val_accuracy: 0.5594 - val_precision: 0.6836 - val_recall: 0.4084 - val_auc: 0.8659 - val_f1_score: 0.5097
# Epoch 23/75
# 395/395 [==============================] - 40s 101ms/step - loss: 1.0866 - accuracy: 0.5793 - precision: 0.7148 - recall: 0.4036 - auc: 0.8797 - f1_score: 0.5144 - val_loss: 1.0555 - val_accuracy: 0.5932 - val_precision: 0.7206 - val_recall: 0.4624 - val_auc: 0.8877 - val_f1_score: 0.5621
# Epoch 24/75
# 395/395 [==============================] - 40s 102ms/step - loss: 1.0653 - accuracy: 0.5885 - precision: 0.7221 - recall: 0.4195 - auc: 0.8847 - f1_score: 0.5293 - val_loss: 1.0510 - val_accuracy: 0.6062 - val_precision: 0.7048 - val_recall: 0.4899 - val_auc: 0.8901 - val_f1_score: 0.5768
# Epoch 25/75
# 395/395 [==============================] - 40s 102ms/step - loss: 1.0494 - accuracy: 0.5918 - precision: 0.7230 - recall: 0.4322 - auc: 0.8881 - f1_score: 0.5395 - val_loss: 1.0604 - val_accuracy: 0.5957 - val_precision: 0.7235 - val_recall: 0.4658 - val_auc: 0.8862 - val_f1_score: 0.5651
# Epoch 26/75
# 395/395 [==============================] - 40s 102ms/step - loss: 1.0288 - accuracy: 0.6043 - precision: 0.7312 - recall: 0.4477 - auc: 0.8926 - f1_score: 0.5540 - val_loss: 1.0541 - val_accuracy: 0.6034 - val_precision: 0.7127 - val_recall: 0.4907 - val_auc: 0.8902 - val_f1_score: 0.5791
# Epoch 27/75
# 395/395 [==============================] - 40s 102ms/step - loss: 1.0139 - accuracy: 0.6099 - precision: 0.7345 - recall: 0.4596 - auc: 0.8959 - f1_score: 0.5641 - val_loss: 1.0690 - val_accuracy: 0.6024 - val_precision: 0.7153 - val_recall: 0.4762 - val_auc: 0.8868 - val_f1_score: 0.5708
# Epoch 28/75
# 395/395 [==============================] - 40s 101ms/step - loss: 1.0048 - accuracy: 0.6125 - precision: 0.7315 - recall: 0.4611 - auc: 0.8977 - f1_score: 0.5647 - val_loss: 1.1142 - val_accuracy: 0.5918 - val_precision: 0.6710 - val_recall: 0.5008 - val_auc: 0.8825 - val_f1_score: 0.5736
# Epoch 29/75
# 395/395 [==============================] - 40s 101ms/step - loss: 0.9864 - accuracy: 0.6189 - precision: 0.7395 - recall: 0.4794 - auc: 0.9014 - f1_score: 0.5805 - val_loss: 1.0394 - val_accuracy: 0.6086 - val_precision: 0.7026 - val_recall: 0.5151 - val_auc: 0.8956 - val_f1_score: 0.5930
# Epoch 30/75
# 395/395 [==============================] - 40s 101ms/step - loss: 0.9723 - accuracy: 0.6265 - precision: 0.7436 - recall: 0.4863 - auc: 0.9045 - f1_score: 0.5869 - val_loss: 1.0599 - val_accuracy: 0.6038 - val_precision: 0.7024 - val_recall: 0.5097 - val_auc: 0.8902 - val_f1_score: 0.5890
# Epoch 31/75
# 395/395 [==============================] - 40s 102ms/step - loss: 0.9584 - accuracy: 0.6299 - precision: 0.7436 - recall: 0.4938 - auc: 0.9071 - f1_score: 0.5924 - val_loss: 1.1281 - val_accuracy: 0.5922 - val_precision: 0.6780 - val_recall: 0.4950 - val_auc: 0.8803 - val_f1_score: 0.5710
# Epoch 32/75
# 395/395 [==============================] - 40s 101ms/step - loss: 0.9450 - accuracy: 0.6358 - precision: 0.7432 - recall: 0.5037 - auc: 0.9098 - f1_score: 0.5991 - val_loss: 1.0203 - val_accuracy: 0.6192 - val_precision: 0.7105 - val_recall: 0.5189 - val_auc: 0.8979 - val_f1_score: 0.5988
# Epoch 33/75
# 395/395 [==============================] - 40s 101ms/step - loss: 0.9299 - accuracy: 0.6419 - precision: 0.7502 - recall: 0.5127 - auc: 0.9128 - f1_score: 0.6081 - val_loss: 1.0644 - val_accuracy: 0.6117 - val_precision: 0.6831 - val_recall: 0.5322 - val_auc: 0.8930 - val_f1_score: 0.5987
# Epoch 34/75
# 395/395 [==============================] - 40s 101ms/step - loss: 0.9096 - accuracy: 0.6497 - precision: 0.7564 - recall: 0.5289 - auc: 0.9165 - f1_score: 0.6215 - val_loss: 1.0802 - val_accuracy: 0.6079 - val_precision: 0.6938 - val_recall: 0.5180 - val_auc: 0.8913 - val_f1_score: 0.5929
# Epoch 35/75
# 395/395 [==============================] - 40s 102ms/step - loss: 0.9025 - accuracy: 0.6560 - precision: 0.7589 - recall: 0.5370 - auc: 0.9178 - f1_score: 0.6282 - val_loss: 1.0240 - val_accuracy: 0.6206 - val_precision: 0.7071 - val_recall: 0.5271 - val_auc: 0.8977 - val_f1_score: 0.6036
# Epoch 36/75
# 395/395 [==============================] - 40s 101ms/step - loss: 0.8927 - accuracy: 0.6619 - precision: 0.7574 - recall: 0.5406 - auc: 0.9197 - f1_score: 0.6300 - val_loss: 1.0291 - val_accuracy: 0.6256 - val_precision: 0.7083 - val_recall: 0.5444 - val_auc: 0.8994 - val_f1_score: 0.6154
# Epoch 37/75
# 395/395 [==============================] - 40s 102ms/step - loss: 0.8784 - accuracy: 0.6619 - precision: 0.7604 - recall: 0.5509 - auc: 0.9221 - f1_score: 0.6380 - val_loss: 1.0411 - val_accuracy: 0.6177 - val_precision: 0.6919 - val_recall: 0.5304 - val_auc: 0.8968 - val_f1_score: 0.6006
# Epoch 38/75
# 395/395 [==============================] - 40s 101ms/step - loss: 0.8655 - accuracy: 0.6700 - precision: 0.7607 - recall: 0.5594 - auc: 0.9244 - f1_score: 0.6438 - val_loss: 0.9978 - val_accuracy: 0.6417 - val_precision: 0.7185 - val_recall: 0.5581 - val_auc: 0.9048 - val_f1_score: 0.6272
# Epoch 39/75
# 395/395 [==============================] - 40s 101ms/step - loss: 0.8556 - accuracy: 0.6734 - precision: 0.7659 - recall: 0.5661 - auc: 0.9262 - f1_score: 0.6502 - val_loss: 0.9976 - val_accuracy: 0.6426 - val_precision: 0.7163 - val_recall: 0.5598 - val_auc: 0.9049 - val_f1_score: 0.6277
# Epoch 40/75
# 395/395 [==============================] - 40s 102ms/step - loss: 0.8382 - accuracy: 0.6821 - precision: 0.7685 - recall: 0.5762 - auc: 0.9291 - f1_score: 0.6578 - val_loss: 1.0149 - val_accuracy: 0.6294 - val_precision: 0.7079 - val_recall: 0.5550 - val_auc: 0.9033 - val_f1_score: 0.6220
# Epoch 41/75
# 395/395 [==============================] - 40s 102ms/step - loss: 0.8252 - accuracy: 0.6859 - precision: 0.7726 - recall: 0.5838 - auc: 0.9313 - f1_score: 0.6643 - val_loss: 1.0301 - val_accuracy: 0.6274 - val_precision: 0.6971 - val_recall: 0.5598 - val_auc: 0.9018 - val_f1_score: 0.6197
# Epoch 42/75
# 395/395 [==============================] - 40s 102ms/step - loss: 0.8132 - accuracy: 0.6922 - precision: 0.7796 - recall: 0.5965 - auc: 0.9333 - f1_score: 0.6749 - val_loss: 1.0591 - val_accuracy: 0.6260 - val_precision: 0.6851 - val_recall: 0.5551 - val_auc: 0.8991 - val_f1_score: 0.6124
# Epoch 43/75
# 395/395 [==============================] - 40s 101ms/step - loss: 0.7988 - accuracy: 0.6986 - precision: 0.7780 - recall: 0.6054 - auc: 0.9355 - f1_score: 0.6802 - val_loss: 1.0576 - val_accuracy: 0.6267 - val_precision: 0.6988 - val_recall: 0.5526 - val_auc: 0.8972 - val_f1_score: 0.6166
# Epoch 44/75
# 395/395 [==============================] - 40s 101ms/step - loss: 0.7867 - accuracy: 0.7013 - precision: 0.7812 - recall: 0.6106 - auc: 0.9375 - f1_score: 0.6847 - val_loss: 1.0393 - val_accuracy: 0.6293 - val_precision: 0.6962 - val_recall: 0.5620 - val_auc: 0.9004 - val_f1_score: 0.6208
# Epoch 45/75
# 395/395 [==============================] - 40s 101ms/step - loss: 0.7691 - accuracy: 0.7106 - precision: 0.7858 - recall: 0.6236 - auc: 0.9402 - f1_score: 0.6945 - val_loss: 1.0084 - val_accuracy: 0.6436 - val_precision: 0.7033 - val_recall: 0.5816 - val_auc: 0.9069 - val_f1_score: 0.6365
# Epoch 46/75
# 395/395 [==============================] - 40s 101ms/step - loss: 0.7582 - accuracy: 0.7126 - precision: 0.7877 - recall: 0.6289 - auc: 0.9419 - f1_score: 0.6987 - val_loss: 1.0468 - val_accuracy: 0.6335 - val_precision: 0.6929 - val_recall: 0.5769 - val_auc: 0.9024 - val_f1_score: 0.6293
# Epoch 47/75
# 395/395 [==============================] - 40s 101ms/step - loss: 0.7450 - accuracy: 0.7204 - precision: 0.7920 - recall: 0.6377 - auc: 0.9438 - f1_score: 0.7061 - val_loss: 1.0869 - val_accuracy: 0.6233 - val_precision: 0.6900 - val_recall: 0.5645 - val_auc: 0.8977 - val_f1_score: 0.6204
# Epoch 48/75
# 395/395 [==============================] - 40s 102ms/step - loss: 0.7331 - accuracy: 0.7237 - precision: 0.7953 - recall: 0.6428 - auc: 0.9455 - f1_score: 0.7103 - val_loss: 1.2369 - val_accuracy: 0.6037 - val_precision: 0.6477 - val_recall: 0.5540 - val_auc: 0.8805 - val_f1_score: 0.5974
# Epoch 49/75
# 395/395 [==============================] - 40s 101ms/step - loss: 0.7246 - accuracy: 0.7261 - precision: 0.7959 - recall: 0.6480 - auc: 0.9467 - f1_score: 0.7138 - val_loss: 1.0529 - val_accuracy: 0.6372 - val_precision: 0.6975 - val_recall: 0.5850 - val_auc: 0.9025 - val_f1_score: 0.6354
# Epoch 50/75
# 395/395 [==============================] - 40s 101ms/step - loss: 0.7138 - accuracy: 0.7328 - precision: 0.7983 - recall: 0.6585 - auc: 0.9482 - f1_score: 0.7212 - val_loss: 1.0564 - val_accuracy: 0.6345 - val_precision: 0.6958 - val_recall: 0.5763 - val_auc: 0.9001 - val_f1_score: 0.6295
# Epoch 51/75
# 395/395 [==============================] - 40s 101ms/step - loss: 0.6993 - accuracy: 0.7371 - precision: 0.8014 - recall: 0.6658 - auc: 0.9503 - f1_score: 0.7267 - val_loss: 1.0494 - val_accuracy: 0.6529 - val_precision: 0.7039 - val_recall: 0.6031 - val_auc: 0.9078 - val_f1_score: 0.6491
# Epoch 52/75
# 395/395 [==============================] - 40s 101ms/step - loss: 0.6830 - accuracy: 0.7444 - precision: 0.8041 - recall: 0.6737 - auc: 0.9525 - f1_score: 0.7327 - val_loss: 1.0641 - val_accuracy: 0.6417 - val_precision: 0.6932 - val_recall: 0.5884 - val_auc: 0.9027 - val_f1_score: 0.6363
# Epoch 53/75
# 395/395 [==============================] - 40s 102ms/step - loss: 0.6711 - accuracy: 0.7489 - precision: 0.8072 - recall: 0.6821 - auc: 0.9541 - f1_score: 0.7389 - val_loss: 1.1318 - val_accuracy: 0.6327 - val_precision: 0.6786 - val_recall: 0.5878 - val_auc: 0.8964 - val_f1_score: 0.6282
# Epoch 54/75
# 395/395 [==============================] - 40s 102ms/step - loss: 0.6598 - accuracy: 0.7530 - precision: 0.8109 - recall: 0.6876 - auc: 0.9555 - f1_score: 0.7437 - val_loss: 1.1322 - val_accuracy: 0.6342 - val_precision: 0.6805 - val_recall: 0.5911 - val_auc: 0.8975 - val_f1_score: 0.6327
# Epoch 55/75
# 395/395 [==============================] - 40s 101ms/step - loss: 0.6506 - accuracy: 0.7590 - precision: 0.8151 - recall: 0.6958 - auc: 0.9567 - f1_score: 0.7502 - val_loss: 1.1457 - val_accuracy: 0.6235 - val_precision: 0.6655 - val_recall: 0.5676 - val_auc: 0.8910 - val_f1_score: 0.6121
# Epoch 56/75
# 395/395 [==============================] - 40s 101ms/step - loss: 0.6380 - accuracy: 0.7622 - precision: 0.8154 - recall: 0.7022 - auc: 0.9584 - f1_score: 0.7541 - val_loss: 1.1169 - val_accuracy: 0.6428 - val_precision: 0.6842 - val_recall: 0.6000 - val_auc: 0.9008 - val_f1_score: 0.6384
# Epoch 57/75
# 395/395 [==============================] - 40s 101ms/step - loss: 0.6304 - accuracy: 0.7656 - precision: 0.8190 - recall: 0.7083 - auc: 0.9592 - f1_score: 0.7591 - val_loss: 1.1680 - val_accuracy: 0.6373 - val_precision: 0.6782 - val_recall: 0.5959 - val_auc: 0.8968 - val_f1_score: 0.6332
# Epoch 58/75
# 395/395 [==============================] - 40s 101ms/step - loss: 0.6183 - accuracy: 0.7698 - precision: 0.8201 - recall: 0.7143 - auc: 0.9608 - f1_score: 0.7630 - val_loss: 1.1145 - val_accuracy: 0.6338 - val_precision: 0.6809 - val_recall: 0.5940 - val_auc: 0.9011 - val_f1_score: 0.6340
# Epoch 59/75
# 395/395 [==============================] - 40s 102ms/step - loss: 0.6067 - accuracy: 0.7752 - precision: 0.8231 - recall: 0.7203 - auc: 0.9621 - f1_score: 0.7678 - val_loss: 1.1292 - val_accuracy: 0.6331 - val_precision: 0.6806 - val_recall: 0.5887 - val_auc: 0.8978 - val_f1_score: 0.6296
# Epoch 60/75
# 395/395 [==============================] - 40s 101ms/step - loss: 0.6023 - accuracy: 0.7778 - precision: 0.8277 - recall: 0.7231 - auc: 0.9627 - f1_score: 0.7715 - val_loss: 1.1663 - val_accuracy: 0.6430 - val_precision: 0.6818 - val_recall: 0.6051 - val_auc: 0.8983 - val_f1_score: 0.6408
# Epoch 61/75
# 395/395 [==============================] - 40s 102ms/step - loss: 0.5949 - accuracy: 0.7752 - precision: 0.8269 - recall: 0.7254 - auc: 0.9635 - f1_score: 0.7724 - val_loss: 1.1456 - val_accuracy: 0.6419 - val_precision: 0.6810 - val_recall: 0.6045 - val_auc: 0.9005 - val_f1_score: 0.6404
# Epoch 62/75
# 395/395 [==============================] - 40s 102ms/step - loss: 0.5722 - accuracy: 0.7874 - precision: 0.8345 - recall: 0.7385 - auc: 0.9661 - f1_score: 0.7832 - val_loss: 1.1442 - val_accuracy: 0.6423 - val_precision: 0.6798 - val_recall: 0.6045 - val_auc: 0.9010 - val_f1_score: 0.6385
# Epoch 63/75
# 395/395 [==============================] - 40s 102ms/step - loss: 0.5697 - accuracy: 0.7861 - precision: 0.8319 - recall: 0.7405 - auc: 0.9664 - f1_score: 0.7832 - val_loss: 1.1891 - val_accuracy: 0.6413 - val_precision: 0.6756 - val_recall: 0.6087 - val_auc: 0.8978 - val_f1_score: 0.6395
# Epoch 64/75
# 395/395 [==============================] - 40s 102ms/step - loss: 0.5652 - accuracy: 0.7926 - precision: 0.8348 - recall: 0.7457 - auc: 0.9669 - f1_score: 0.7874 - val_loss: 1.1646 - val_accuracy: 0.6421 - val_precision: 0.6747 - val_recall: 0.6061 - val_auc: 0.8990 - val_f1_score: 0.6384
# Epoch 65/75
# 395/395 [==============================] - 40s 102ms/step - loss: 0.5469 - accuracy: 0.7985 - precision: 0.8415 - recall: 0.7536 - auc: 0.9688 - f1_score: 0.7948 - val_loss: 1.3107 - val_accuracy: 0.6235 - val_precision: 0.6581 - val_recall: 0.5895 - val_auc: 0.8841 - val_f1_score: 0.6222
# Epoch 66/75
# 395/395 [==============================] - 40s 101ms/step - loss: 0.5376 - accuracy: 0.8005 - precision: 0.8439 - recall: 0.7582 - auc: 0.9699 - f1_score: 0.7983 - val_loss: 1.1667 - val_accuracy: 0.6441 - val_precision: 0.6781 - val_recall: 0.6144 - val_auc: 0.9014 - val_f1_score: 0.6443
# Epoch 67/75
# 395/395 [==============================] - 40s 101ms/step - loss: 0.5311 - accuracy: 0.8027 - precision: 0.8437 - recall: 0.7613 - auc: 0.9704 - f1_score: 0.8001 - val_loss: 1.1578 - val_accuracy: 0.6396 - val_precision: 0.6782 - val_recall: 0.6015 - val_auc: 0.8986 - val_f1_score: 0.6383
# Epoch 68/75
# 395/395 [==============================] - 40s 102ms/step - loss: 0.5235 - accuracy: 0.8063 - precision: 0.8471 - recall: 0.7653 - auc: 0.9715 - f1_score: 0.8039 - val_loss: 1.1731 - val_accuracy: 0.6410 - val_precision: 0.6820 - val_recall: 0.6056 - val_auc: 0.8967 - val_f1_score: 0.6419
# Epoch 69/75
# 395/395 [==============================] - 40s 101ms/step - loss: 0.5119 - accuracy: 0.8117 - precision: 0.8491 - recall: 0.7734 - auc: 0.9725 - f1_score: 0.8090 - val_loss: 1.2001 - val_accuracy: 0.6420 - val_precision: 0.6761 - val_recall: 0.6134 - val_auc: 0.8979 - val_f1_score: 0.6424
# Epoch 70/75
# 395/395 [==============================] - 40s 101ms/step - loss: 0.5062 - accuracy: 0.8146 - precision: 0.8518 - recall: 0.7757 - auc: 0.9732 - f1_score: 0.8116 - val_loss: 1.2587 - val_accuracy: 0.6344 - val_precision: 0.6669 - val_recall: 0.6039 - val_auc: 0.8898 - val_f1_score: 0.6337
# Epoch 71/75
# 395/395 [==============================] - 40s 102ms/step - loss: 0.4970 - accuracy: 0.8161 - precision: 0.8506 - recall: 0.7793 - auc: 0.9741 - f1_score: 0.8131 - val_loss: 1.2292 - val_accuracy: 0.6421 - val_precision: 0.6712 - val_recall: 0.6110 - val_auc: 0.8958 - val_f1_score: 0.6401
# Epoch 72/75
# 395/395 [==============================] - 40s 102ms/step - loss: 0.4844 - accuracy: 0.8215 - precision: 0.8571 - recall: 0.7861 - auc: 0.9752 - f1_score: 0.8198 - val_loss: 1.2873 - val_accuracy: 0.6440 - val_precision: 0.6742 - val_recall: 0.6155 - val_auc: 0.8932 - val_f1_score: 0.6441
# Epoch 73/75
# 395/395 [==============================] - 40s 101ms/step - loss: 0.4717 - accuracy: 0.8262 - precision: 0.8576 - recall: 0.7924 - auc: 0.9765 - f1_score: 0.8235 - val_loss: 1.3150 - val_accuracy: 0.6443 - val_precision: 0.6703 - val_recall: 0.6191 - val_auc: 0.8918 - val_f1_score: 0.6432
# Epoch 74/75
# 395/395 [==============================] - 40s 101ms/step - loss: 0.4676 - accuracy: 0.8247 - precision: 0.8572 - recall: 0.7944 - auc: 0.9769 - f1_score: 0.8244 - val_loss: 1.2144 - val_accuracy: 0.6419 - val_precision: 0.6738 - val_recall: 0.6106 - val_auc: 0.8980 - val_f1_score: 0.6415
# Epoch 75/75
# 395/395 [==============================] - 40s 101ms/step - loss: 0.4653 - accuracy: 0.8254 - precision: 0.8574 - recall: 0.7942 - auc: 0.9770 - f1_score: 0.8243 - val_loss: 1.3013 - val_accuracy: 0.6436 - val_precision: 0.6708 - val_recall: 0.6222 - val_auc: 0.8930 - val_f1_score: 0.6462

# %% [markdown]
# <h2>Saving the Model</h2>

# %%
# !mkdir /content/git5
# %cd /content/git5
# create the git folder
# !git init
# !git config --global user.email "samkht3327@gmail.com"
# !git config --global user.name "Ash3327"
# !git remote remove origin
# !git remote add origin "https://HEP-Dexan3327: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@github.com/HEP-Dexan3327/AI-Diary-1-Vanilla-CNN-"
# !git pull origin main
# Out:
# /content/git5
# Initialized empty Git repository in /content/git5/.git/
# fatal: No such remote: origin
# remote: Enumerating objects: 334, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 334 (delta 10), reused 23 (delta 7), pack-reused 304
# Receiving objects: 100% (334/334), 115.18 MiB | 38.36 MiB/s, done.
# Resolving deltas: 100% (158/158), done.
# From https://github.com/HEP-Dexan3327/AI-Diary-1-Vanilla-CNN-
#  * branch            main       -> FETCH_HEAD
#  * [new branch]      main       -> origin/main

# %%
# %cd models
# navigate to git/models
# Out:
# /content/git5/models

# %%
#Saving the visualization of model
visualfile = version+"_shape.png"
# !pip install visualkeras
import visualkeras
from tensorflow.keras.layers import BatchNormalization, ZeroPadding2D, Activation, MaxPool2D

# Visualizing our model architecture
visualkeras.layered_view(model, 
                         legend=True, 
                         to_file=visualfile,
                         type_ignore=[MaxPool2D,Activation,ZeroPadding2D,BatchNormalization,Dropout,Flatten])  # font is optional!
                         
# !git add $visualfile
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting visualkeras
#   Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.7/dist-packages (from visualkeras) (1.21.6)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from visualkeras) (7.1.2)
# Collecting aggdraw>=1.3.11
#   Downloading aggdraw-1.3.14-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (992 kB)
#      |████████████████████████████████| 992 kB 34.4 MB/s
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.14 visualkeras-0.0.2

# %%
#Saving the model
modelfile = version+'_model.h5'
model.save(modelfile)

# !git add $modelfile

# %%
errorrate = "0.6436"

# %%
# %cd /content/git5/_trials
mdfile = version+".md"
# navigate to git/_trials
nameline = "name: " + name
datetime = "datetime: " + version
errorate = "errorrate: " + errorrate
imagelin = "img: " + visualfile
datasetn = "dataset: " + dataset
# !echo --- > $mdfile
# !echo $nameline >> $mdfile
# !echo $datetime >> $mdfile
# !echo $errorate >> $mdfile
# !echo $imagelin >> $mdfile
# !echo $datasetn >> $mdfile
# !echo --- >> $mdfile

# !git add $mdfile
# Out:
# /content/git5/_trials

# %%
# pushing back to git repo
# %cd /content/git5
# !git commit -m $version
# Out:
# /content/git5
# [master b3d002f] 202206111316
#  3 files changed, 7 insertions(+)
#  create mode 100644 _trials/202206111316.md
#  create mode 100644 models/202206111316_model.h5
#  create mode 100644 models/202206111316_shape.png

# %%
# !pwd
# Out:
# /content/git5

# %%
# !git push -u origin master
# Out:
# Counting objects: 7, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (7/7), done.
# Writing objects: 100% (7/7), 16.39 MiB | 4.11 MiB/s, done.
# Total 7 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# remote: warning: See http://git.io/iEPt8g for more information.
# remote: warning: File models/202206111316_model.h5 is 69.12 MB; this is larger than GitHub's recommended maximum file size of 50.00 MB
# remote: warning: GH001: Large files detected. You may want to try Git Large File Storage - https://git-lfs.github.com.
# To https://github.com/HEP-Dexan3327/AI-Diary-1-Vanilla-CNN-
#    75b2ad6..b3d002f  master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.

# %%
def plt_acc_loss(model,num_epochs):
    acc = model.history['accuracy'] # new change for TF changes
    val_acc = model.history['val_accuracy'] # new change for TF changes

    loss = model.history['loss']
    val_loss = model.history['val_loss']

    epochs_range = range(num_epochs)

    plt.figure(figsize=(8, 8))
    plt.subplot(1, 2, 1)
    plt.ylim(0.3,1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.show()

# %%
import matplotlib.pyplot as plt
plt_acc_loss(model_info,75)

# %% [markdown]
# <h2>Loading the Model</h2>
# Loading the model named "model.h5". If you don't have enough time to train, just use the file I gave.
# The accuracy of my model is around 60% only. The accuracy can be slightly improved by training with 200 iterations.

# %%
#from keras.models import load_model
#emotion_model = load_model('model.h5',custom_objects={'f1_score':f1_score})

# %% [markdown]
# <h2>Confusion Matrix</h2>

# %%
# %cd /content
import tensorflow as tf
import numpy as np
from keras.models import model_from_json
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report,ConfusionMatrixDisplay


emotion_dict = {0: "Angry", 1: "Fear", 2: "Happy", 3: "Neutral", 4: "Sad", 5: "Surprised"}

# do prediction on test data


predictions = np.array([])
labels =  np.array([])

I = 0
for x, y in val_data:
  predictions = np.concatenate([predictions, np.argmax(model.predict(x),axis=-1)])
  labels = np.concatenate([labels, np.argmax(y,axis=-1)])
  I += 1
  if I > 200:
    break
ConfusionMatrixDisplay(
    confusion_matrix=tf.math.confusion_matrix(
        labels=labels, predictions=predictions)
    .numpy(), display_labels=emotion_dict).plot(cmap=plt.cm.Blues)
plt.show()
print(tf.math.confusion_matrix(labels=labels, predictions=predictions).numpy())
# Out:
# /content
# [[1049  168   54  176  231   52]
#  [ 281  728   57  200  416  175]
#  [ 119   80 2639  194   81  127]
#  [ 181   83  145 1415  357   48]
#  [ 306  162   90  440 1222   54]
#  [  67  110   48   34   27 1211]]

# %%
# Classification report
print("-----------------------------------------------------------------")
print(classification_report(labels, predictions))
# Out:
# -----------------------------------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.61      0.56      1730
#          1.0       0.55      0.39      0.46      1857
#          2.0       0.87      0.81      0.84      3240
#          3.0       0.58      0.63      0.60      2229
#          4.0       0.52      0.54      0.53      2274
#          5.0       0.73      0.81      0.77      1497
#
#     accuracy                           0.64     12827
#    macro avg       0.63      0.63      0.63     12827
# weighted avg       0.65      0.64      0.64     12827

# %% [markdown]
# <h1>Photo Emotion Analysis</h1>

# %%
def emotion_analysis(emotions):
    objects = ('Angry', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise')
    y_pos = np.arange(len(objects))
    
    plt.bar(y_pos, emotions, align='center', alpha=0.5)
    plt.xticks(y_pos, objects)
    plt.ylabel('percentage')
    plt.title('emotion')
    
    plt.show()

# %%
import cv2
            
def facecrop(image):  
    facedata = cv2.data.haarcascades + 'haarcascade_frontalface_alt.xml'
    cascade = cv2.CascadeClassifier(facedata)

    img = cv2.imread(image)

    try:
    
        minisize = (img.shape[1],img.shape[0])
        miniframe = cv2.resize(img, minisize)

        faces = cascade.detectMultiScale(miniframe)

        for f in faces:
            x, y, w, h = [ v for v in f ]
            cv2.rectangle(img, (x,y), (x+w,y+h), (0,255,0), 2)

            sub_face = img[y:y+h, x:x+w]

            
            cv2.imwrite('capture.jpg', sub_face)
            print ("Writing: " + image)

    except Exception as e:
        print (e)

   


if __name__ == '__main__':
    facecrop(root+"facialexpression/fear.jpg") ###############the file path here is your image

#Testing a file.

from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator

import numpy as np
import matplotlib.pyplot as plt


file = 'capture.jpg'
true_image = image.load_img(file)
img = image.load_img(file, color_mode="grayscale", target_size=(48, 48))

x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)

x /= 255

custom = model.predict(x)
emotion_analysis(custom[0])

x = np.array(x, 'float32')
x = x.reshape([48, 48])


plt.imshow(true_image)
plt.show()
# Out:
# Writing: /content/drive/MyDrive/Colab/facialexpression/fear.jpg
