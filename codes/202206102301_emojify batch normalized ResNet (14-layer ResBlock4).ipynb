# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
root = "/content/drive/MyDrive/Colab/"
version = "202206102301"
name = "ResNet batch normalized 14-layers _ 3 x ResBlock4"
dataset = "emojify"

# %%
# Import data source
from zipfile import ZipFile
file_name = root+"facialexpression/emojify.zip"

with ZipFile(file_name, 'r') as zip:
  zip.extractall()
  print("Done")
# Out:
# Done

# %%
import numpy as np
import cv2
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, BatchNormalization, MaxPooling2D, Add
from tensorflow.keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# <h2>Importing Data</h2>

# %%
from tensorflow import keras
# Model / data parameters
num_classes = 6
input_shape = (48, 48, 1)

train_dir = 'train'
val_dir = 'test'
train_datagen = ImageDataGenerator(
        rotation_range=30,## data augmentation, able to increase the accuracy of the training.
        zoom_range=0.2,
        rescale=1./255,
        fill_mode='nearest') # Split 0.2 of the train data to validation data
val_datagen = ImageDataGenerator(rescale=1./255)

train_data = train_datagen.flow_from_directory(
        train_dir,
        target_size=(48,48),
        batch_size=64,
        color_mode="grayscale",
        class_mode='categorical')

val_data = val_datagen.flow_from_directory(
        val_dir,
        target_size=(48,48),
        batch_size=64,
        color_mode="grayscale",
        class_mode='categorical')
# Out:
# Found 25269 images belonging to 6 classes.
# Found 7067 images belonging to 6 classes.

# %% [markdown]
# <h2>Defining the Model</h2>

# %%
class Residual(keras.layers.Layer):
  def __init__(self, downsample: bool, filters: int, kernel_size: int = 3):
    super(Residual, self).__init__()
    self.conv1 = Conv2D(filters=filters, kernel_size=kernel_size, activation="relu", padding="same", strides=(1 if not downsample else 2))
    self.bn1 = BatchNormalization()
    self.conv2 = Conv2D(filters=filters, kernel_size=kernel_size, activation="relu", padding="same")
    self.bn2 = BatchNormalization()
    self.conv3 = Conv2D(filters=filters, kernel_size=kernel_size, activation="relu", padding="same")
    self.bn3 = BatchNormalization()
    self.conv4 = Conv2D(filters=filters, kernel_size=kernel_size, activation="relu", padding="same")
    self.convx = Conv2D(kernel_size=1, strides=2, filters=filters, padding="same")
    self.downsample = downsample
    self.add = Add()
    self.bnO = BatchNormalization()

  def call(self, inputs):
    x = inputs
    y = self.bn1(self.conv1(x))
    y = self.bn2(self.conv2(y))
    y = self.bn3(self.conv3(y))
    y = self.conv4(y)
    if self.downsample:
      x = self.convx(x)
    out = self.add([x,y])
    out = self.bnO(out)
    return out

  def get_config(self):
    return {
        "downsample": self.downsample,
        "conv1": self.conv1,
        "bn1": self.bn1,
        "conv2": self.conv2,
        "bn2": self.bn2,
        "conv3": self.conv3,
        "bn3": self.bn3,
        "conv4": self.conv4,
        "convx": self.convx,
        "add": self.add,
        "bnO": self.bnO
    }

# %%
model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        BatchNormalization(),
        Conv2D(filters=32, kernel_size=3, activation="relu", padding="same"),
        BatchNormalization(),
        Residual(False, 32, 3),
        Residual(True, 64, 3),
        Residual(True, 128, 3),
        Flatten(),
        Dense(num_classes, activation="softmax"),
    ]
)

# %% [markdown]
# <h3>F1 Score: a method for evaluating the accuracy of a model</h3>
# The block below should be runned before loading the model.

# %%
import keras.backend as K
def f1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %% [markdown]
# <h3>Training the Model</h3>
# The accuracy of my model is around 60% only. The accuracy can be slightly improved by training with 200 iterations. Use Google Colab with a GPU to speed up the training to around 10~12s per epoch.
# Note that the accuracy of the model for random guessing is 16.67% (1/6); While the accuracy for a binary classification model for random guessing is 50% (1/2), so the accuracies of binary classification model and this kind of model cannot be compared directly.

# %%
model.compile(loss='categorical_crossentropy',optimizer=Adam(learning_rate=0.001, decay=1e-6),
      metrics=['accuracy',tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),f1_score])
model.build(input_shape)
batch_size = 128
model_info = model.fit(
        train_data, validation_data=val_data, batch_size=batch_size, epochs=50)
# Out:
# Epoch 1/50
# 395/395 [==============================] - 41s 68ms/step - loss: 3.0609 - accuracy: 0.2369 - precision: 0.2539 - recall: 0.1393 - auc: 0.5828 - f1_score: 0.1781 - val_loss: 2.2897 - val_accuracy: 0.2888 - val_precision: 0.3630 - val_recall: 0.1947 - val_auc: 0.6014 - val_f1_score: 0.2528
# Epoch 2/50
# 395/395 [==============================] - 23s 58ms/step - loss: 2.3385 - accuracy: 0.2771 - precision: 0.3083 - recall: 0.1655 - auc: 0.6299 - f1_score: 0.2143 - val_loss: 2.2959 - val_accuracy: 0.3236 - val_precision: 0.3694 - val_recall: 0.2570 - val_auc: 0.6646 - val_f1_score: 0.3028
# Epoch 3/50
# 395/395 [==============================] - 24s 60ms/step - loss: 1.8263 - accuracy: 0.3344 - precision: 0.4048 - recall: 0.1947 - auc: 0.6900 - f1_score: 0.2620 - val_loss: 1.5230 - val_accuracy: 0.4351 - val_precision: 0.5509 - val_recall: 0.2681 - val_auc: 0.7657 - val_f1_score: 0.3595
# Epoch 4/50
# 395/395 [==============================] - 25s 62ms/step - loss: 1.5270 - accuracy: 0.4096 - precision: 0.5397 - recall: 0.2312 - auc: 0.7589 - f1_score: 0.3224 - val_loss: 1.3711 - val_accuracy: 0.4793 - val_precision: 0.6298 - val_recall: 0.3269 - val_auc: 0.8073 - val_f1_score: 0.4295
# Epoch 5/50
# 395/395 [==============================] - 23s 58ms/step - loss: 1.3749 - accuracy: 0.4601 - precision: 0.6235 - recall: 0.2622 - auc: 0.8019 - f1_score: 0.3674 - val_loss: 1.2896 - val_accuracy: 0.4958 - val_precision: 0.6253 - val_recall: 0.3291 - val_auc: 0.8300 - val_f1_score: 0.4302
# Epoch 6/50
# 395/395 [==============================] - 24s 61ms/step - loss: 1.2983 - accuracy: 0.4860 - precision: 0.6595 - recall: 0.2838 - auc: 0.8235 - f1_score: 0.3951 - val_loss: 1.1754 - val_accuracy: 0.5386 - val_precision: 0.7323 - val_recall: 0.3414 - val_auc: 0.8570 - val_f1_score: 0.4637
# Epoch 7/50
# 395/395 [==============================] - 23s 58ms/step - loss: 1.2328 - accuracy: 0.5196 - precision: 0.6858 - recall: 0.3137 - auc: 0.8426 - f1_score: 0.4289 - val_loss: 1.1814 - val_accuracy: 0.5410 - val_precision: 0.6861 - val_recall: 0.3879 - val_auc: 0.8581 - val_f1_score: 0.4947
# Epoch 8/50
# 395/395 [==============================] - 23s 59ms/step - loss: 1.1911 - accuracy: 0.5366 - precision: 0.6932 - recall: 0.3376 - auc: 0.8537 - f1_score: 0.4526 - val_loss: 1.1985 - val_accuracy: 0.5493 - val_precision: 0.6928 - val_recall: 0.4034 - val_auc: 0.8547 - val_f1_score: 0.5094
# Epoch 9/50
# 395/395 [==============================] - 23s 59ms/step - loss: 1.1588 - accuracy: 0.5491 - precision: 0.7080 - recall: 0.3597 - auc: 0.8623 - f1_score: 0.4754 - val_loss: 1.1341 - val_accuracy: 0.5654 - val_precision: 0.6825 - val_recall: 0.4405 - val_auc: 0.8718 - val_f1_score: 0.5343
# Epoch 10/50
# 395/395 [==============================] - 23s 59ms/step - loss: 1.1310 - accuracy: 0.5619 - precision: 0.7104 - recall: 0.3762 - auc: 0.8692 - f1_score: 0.4901 - val_loss: 1.1799 - val_accuracy: 0.5674 - val_precision: 0.6778 - val_recall: 0.4235 - val_auc: 0.8618 - val_f1_score: 0.5200
# Epoch 11/50
# 395/395 [==============================] - 23s 59ms/step - loss: 1.1052 - accuracy: 0.5728 - precision: 0.7179 - recall: 0.3961 - auc: 0.8754 - f1_score: 0.5092 - val_loss: 1.0986 - val_accuracy: 0.5882 - val_precision: 0.7284 - val_recall: 0.4546 - val_auc: 0.8783 - val_f1_score: 0.5599
# Epoch 12/50
# 395/395 [==============================] - 23s 59ms/step - loss: 1.0830 - accuracy: 0.5851 - precision: 0.7211 - recall: 0.4131 - auc: 0.8809 - f1_score: 0.5237 - val_loss: 1.1054 - val_accuracy: 0.5879 - val_precision: 0.7124 - val_recall: 0.4617 - val_auc: 0.8781 - val_f1_score: 0.5594
# Epoch 13/50
# 395/395 [==============================] - 23s 59ms/step - loss: 1.0653 - accuracy: 0.5914 - precision: 0.7254 - recall: 0.4311 - auc: 0.8847 - f1_score: 0.5396 - val_loss: 1.1053 - val_accuracy: 0.5858 - val_precision: 0.7052 - val_recall: 0.4684 - val_auc: 0.8784 - val_f1_score: 0.5609
# Epoch 14/50
# 395/395 [==============================] - 23s 59ms/step - loss: 1.0419 - accuracy: 0.5986 - precision: 0.7275 - recall: 0.4417 - auc: 0.8899 - f1_score: 0.5483 - val_loss: 1.0800 - val_accuracy: 0.5940 - val_precision: 0.7008 - val_recall: 0.4803 - val_auc: 0.8841 - val_f1_score: 0.5696
# Epoch 15/50
# 395/395 [==============================] - 23s 59ms/step - loss: 1.0183 - accuracy: 0.6069 - precision: 0.7351 - recall: 0.4572 - auc: 0.8949 - f1_score: 0.5626 - val_loss: 1.0671 - val_accuracy: 0.6008 - val_precision: 0.7110 - val_recall: 0.4888 - val_auc: 0.8872 - val_f1_score: 0.5787
# Epoch 16/50
# 395/395 [==============================] - 24s 61ms/step - loss: 0.9937 - accuracy: 0.6232 - precision: 0.7406 - recall: 0.4783 - auc: 0.9002 - f1_score: 0.5800 - val_loss: 1.0580 - val_accuracy: 0.6053 - val_precision: 0.7086 - val_recall: 0.4903 - val_auc: 0.8898 - val_f1_score: 0.5791
# Epoch 17/50
# 395/395 [==============================] - 23s 59ms/step - loss: 0.9755 - accuracy: 0.6307 - precision: 0.7412 - recall: 0.4875 - auc: 0.9040 - f1_score: 0.5872 - val_loss: 1.1514 - val_accuracy: 0.5724 - val_precision: 0.6747 - val_recall: 0.4416 - val_auc: 0.8700 - val_f1_score: 0.5337
# Epoch 18/50
# 395/395 [==============================] - 23s 59ms/step - loss: 0.9573 - accuracy: 0.6326 - precision: 0.7452 - recall: 0.5024 - auc: 0.9074 - f1_score: 0.5990 - val_loss: 1.1151 - val_accuracy: 0.6003 - val_precision: 0.6896 - val_recall: 0.4992 - val_auc: 0.8833 - val_f1_score: 0.5775
# Epoch 19/50
# 395/395 [==============================] - 23s 59ms/step - loss: 0.9379 - accuracy: 0.6430 - precision: 0.7506 - recall: 0.5143 - auc: 0.9113 - f1_score: 0.6092 - val_loss: 1.0773 - val_accuracy: 0.6096 - val_precision: 0.6929 - val_recall: 0.5197 - val_auc: 0.8890 - val_f1_score: 0.5932
# Epoch 20/50
# 395/395 [==============================] - 23s 59ms/step - loss: 0.9167 - accuracy: 0.6525 - precision: 0.7540 - recall: 0.5279 - auc: 0.9153 - f1_score: 0.6201 - val_loss: 1.0530 - val_accuracy: 0.6202 - val_precision: 0.6956 - val_recall: 0.5391 - val_auc: 0.8965 - val_f1_score: 0.6074
# Epoch 21/50
# 395/395 [==============================] - 23s 59ms/step - loss: 0.9013 - accuracy: 0.6607 - precision: 0.7579 - recall: 0.5430 - auc: 0.9182 - f1_score: 0.6317 - val_loss: 1.0395 - val_accuracy: 0.6228 - val_precision: 0.7064 - val_recall: 0.5332 - val_auc: 0.8967 - val_f1_score: 0.6062
# Epoch 22/50
# 395/395 [==============================] - 23s 59ms/step - loss: 0.8861 - accuracy: 0.6614 - precision: 0.7567 - recall: 0.5480 - auc: 0.9208 - f1_score: 0.6347 - val_loss: 0.9951 - val_accuracy: 0.6286 - val_precision: 0.7278 - val_recall: 0.5267 - val_auc: 0.9021 - val_f1_score: 0.6099
# Epoch 23/50
# 395/395 [==============================] - 23s 58ms/step - loss: 0.8627 - accuracy: 0.6733 - precision: 0.7646 - recall: 0.5630 - auc: 0.9249 - f1_score: 0.6478 - val_loss: 1.0619 - val_accuracy: 0.6254 - val_precision: 0.6986 - val_recall: 0.5483 - val_auc: 0.8967 - val_f1_score: 0.6136
# Epoch 24/50
# 395/395 [==============================] - 23s 59ms/step - loss: 0.8403 - accuracy: 0.6842 - precision: 0.7708 - recall: 0.5796 - auc: 0.9288 - f1_score: 0.6608 - val_loss: 1.0652 - val_accuracy: 0.6182 - val_precision: 0.6863 - val_recall: 0.5478 - val_auc: 0.8962 - val_f1_score: 0.6083
# Epoch 25/50
# 395/395 [==============================] - 23s 59ms/step - loss: 0.8279 - accuracy: 0.6897 - precision: 0.7724 - recall: 0.5878 - auc: 0.9309 - f1_score: 0.6668 - val_loss: 1.1093 - val_accuracy: 0.6089 - val_precision: 0.6776 - val_recall: 0.5386 - val_auc: 0.8897 - val_f1_score: 0.6000
# Epoch 26/50
# 395/395 [==============================] - 23s 58ms/step - loss: 0.8024 - accuracy: 0.6989 - precision: 0.7808 - recall: 0.6048 - auc: 0.9351 - f1_score: 0.6808 - val_loss: 1.1591 - val_accuracy: 0.6117 - val_precision: 0.6658 - val_recall: 0.5475 - val_auc: 0.8852 - val_f1_score: 0.6005
# Epoch 27/50
# 395/395 [==============================] - 23s 59ms/step - loss: 0.7853 - accuracy: 0.7060 - precision: 0.7812 - recall: 0.6153 - auc: 0.9377 - f1_score: 0.6875 - val_loss: 1.1036 - val_accuracy: 0.6140 - val_precision: 0.6885 - val_recall: 0.5466 - val_auc: 0.8912 - val_f1_score: 0.6093
# Epoch 28/50
# 395/395 [==============================] - 23s 59ms/step - loss: 0.7725 - accuracy: 0.7127 - precision: 0.7868 - recall: 0.6283 - auc: 0.9397 - f1_score: 0.6980 - val_loss: 1.1029 - val_accuracy: 0.6293 - val_precision: 0.6884 - val_recall: 0.5741 - val_auc: 0.8973 - val_f1_score: 0.6261
# Epoch 29/50
# 395/395 [==============================] - 24s 61ms/step - loss: 0.7529 - accuracy: 0.7167 - precision: 0.7897 - recall: 0.6347 - auc: 0.9426 - f1_score: 0.7033 - val_loss: 1.1083 - val_accuracy: 0.6263 - val_precision: 0.6882 - val_recall: 0.5728 - val_auc: 0.8967 - val_f1_score: 0.6258
# Epoch 30/50
# 395/395 [==============================] - 23s 58ms/step - loss: 0.7379 - accuracy: 0.7241 - precision: 0.7961 - recall: 0.6466 - auc: 0.9448 - f1_score: 0.7131 - val_loss: 1.1028 - val_accuracy: 0.6297 - val_precision: 0.6868 - val_recall: 0.5738 - val_auc: 0.8969 - val_f1_score: 0.6244
# Epoch 31/50
# 395/395 [==============================] - 23s 58ms/step - loss: 0.7162 - accuracy: 0.7279 - precision: 0.7955 - recall: 0.6527 - auc: 0.9479 - f1_score: 0.7165 - val_loss: 1.1034 - val_accuracy: 0.6324 - val_precision: 0.6834 - val_recall: 0.5797 - val_auc: 0.8979 - val_f1_score: 0.6268
# Epoch 32/50
# 395/395 [==============================] - 23s 59ms/step - loss: 0.7022 - accuracy: 0.7392 - precision: 0.8039 - recall: 0.6664 - auc: 0.9500 - f1_score: 0.7281 - val_loss: 1.1163 - val_accuracy: 0.6310 - val_precision: 0.6835 - val_recall: 0.5785 - val_auc: 0.8969 - val_f1_score: 0.6260
# Epoch 33/50
# 395/395 [==============================] - 23s 58ms/step - loss: 0.6829 - accuracy: 0.7455 - precision: 0.8093 - recall: 0.6784 - auc: 0.9525 - f1_score: 0.7376 - val_loss: 1.0898 - val_accuracy: 0.6369 - val_precision: 0.6960 - val_recall: 0.5796 - val_auc: 0.8982 - val_f1_score: 0.6320
# Epoch 34/50
# 395/395 [==============================] - 23s 58ms/step - loss: 0.6671 - accuracy: 0.7531 - precision: 0.8099 - recall: 0.6865 - auc: 0.9545 - f1_score: 0.7426 - val_loss: 1.1179 - val_accuracy: 0.6353 - val_precision: 0.6873 - val_recall: 0.5888 - val_auc: 0.9000 - val_f1_score: 0.6332
# Epoch 35/50
# 395/395 [==============================] - 23s 58ms/step - loss: 0.6560 - accuracy: 0.7581 - precision: 0.8137 - recall: 0.6980 - auc: 0.9561 - f1_score: 0.7509 - val_loss: 1.2212 - val_accuracy: 0.6192 - val_precision: 0.6642 - val_recall: 0.5763 - val_auc: 0.8875 - val_f1_score: 0.6171
# Epoch 36/50
# 395/395 [==============================] - 23s 58ms/step - loss: 0.6414 - accuracy: 0.7602 - precision: 0.8147 - recall: 0.7014 - auc: 0.9580 - f1_score: 0.7534 - val_loss: 1.1620 - val_accuracy: 0.6352 - val_precision: 0.6827 - val_recall: 0.5997 - val_auc: 0.8976 - val_f1_score: 0.6389
# Epoch 37/50
# 395/395 [==============================] - 23s 59ms/step - loss: 0.6163 - accuracy: 0.7715 - precision: 0.8220 - recall: 0.7162 - auc: 0.9608 - f1_score: 0.7649 - val_loss: 1.1751 - val_accuracy: 0.6380 - val_precision: 0.6787 - val_recall: 0.6003 - val_auc: 0.8977 - val_f1_score: 0.6369
# Epoch 38/50
# 395/395 [==============================] - 23s 59ms/step - loss: 0.6080 - accuracy: 0.7753 - precision: 0.8256 - recall: 0.7198 - auc: 0.9619 - f1_score: 0.7686 - val_loss: 1.2012 - val_accuracy: 0.6358 - val_precision: 0.6792 - val_recall: 0.5994 - val_auc: 0.8948 - val_f1_score: 0.6368
# Epoch 39/50
# 395/395 [==============================] - 23s 58ms/step - loss: 0.5926 - accuracy: 0.7817 - precision: 0.8266 - recall: 0.7299 - auc: 0.9638 - f1_score: 0.7749 - val_loss: 1.2490 - val_accuracy: 0.6281 - val_precision: 0.6667 - val_recall: 0.5930 - val_auc: 0.8919 - val_f1_score: 0.6274
# Epoch 40/50
# 395/395 [==============================] - 23s 59ms/step - loss: 0.5860 - accuracy: 0.7846 - precision: 0.8306 - recall: 0.7351 - auc: 0.9646 - f1_score: 0.7795 - val_loss: 1.2835 - val_accuracy: 0.6177 - val_precision: 0.6537 - val_recall: 0.5795 - val_auc: 0.8845 - val_f1_score: 0.6140
# Epoch 41/50
# 395/395 [==============================] - 23s 59ms/step - loss: 0.5627 - accuracy: 0.7955 - precision: 0.8386 - recall: 0.7487 - auc: 0.9672 - f1_score: 0.7908 - val_loss: 1.3029 - val_accuracy: 0.6295 - val_precision: 0.6683 - val_recall: 0.5995 - val_auc: 0.8881 - val_f1_score: 0.6308
# Epoch 42/50
# 395/395 [==============================] - 23s 58ms/step - loss: 0.5608 - accuracy: 0.7926 - precision: 0.8365 - recall: 0.7488 - auc: 0.9674 - f1_score: 0.7899 - val_loss: 1.2202 - val_accuracy: 0.6399 - val_precision: 0.6822 - val_recall: 0.6018 - val_auc: 0.8933 - val_f1_score: 0.6398
# Epoch 43/50
# 395/395 [==============================] - 23s 59ms/step - loss: 0.5464 - accuracy: 0.7986 - precision: 0.8397 - recall: 0.7536 - auc: 0.9689 - f1_score: 0.7939 - val_loss: 1.3295 - val_accuracy: 0.6291 - val_precision: 0.6616 - val_recall: 0.5967 - val_auc: 0.8878 - val_f1_score: 0.6269
# Epoch 44/50
# 395/395 [==============================] - 23s 58ms/step - loss: 0.5471 - accuracy: 0.7981 - precision: 0.8374 - recall: 0.7555 - auc: 0.9688 - f1_score: 0.7941 - val_loss: 1.3160 - val_accuracy: 0.6235 - val_precision: 0.6580 - val_recall: 0.5884 - val_auc: 0.8869 - val_f1_score: 0.6206
# Epoch 45/50
# 395/395 [==============================] - 23s 58ms/step - loss: 0.5186 - accuracy: 0.8081 - precision: 0.8492 - recall: 0.7672 - auc: 0.9719 - f1_score: 0.8057 - val_loss: 1.2715 - val_accuracy: 0.6315 - val_precision: 0.6665 - val_recall: 0.6034 - val_auc: 0.8925 - val_f1_score: 0.6325
# Epoch 46/50
# 395/395 [==============================] - 23s 59ms/step - loss: 0.5150 - accuracy: 0.8133 - precision: 0.8507 - recall: 0.7710 - auc: 0.9720 - f1_score: 0.8085 - val_loss: 1.2248 - val_accuracy: 0.6403 - val_precision: 0.6793 - val_recall: 0.6073 - val_auc: 0.8956 - val_f1_score: 0.6414
# Epoch 47/50
# 395/395 [==============================] - 23s 59ms/step - loss: 0.5089 - accuracy: 0.8149 - precision: 0.8502 - recall: 0.7759 - auc: 0.9727 - f1_score: 0.8111 - val_loss: 1.3463 - val_accuracy: 0.6370 - val_precision: 0.6643 - val_recall: 0.6117 - val_auc: 0.8903 - val_f1_score: 0.6360
# Epoch 48/50
# 395/395 [==============================] - 23s 59ms/step - loss: 0.4971 - accuracy: 0.8186 - precision: 0.8544 - recall: 0.7827 - auc: 0.9738 - f1_score: 0.8167 - val_loss: 1.3289 - val_accuracy: 0.6291 - val_precision: 0.6675 - val_recall: 0.6027 - val_auc: 0.8878 - val_f1_score: 0.6328
# Epoch 49/50
# 395/395 [==============================] - 23s 59ms/step - loss: 0.4864 - accuracy: 0.8237 - precision: 0.8569 - recall: 0.7864 - auc: 0.9750 - f1_score: 0.8199 - val_loss: 1.3067 - val_accuracy: 0.6312 - val_precision: 0.6642 - val_recall: 0.6014 - val_auc: 0.8916 - val_f1_score: 0.6309
# Epoch 50/50
# 395/395 [==============================] - 23s 59ms/step - loss: 0.4809 - accuracy: 0.8260 - precision: 0.8597 - recall: 0.7926 - auc: 0.9752 - f1_score: 0.8245 - val_loss: 1.3458 - val_accuracy: 0.6235 - val_precision: 0.6582 - val_recall: 0.5993 - val_auc: 0.8834 - val_f1_score: 0.6273

# %% [markdown]
# <h2>Saving the Model</h2>

# %%
# !mkdir /content/git5
# %cd /content/git5
# create the git folder
# !git init
# !git config --global user.email "samkht3327@gmail.com"
# !git config --global user.name "Ash3327"
# !git remote remove origin
# !git remote add origin "https://HEP-Dexan3327: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@github.com/HEP-Dexan3327/AI-Diary-1-Vanilla-CNN-"
# !git pull origin main
# Out:
# /content/git5
# Initialized empty Git repository in /content/git5/.git/
# fatal: No such remote: origin
# remote: Enumerating objects: 291, done.
# remote: Counting objects: 100% (88/88), done.
# remote: Compressing objects: 100% (79/79), done.
# remote: Total 291 (delta 41), reused 23 (delta 9), pack-reused 203
# Receiving objects: 100% (291/291), 72.75 MiB | 37.42 MiB/s, done.
# Resolving deltas: 100% (131/131), done.
# From https://github.com/HEP-Dexan3327/AI-Diary-1-Vanilla-CNN-
#  * branch            main       -> FETCH_HEAD
#  * [new branch]      main       -> origin/main

# %%
# %cd models
# navigate to git/models
# Out:
# /content/git5/models

# %%
#Saving the visualization of model
visualfile = version+"_shape.png"
# !pip install visualkeras
import visualkeras
from tensorflow.keras.layers import BatchNormalization, ZeroPadding2D, Activation, MaxPool2D

# Visualizing our model architecture
visualkeras.layered_view(model, 
                         legend=True, 
                         to_file=visualfile,
                         type_ignore=[MaxPool2D,Activation,ZeroPadding2D,BatchNormalization,Dropout,Flatten])  # font is optional!
                         
# !git add $visualfile
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting visualkeras
#   Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.7/dist-packages (from visualkeras) (1.21.6)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from visualkeras) (7.1.2)
# Collecting aggdraw>=1.3.11
#   Downloading aggdraw-1.3.14-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (992 kB)
#      |████████████████████████████████| 992 kB 5.2 MB/s
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.14 visualkeras-0.0.2

# %%
#Saving the model
modelfile = version+'_model.h5'
model.save(modelfile)

# !git add $modelfile

# %%
errorrate = "0.6235"

# %%
# %cd /content/git5/_trials
mdfile = version+".md"
# navigate to git/_trials
nameline = "name: " + name
datetime = "datetime: " + version
errorate = "errorrate: " + errorrate
imagelin = "img: " + visualfile
datasetn = "dataset: " + dataset
# !echo --- > $mdfile
# !echo $nameline >> $mdfile
# !echo $datetime >> $mdfile
# !echo $errorate >> $mdfile
# !echo $imagelin >> $mdfile
# !echo $datasetn >> $mdfile
# !echo --- >> $mdfile

# !git add $mdfile
# Out:
# /content/git5/_trials

# %%
# pushing back to git repo
# %cd /content/git5
# !git commit -m $version
# Out:
# /content/git5
# [master 41af61f] 202206102301
#  3 files changed, 7 insertions(+)
#  create mode 100644 _trials/202206102301.md
#  create mode 100644 models/202206102301_model.h5
#  create mode 100644 models/202206102301_shape.png

# %%
# !pwd
# Out:
# /content/git5

# %%
# !git push -u origin master
# Out:
# Counting objects: 7, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (7/7), done.
# Writing objects: 100% (7/7), 8.50 MiB | 5.72 MiB/s, done.
# Total 7 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/HEP-Dexan3327/AI-Diary-1-Vanilla-CNN-
#    b660725..41af61f  master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.

# %%
def plt_acc_loss(model,num_epochs):
    acc = model.history['accuracy'] # new change for TF changes
    val_acc = model.history['val_accuracy'] # new change for TF changes

    loss = model.history['loss']
    val_loss = model.history['val_loss']

    epochs_range = range(num_epochs)

    plt.figure(figsize=(8, 8))
    plt.subplot(1, 2, 1)
    plt.ylim(0.3,1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.show()

# %%
import matplotlib.pyplot as plt
plt_acc_loss(model_info,50)

# %% [markdown]
# <h2>Loading the Model</h2>
# Loading the model named "model.h5". If you don't have enough time to train, just use the file I gave.
# The accuracy of my model is around 60% only. The accuracy can be slightly improved by training with 200 iterations.

# %%
#from keras.models import load_model
#emotion_model = load_model('model.h5',custom_objects={'f1_score':f1_score})

# %% [markdown]
# <h2>Confusion Matrix</h2>

# %%
# %cd /content
import tensorflow as tf
import numpy as np
from keras.models import model_from_json
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report,ConfusionMatrixDisplay


emotion_dict = {0: "Angry", 1: "Fear", 2: "Happy", 3: "Neutral", 4: "Sad", 5: "Surprised"}

# do prediction on test data


predictions = np.array([])
labels =  np.array([])

I = 0
for x, y in val_data:
  predictions = np.concatenate([predictions, np.argmax(model.predict(x),axis=-1)])
  labels = np.concatenate([labels, np.argmax(y,axis=-1)])
  I += 1
  if I > 200:
    break
ConfusionMatrixDisplay(
    confusion_matrix=tf.math.confusion_matrix(
        labels=labels, predictions=predictions)
    .numpy(), display_labels=emotion_dict).plot(cmap=plt.cm.Blues)
plt.show()
print(tf.math.confusion_matrix(labels=labels, predictions=predictions).numpy())
# Out:
# /content
# [[1097  190   18  205  234   13]
#  [ 233  875   26  255  355  108]
#  [ 208  138 2305  332  144   92]
#  [ 189  121   66 1439  364   38]
#  [ 279  260   51  487 1138   43]
#  [  67  138   30   70   37 1145]]

# %%
# Classification report
print("-----------------------------------------------------------------")
print(classification_report(labels, predictions))
# Out:
# -----------------------------------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.62      0.57      1757
#          1.0       0.51      0.47      0.49      1852
#          2.0       0.92      0.72      0.81      3219
#          3.0       0.52      0.65      0.58      2217
#          4.0       0.50      0.50      0.50      2258
#          5.0       0.80      0.77      0.78      1487
#
#     accuracy                           0.63     12790
#    macro avg       0.63      0.62      0.62     12790
# weighted avg       0.65      0.63      0.63     12790

# %% [markdown]
# <h1>Photo Emotion Analysis</h1>

# %%
def emotion_analysis(emotions):
    objects = ('Angry', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise')
    y_pos = np.arange(len(objects))
    
    plt.bar(y_pos, emotions, align='center', alpha=0.5)
    plt.xticks(y_pos, objects)
    plt.ylabel('percentage')
    plt.title('emotion')
    
    plt.show()

# %%
import cv2
            
def facecrop(image):  
    facedata = cv2.data.haarcascades + 'haarcascade_frontalface_alt.xml'
    cascade = cv2.CascadeClassifier(facedata)

    img = cv2.imread(image)

    try:
    
        minisize = (img.shape[1],img.shape[0])
        miniframe = cv2.resize(img, minisize)

        faces = cascade.detectMultiScale(miniframe)

        for f in faces:
            x, y, w, h = [ v for v in f ]
            cv2.rectangle(img, (x,y), (x+w,y+h), (0,255,0), 2)

            sub_face = img[y:y+h, x:x+w]

            
            cv2.imwrite('capture.jpg', sub_face)
            print ("Writing: " + image)

    except Exception as e:
        print (e)

   


if __name__ == '__main__':
    facecrop(root+"facialexpression/fear.jpg") ###############the file path here is your image

#Testing a file.

from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator

import numpy as np
import matplotlib.pyplot as plt


file = 'capture.jpg'
true_image = image.load_img(file)
img = image.load_img(file, color_mode="grayscale", target_size=(48, 48))

x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)

x /= 255

custom = model.predict(x)
emotion_analysis(custom[0])

x = np.array(x, 'float32')
x = x.reshape([48, 48])


plt.imshow(true_image)
plt.show()
# Out:
# Writing: /content/drive/MyDrive/Colab/facialexpression/fear.jpg
