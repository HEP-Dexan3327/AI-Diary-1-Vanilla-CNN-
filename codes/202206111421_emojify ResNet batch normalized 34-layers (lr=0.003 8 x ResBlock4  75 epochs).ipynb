# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
root = "/content/drive/MyDrive/Colab/"
version = "202206111421"
name = "ResNet batch normalized 34-layers _ lr=0.003 8 x ResBlock4 _ 75 epochs"
dataset = "emojify"

# %%
# Import data source
from zipfile import ZipFile
file_name = root+"facialexpression/emojify.zip"

with ZipFile(file_name, 'r') as zip:
  zip.extractall()
  print("Done")
# Out:
# Done

# %%
import numpy as np
import cv2
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, BatchNormalization, MaxPooling2D, Add
from tensorflow.keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# <h2>Importing Data</h2>

# %%
from tensorflow import keras
# Model / data parameters
num_classes = 6
input_shape = (48, 48, 1)

train_dir = 'train'
val_dir = 'test'
train_datagen = ImageDataGenerator(
        rotation_range=30,## data augmentation, able to increase the accuracy of the training.
        zoom_range=0.2,
        rescale=1./255,
        fill_mode='nearest') # Split 0.2 of the train data to validation data
val_datagen = ImageDataGenerator(rescale=1./255)

train_data = train_datagen.flow_from_directory(
        train_dir,
        target_size=(48,48),
        batch_size=64,
        color_mode="grayscale",
        class_mode='categorical')

val_data = val_datagen.flow_from_directory(
        val_dir,
        target_size=(48,48),
        batch_size=64,
        color_mode="grayscale",
        class_mode='categorical')
# Out:
# Found 25269 images belonging to 6 classes.
# Found 7067 images belonging to 6 classes.

# %% [markdown]
# <h2>Defining the Model</h2>

# %%
from keras import initializers
def conv(filter: int, kernel_size: int, zero: bool, stride: int) -> Conv2D:
  if zero:
    return Conv2D(filters=filter, kernel_size=kernel_size, activation="relu", padding="same", strides=stride, kernel_initializer=initializers.Zeros())
  else:
    return Conv2D(filters=filter, kernel_size=kernel_size, activation="relu", padding="same", strides=stride)
class Residual(keras.layers.Layer):
  def __init__(self, downsample: bool, filters: int, zero: bool, kernel_size: int = 3):
    super(Residual, self).__init__()
    self.conv1 = conv(filters, kernel_size, zero, (1 if not downsample else 2))
    self.bn1 = BatchNormalization()
    self.conv2 = conv(filters, kernel_size, zero, 1)
    self.bn2 = BatchNormalization()
    self.conv3 = conv(filters, kernel_size, zero, 1)
    self.bn3 = BatchNormalization()
    self.conv4 = conv(filters, kernel_size, zero, 1)
    self.convx = Conv2D(kernel_size=1, strides=2, filters=filters, padding="same")
    self.downsample = downsample
    self.add = Add()
    self.bnO = BatchNormalization()

  def call(self, inputs):
    x = inputs
    y = self.bn1(self.conv1(x))
    y = self.bn2(self.conv2(y))
    y = self.bn3(self.conv3(y))
    y = self.conv4(y)
    if self.downsample:
      x = self.convx(x)
    out = self.add([x,y])
    out = self.bnO(out)
    return out

  def get_config(self):
    return {
        "downsample": self.downsample,
        "conv1": self.conv1,
        "bn1": self.bn1,
        "conv2": self.conv2,
        "bn2": self.bn2,
        "conv3": self.conv3,
        "bn3": self.bn3,
        "conv4": self.conv4,
        "convx": self.convx,
        "add": self.add,
        "bnO": self.bnO
    }

# %%
B1 = BatchNormalization()
C = Conv2D(filters=32, kernel_size=3, activation="relu", padding="same")
B2 = BatchNormalization()
R11 = Residual(False, 32, False, 3)
R12 = Residual(False, 32, False, 3)
R21 = Residual(True, 64, False, 3)
R22 = Residual(False, 64, False, 3)
R31 = Residual(True, 128, False, 3)
R32 = Residual(False, 128, False, 3)
R41 = Residual(True, 256, True, 3)
R42 = Residual(False, 256, True, 3)
F = Flatten()
D = Dense(num_classes, activation="softmax")

model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        B1,C,B2,
        R11,R12,
        R21,R22,
        R31,R32,
        R41,R42,
        F,
        D,
    ]
)

# %% [markdown]
# <h3>F1 Score: a method for evaluating the accuracy of a model</h3>
# The block below should be runned before loading the model.

# %%
import keras.backend as K
def f1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %% [markdown]
# <h3>Training the Model</h3>
# The accuracy of my model is around 60% only. The accuracy can be slightly improved by training with 200 iterations. Use Google Colab with a GPU to speed up the training to around 10~12s per epoch.
# Note that the accuracy of the model for random guessing is 16.67% (1/6); While the accuracy for a binary classification model for random guessing is 50% (1/2), so the accuracies of binary classification model and this kind of model cannot be compared directly.

# %%
model.compile(loss='categorical_crossentropy',optimizer=Adam(learning_rate=0.003, decay=1e-6),
      metrics=['accuracy',tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),f1_score])
batch_size = 128
model_info = model.fit(
        train_data, validation_data=val_data, batch_size=batch_size, epochs=75)
# Out:
# Epoch 1/75
# 395/395 [==============================] - 57s 102ms/step - loss: 3.3906 - accuracy: 0.1965 - precision: 0.1898 - recall: 0.0355 - auc: 0.5398 - f1_score: 0.0501 - val_loss: 2.0270 - val_accuracy: 0.1765 - val_precision: 0.1813 - val_recall: 0.0044 - val_auc: 0.5223 - val_f1_score: 0.0084
# Epoch 2/75
# 395/395 [==============================] - 40s 101ms/step - loss: 1.9831 - accuracy: 0.2135 - precision: 0.2046 - recall: 0.0046 - auc: 0.5814 - f1_score: 0.0089 - val_loss: 1.7296 - val_accuracy: 0.2440 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6225 - val_f1_score: 0.0000e+00
# Epoch 3/75
# 395/395 [==============================] - 43s 109ms/step - loss: 1.7630 - accuracy: 0.2413 - precision: 0.2258 - recall: 0.0028 - auc: 0.6054 - f1_score: 0.0054 - val_loss: 1.7731 - val_accuracy: 0.2608 - val_precision: 0.1250 - val_recall: 8.4902e-04 - val_auc: 0.6182 - val_f1_score: 0.0020
# Epoch 4/75
# 395/395 [==============================] - 45s 113ms/step - loss: 1.7248 - accuracy: 0.2543 - precision: 0.4039 - recall: 0.0049 - auc: 0.6243 - f1_score: 0.0095 - val_loss: 1.7231 - val_accuracy: 0.2414 - val_precision: 0.4884 - val_recall: 0.0030 - val_auc: 0.6251 - val_f1_score: 0.0058
# Epoch 5/75
# 395/395 [==============================] - 41s 105ms/step - loss: 1.6914 - accuracy: 0.2831 - precision: 0.5582 - recall: 0.0184 - auc: 0.6482 - f1_score: 0.0351 - val_loss: 1.6311 - val_accuracy: 0.3405 - val_precision: 0.6995 - val_recall: 0.0191 - val_auc: 0.6931 - val_f1_score: 0.0373
# Epoch 6/75
# 395/395 [==============================] - 41s 104ms/step - loss: 1.6541 - accuracy: 0.3105 - precision: 0.6135 - recall: 0.0332 - auc: 0.6716 - f1_score: 0.0617 - val_loss: 1.5689 - val_accuracy: 0.3628 - val_precision: 0.7040 - val_recall: 0.0996 - val_auc: 0.7151 - val_f1_score: 0.1732
# Epoch 7/75
# 395/395 [==============================] - 42s 105ms/step - loss: 1.6192 - accuracy: 0.3279 - precision: 0.6048 - recall: 0.0504 - auc: 0.6923 - f1_score: 0.0919 - val_loss: 1.5317 - val_accuracy: 0.3903 - val_precision: 0.7209 - val_recall: 0.1078 - val_auc: 0.7360 - val_f1_score: 0.1860
# Epoch 8/75
# 395/395 [==============================] - 41s 104ms/step - loss: 1.5887 - accuracy: 0.3424 - precision: 0.6424 - recall: 0.0670 - auc: 0.7077 - f1_score: 0.1199 - val_loss: 1.6458 - val_accuracy: 0.3334 - val_precision: 0.5485 - val_recall: 0.1128 - val_auc: 0.6847 - val_f1_score: 0.1858
# Epoch 9/75
# 395/395 [==============================] - 42s 106ms/step - loss: 1.5520 - accuracy: 0.3642 - precision: 0.6684 - recall: 0.0858 - auc: 0.7250 - f1_score: 0.1503 - val_loss: 1.4976 - val_accuracy: 0.4007 - val_precision: 0.6684 - val_recall: 0.1603 - val_auc: 0.7495 - val_f1_score: 0.2565
# Epoch 10/75
# 395/395 [==============================] - 41s 105ms/step - loss: 1.5086 - accuracy: 0.3826 - precision: 0.6790 - recall: 0.1079 - auc: 0.7439 - f1_score: 0.1843 - val_loss: 1.4364 - val_accuracy: 0.4241 - val_precision: 0.6750 - val_recall: 0.2066 - val_auc: 0.7747 - val_f1_score: 0.3147
# Epoch 11/75
# 395/395 [==============================] - 41s 104ms/step - loss: 1.4634 - accuracy: 0.4058 - precision: 0.6937 - recall: 0.1352 - auc: 0.7634 - f1_score: 0.2241 - val_loss: 1.8266 - val_accuracy: 0.4340 - val_precision: 0.6280 - val_recall: 0.1933 - val_auc: 0.7621 - val_f1_score: 0.2940
# Epoch 12/75
# 395/395 [==============================] - 41s 104ms/step - loss: 1.4068 - accuracy: 0.4335 - precision: 0.6889 - recall: 0.1675 - auc: 0.7853 - f1_score: 0.2675 - val_loss: 1.5692 - val_accuracy: 0.3938 - val_precision: 0.5667 - val_recall: 0.1958 - val_auc: 0.7438 - val_f1_score: 0.2887
# Epoch 13/75
# 395/395 [==============================] - 41s 104ms/step - loss: 1.3599 - accuracy: 0.4549 - precision: 0.6907 - recall: 0.1932 - auc: 0.8022 - f1_score: 0.2997 - val_loss: 1.2836 - val_accuracy: 0.4946 - val_precision: 0.6528 - val_recall: 0.3298 - val_auc: 0.8305 - val_f1_score: 0.4350
# Epoch 14/75
# 395/395 [==============================] - 41s 105ms/step - loss: 1.3152 - accuracy: 0.4749 - precision: 0.6952 - recall: 0.2274 - auc: 0.8169 - f1_score: 0.3411 - val_loss: 1.3803 - val_accuracy: 0.5006 - val_precision: 0.6219 - val_recall: 0.3775 - val_auc: 0.8260 - val_f1_score: 0.4690
# Epoch 15/75
# 395/395 [==============================] - 41s 104ms/step - loss: 1.2840 - accuracy: 0.4912 - precision: 0.6953 - recall: 0.2509 - auc: 0.8265 - f1_score: 0.3670 - val_loss: 1.2784 - val_accuracy: 0.5179 - val_precision: 0.6998 - val_recall: 0.3487 - val_auc: 0.8368 - val_f1_score: 0.4634
# Epoch 16/75
# 395/395 [==============================] - 41s 104ms/step - loss: 1.2593 - accuracy: 0.5023 - precision: 0.6986 - recall: 0.2668 - auc: 0.8343 - f1_score: 0.3841 - val_loss: 1.1913 - val_accuracy: 0.5452 - val_precision: 0.6776 - val_recall: 0.3990 - val_auc: 0.8576 - val_f1_score: 0.5022
# Epoch 17/75
# 395/395 [==============================] - 41s 104ms/step - loss: 1.2281 - accuracy: 0.5154 - precision: 0.7014 - recall: 0.2961 - auc: 0.8430 - f1_score: 0.4148 - val_loss: 1.1785 - val_accuracy: 0.5534 - val_precision: 0.7138 - val_recall: 0.3932 - val_auc: 0.8583 - val_f1_score: 0.5063
# Epoch 18/75
# 395/395 [==============================] - 42s 105ms/step - loss: 1.2122 - accuracy: 0.5236 - precision: 0.7006 - recall: 0.3094 - auc: 0.8475 - f1_score: 0.4274 - val_loss: 1.2023 - val_accuracy: 0.5379 - val_precision: 0.6763 - val_recall: 0.3823 - val_auc: 0.8528 - val_f1_score: 0.4860
# Epoch 19/75
# 395/395 [==============================] - 41s 104ms/step - loss: 1.1766 - accuracy: 0.5390 - precision: 0.7080 - recall: 0.3376 - auc: 0.8573 - f1_score: 0.4554 - val_loss: 1.2511 - val_accuracy: 0.5299 - val_precision: 0.6748 - val_recall: 0.3794 - val_auc: 0.8464 - val_f1_score: 0.4849
# Epoch 20/75
# 395/395 [==============================] - 41s 104ms/step - loss: 1.1631 - accuracy: 0.5384 - precision: 0.7056 - recall: 0.3498 - auc: 0.8606 - f1_score: 0.4659 - val_loss: 1.1026 - val_accuracy: 0.5727 - val_precision: 0.7390 - val_recall: 0.4142 - val_auc: 0.8758 - val_f1_score: 0.5293
# Epoch 21/75
# 395/395 [==============================] - 41s 105ms/step - loss: 1.1419 - accuracy: 0.5544 - precision: 0.7080 - recall: 0.3678 - auc: 0.8662 - f1_score: 0.4826 - val_loss: 1.2340 - val_accuracy: 0.5305 - val_precision: 0.6462 - val_recall: 0.4176 - val_auc: 0.8523 - val_f1_score: 0.5064
# Epoch 22/75
# 395/395 [==============================] - 44s 110ms/step - loss: 1.1361 - accuracy: 0.5525 - precision: 0.7056 - recall: 0.3725 - auc: 0.8676 - f1_score: 0.4859 - val_loss: 1.1363 - val_accuracy: 0.5847 - val_precision: 0.6969 - val_recall: 0.4580 - val_auc: 0.8761 - val_f1_score: 0.5525
# Epoch 23/75
# 395/395 [==============================] - 41s 105ms/step - loss: 1.1106 - accuracy: 0.5688 - precision: 0.7107 - recall: 0.3904 - auc: 0.8740 - f1_score: 0.5024 - val_loss: 1.2365 - val_accuracy: 0.5229 - val_precision: 0.6366 - val_recall: 0.3920 - val_auc: 0.8498 - val_f1_score: 0.4832
# Epoch 24/75
# 395/395 [==============================] - 42s 105ms/step - loss: 1.0937 - accuracy: 0.5726 - precision: 0.7117 - recall: 0.4014 - auc: 0.8778 - f1_score: 0.5117 - val_loss: 1.1584 - val_accuracy: 0.5578 - val_precision: 0.6879 - val_recall: 0.4361 - val_auc: 0.8667 - val_f1_score: 0.5323
# Epoch 25/75
# 395/395 [==============================] - 41s 104ms/step - loss: 1.0729 - accuracy: 0.5853 - precision: 0.7202 - recall: 0.4173 - auc: 0.8828 - f1_score: 0.5271 - val_loss: 1.0855 - val_accuracy: 0.5943 - val_precision: 0.7012 - val_recall: 0.4725 - val_auc: 0.8844 - val_f1_score: 0.5639
# Epoch 26/75
# 395/395 [==============================] - 41s 105ms/step - loss: 1.0680 - accuracy: 0.5847 - precision: 0.7205 - recall: 0.4189 - auc: 0.8837 - f1_score: 0.5283 - val_loss: 1.1512 - val_accuracy: 0.5613 - val_precision: 0.6702 - val_recall: 0.4288 - val_auc: 0.8677 - val_f1_score: 0.5220
# Epoch 27/75
# 395/395 [==============================] - 41s 104ms/step - loss: 1.0604 - accuracy: 0.5891 - precision: 0.7202 - recall: 0.4277 - auc: 0.8858 - f1_score: 0.5352 - val_loss: 1.2455 - val_accuracy: 0.5446 - val_precision: 0.6406 - val_recall: 0.4306 - val_auc: 0.8538 - val_f1_score: 0.5137
# Epoch 28/75
# 395/395 [==============================] - 41s 104ms/step - loss: 1.0441 - accuracy: 0.5931 - precision: 0.7220 - recall: 0.4403 - auc: 0.8893 - f1_score: 0.5461 - val_loss: 1.0446 - val_accuracy: 0.6062 - val_precision: 0.6977 - val_recall: 0.4957 - val_auc: 0.8918 - val_f1_score: 0.5793
# Epoch 29/75
# 395/395 [==============================] - 41s 105ms/step - loss: 1.0338 - accuracy: 0.5999 - precision: 0.7224 - recall: 0.4470 - auc: 0.8915 - f1_score: 0.5511 - val_loss: 1.0505 - val_accuracy: 0.6056 - val_precision: 0.7128 - val_recall: 0.4858 - val_auc: 0.8909 - val_f1_score: 0.5769
# Epoch 30/75
# 395/395 [==============================] - 41s 104ms/step - loss: 1.0183 - accuracy: 0.6052 - precision: 0.7273 - recall: 0.4611 - auc: 0.8949 - f1_score: 0.5635 - val_loss: 1.0425 - val_accuracy: 0.6024 - val_precision: 0.7218 - val_recall: 0.4722 - val_auc: 0.8908 - val_f1_score: 0.5694
# Epoch 31/75
# 395/395 [==============================] - 42s 105ms/step - loss: 1.0131 - accuracy: 0.6113 - precision: 0.7334 - recall: 0.4652 - auc: 0.8958 - f1_score: 0.5680 - val_loss: 1.0484 - val_accuracy: 0.6031 - val_precision: 0.7124 - val_recall: 0.4914 - val_auc: 0.8919 - val_f1_score: 0.5816
# Epoch 32/75
# 395/395 [==============================] - 41s 104ms/step - loss: 1.0046 - accuracy: 0.6135 - precision: 0.7312 - recall: 0.4673 - auc: 0.8980 - f1_score: 0.5692 - val_loss: 1.0502 - val_accuracy: 0.5997 - val_precision: 0.7009 - val_recall: 0.5043 - val_auc: 0.8925 - val_f1_score: 0.5860
# Epoch 33/75
# 395/395 [==============================] - 41s 104ms/step - loss: 0.9869 - accuracy: 0.6198 - precision: 0.7353 - recall: 0.4815 - auc: 0.9014 - f1_score: 0.5808 - val_loss: 1.0637 - val_accuracy: 0.6022 - val_precision: 0.7131 - val_recall: 0.4950 - val_auc: 0.8888 - val_f1_score: 0.5840
# Epoch 34/75
# 395/395 [==============================] - 41s 104ms/step - loss: 0.9739 - accuracy: 0.6234 - precision: 0.7366 - recall: 0.4869 - auc: 0.9041 - f1_score: 0.5851 - val_loss: 1.0977 - val_accuracy: 0.5995 - val_precision: 0.6938 - val_recall: 0.4953 - val_auc: 0.8847 - val_f1_score: 0.5771
# Epoch 35/75
# 395/395 [==============================] - 42s 105ms/step - loss: 0.9667 - accuracy: 0.6266 - precision: 0.7417 - recall: 0.4948 - auc: 0.9056 - f1_score: 0.5923 - val_loss: 1.0018 - val_accuracy: 0.6335 - val_precision: 0.7172 - val_recall: 0.5486 - val_auc: 0.9042 - val_f1_score: 0.6205
# Epoch 36/75
# 395/395 [==============================] - 41s 104ms/step - loss: 0.9513 - accuracy: 0.6353 - precision: 0.7396 - recall: 0.5054 - auc: 0.9086 - f1_score: 0.5993 - val_loss: 0.9986 - val_accuracy: 0.6293 - val_precision: 0.7307 - val_recall: 0.5279 - val_auc: 0.9027 - val_f1_score: 0.6119
# Epoch 37/75
# 395/395 [==============================] - 41s 104ms/step - loss: 0.9495 - accuracy: 0.6359 - precision: 0.7419 - recall: 0.5089 - auc: 0.9089 - f1_score: 0.6028 - val_loss: 1.0249 - val_accuracy: 0.6133 - val_precision: 0.7167 - val_recall: 0.5108 - val_auc: 0.8975 - val_f1_score: 0.5956
# Epoch 38/75
# 395/395 [==============================] - 41s 104ms/step - loss: 0.9379 - accuracy: 0.6410 - precision: 0.7421 - recall: 0.5135 - auc: 0.9112 - f1_score: 0.6060 - val_loss: 1.0115 - val_accuracy: 0.6266 - val_precision: 0.7212 - val_recall: 0.5325 - val_auc: 0.9010 - val_f1_score: 0.6122
# Epoch 39/75
# 395/395 [==============================] - 41s 104ms/step - loss: 0.9259 - accuracy: 0.6456 - precision: 0.7495 - recall: 0.5234 - auc: 0.9134 - f1_score: 0.6154 - val_loss: 1.0966 - val_accuracy: 0.6004 - val_precision: 0.6819 - val_recall: 0.5073 - val_auc: 0.8857 - val_f1_score: 0.5819
# Epoch 40/75
# 395/395 [==============================] - 41s 105ms/step - loss: 0.9126 - accuracy: 0.6494 - precision: 0.7465 - recall: 0.5292 - auc: 0.9159 - f1_score: 0.6181 - val_loss: 1.0484 - val_accuracy: 0.6167 - val_precision: 0.6983 - val_recall: 0.5287 - val_auc: 0.8951 - val_f1_score: 0.6001
# Epoch 41/75
# 395/395 [==============================] - 41s 104ms/step - loss: 0.8982 - accuracy: 0.6585 - precision: 0.7570 - recall: 0.5437 - auc: 0.9186 - f1_score: 0.6318 - val_loss: 1.0837 - val_accuracy: 0.5984 - val_precision: 0.6833 - val_recall: 0.4930 - val_auc: 0.8857 - val_f1_score: 0.5720
# Epoch 42/75
# 395/395 [==============================] - 41s 104ms/step - loss: 0.8906 - accuracy: 0.6607 - precision: 0.7566 - recall: 0.5505 - auc: 0.9200 - f1_score: 0.6363 - val_loss: 1.0231 - val_accuracy: 0.6329 - val_precision: 0.7093 - val_recall: 0.5489 - val_auc: 0.8999 - val_f1_score: 0.6180
# Epoch 43/75
# 395/395 [==============================] - 41s 104ms/step - loss: 0.8773 - accuracy: 0.6641 - precision: 0.7577 - recall: 0.5566 - auc: 0.9223 - f1_score: 0.6409 - val_loss: 1.0403 - val_accuracy: 0.6247 - val_precision: 0.6922 - val_recall: 0.5545 - val_auc: 0.8998 - val_f1_score: 0.6158
# Epoch 44/75
# 395/395 [==============================] - 42s 105ms/step - loss: 0.8617 - accuracy: 0.6734 - precision: 0.7648 - recall: 0.5653 - auc: 0.9251 - f1_score: 0.6494 - val_loss: 1.0905 - val_accuracy: 0.6259 - val_precision: 0.6924 - val_recall: 0.5602 - val_auc: 0.8970 - val_f1_score: 0.6182
# Epoch 45/75
# 395/395 [==============================] - 41s 104ms/step - loss: 0.8542 - accuracy: 0.6732 - precision: 0.7632 - recall: 0.5739 - auc: 0.9265 - f1_score: 0.6543 - val_loss: 0.9911 - val_accuracy: 0.6379 - val_precision: 0.7272 - val_recall: 0.5398 - val_auc: 0.9035 - val_f1_score: 0.6187
# Epoch 46/75
# 395/395 [==============================] - 41s 104ms/step - loss: 0.8482 - accuracy: 0.6754 - precision: 0.7624 - recall: 0.5740 - auc: 0.9274 - f1_score: 0.6542 - val_loss: 1.0716 - val_accuracy: 0.6264 - val_precision: 0.6933 - val_recall: 0.5670 - val_auc: 0.8976 - val_f1_score: 0.6237
# Epoch 47/75
# 395/395 [==============================] - 41s 104ms/step - loss: 0.8285 - accuracy: 0.6857 - precision: 0.7698 - recall: 0.5886 - auc: 0.9308 - f1_score: 0.6663 - val_loss: 1.0540 - val_accuracy: 0.6179 - val_precision: 0.7110 - val_recall: 0.5292 - val_auc: 0.8941 - val_f1_score: 0.6058
# Epoch 48/75
# 395/395 [==============================] - 41s 105ms/step - loss: 0.8210 - accuracy: 0.6894 - precision: 0.7715 - recall: 0.5958 - auc: 0.9319 - f1_score: 0.6717 - val_loss: 1.0239 - val_accuracy: 0.6379 - val_precision: 0.7015 - val_recall: 0.5742 - val_auc: 0.9064 - val_f1_score: 0.6311
# Epoch 49/75
# 395/395 [==============================] - 41s 104ms/step - loss: 0.8109 - accuracy: 0.6934 - precision: 0.7750 - recall: 0.6004 - auc: 0.9336 - f1_score: 0.6759 - val_loss: 1.0725 - val_accuracy: 0.6247 - val_precision: 0.7014 - val_recall: 0.5502 - val_auc: 0.8944 - val_f1_score: 0.6158
# Epoch 50/75
# 395/395 [==============================] - 41s 104ms/step - loss: 0.8036 - accuracy: 0.6965 - precision: 0.7749 - recall: 0.6043 - auc: 0.9347 - f1_score: 0.6782 - val_loss: 1.0557 - val_accuracy: 0.6263 - val_precision: 0.6902 - val_recall: 0.5594 - val_auc: 0.8988 - val_f1_score: 0.6177
# Epoch 51/75
# 395/395 [==============================] - 41s 104ms/step - loss: 0.7892 - accuracy: 0.6973 - precision: 0.7751 - recall: 0.6098 - auc: 0.9370 - f1_score: 0.6818 - val_loss: 1.1101 - val_accuracy: 0.6131 - val_precision: 0.6758 - val_recall: 0.5417 - val_auc: 0.8892 - val_f1_score: 0.6000
# Epoch 52/75
# 395/395 [==============================] - 41s 104ms/step - loss: 0.7769 - accuracy: 0.7067 - precision: 0.7837 - recall: 0.6185 - auc: 0.9390 - f1_score: 0.6906 - val_loss: 1.0403 - val_accuracy: 0.6274 - val_precision: 0.6944 - val_recall: 0.5575 - val_auc: 0.9018 - val_f1_score: 0.6182
# Epoch 53/75
# 395/395 [==============================] - 41s 105ms/step - loss: 0.7629 - accuracy: 0.7106 - precision: 0.7839 - recall: 0.6276 - auc: 0.9411 - f1_score: 0.6964 - val_loss: 1.0579 - val_accuracy: 0.6278 - val_precision: 0.6929 - val_recall: 0.5676 - val_auc: 0.8986 - val_f1_score: 0.6233
# Epoch 54/75
# 395/395 [==============================] - 41s 104ms/step - loss: 0.7565 - accuracy: 0.7169 - precision: 0.7868 - recall: 0.6341 - auc: 0.9420 - f1_score: 0.7016 - val_loss: 1.0528 - val_accuracy: 0.6339 - val_precision: 0.6923 - val_recall: 0.5775 - val_auc: 0.9009 - val_f1_score: 0.6287
# Epoch 55/75
# 395/395 [==============================] - 41s 104ms/step - loss: 0.7505 - accuracy: 0.7176 - precision: 0.7873 - recall: 0.6383 - auc: 0.9429 - f1_score: 0.7044 - val_loss: 1.0596 - val_accuracy: 0.6334 - val_precision: 0.6976 - val_recall: 0.5772 - val_auc: 0.9019 - val_f1_score: 0.6314
# Epoch 56/75
# 395/395 [==============================] - 41s 104ms/step - loss: 0.7380 - accuracy: 0.7211 - precision: 0.7893 - recall: 0.6442 - auc: 0.9448 - f1_score: 0.7089 - val_loss: 1.0049 - val_accuracy: 0.6467 - val_precision: 0.7111 - val_recall: 0.5712 - val_auc: 0.9058 - val_f1_score: 0.6327
# Epoch 57/75
# 395/395 [==============================] - 41s 104ms/step - loss: 0.7313 - accuracy: 0.7227 - precision: 0.7925 - recall: 0.6510 - auc: 0.9459 - f1_score: 0.7142 - val_loss: 1.1410 - val_accuracy: 0.6245 - val_precision: 0.6733 - val_recall: 0.5725 - val_auc: 0.8930 - val_f1_score: 0.6191
# Epoch 58/75
# 395/395 [==============================] - 41s 105ms/step - loss: 0.7159 - accuracy: 0.7315 - precision: 0.7964 - recall: 0.6606 - auc: 0.9479 - f1_score: 0.7217 - val_loss: 1.0449 - val_accuracy: 0.6464 - val_precision: 0.7032 - val_recall: 0.5888 - val_auc: 0.9046 - val_f1_score: 0.6401
# Epoch 59/75
# 395/395 [==============================] - 41s 105ms/step - loss: 0.7071 - accuracy: 0.7351 - precision: 0.8003 - recall: 0.6648 - auc: 0.9493 - f1_score: 0.7257 - val_loss: 1.1600 - val_accuracy: 0.6052 - val_precision: 0.6657 - val_recall: 0.5404 - val_auc: 0.8847 - val_f1_score: 0.5965
# Epoch 60/75
# 395/395 [==============================] - 41s 105ms/step - loss: 0.6993 - accuracy: 0.7364 - precision: 0.7997 - recall: 0.6684 - auc: 0.9503 - f1_score: 0.7277 - val_loss: 1.0845 - val_accuracy: 0.6322 - val_precision: 0.6843 - val_recall: 0.5793 - val_auc: 0.9005 - val_f1_score: 0.6274
# Epoch 61/75
# 395/395 [==============================] - 41s 104ms/step - loss: 0.6803 - accuracy: 0.7441 - precision: 0.8040 - recall: 0.6781 - auc: 0.9529 - f1_score: 0.7351 - val_loss: 1.1000 - val_accuracy: 0.6365 - val_precision: 0.6843 - val_recall: 0.5902 - val_auc: 0.9002 - val_f1_score: 0.6338
# Epoch 62/75
# 395/395 [==============================] - 42s 105ms/step - loss: 0.6769 - accuracy: 0.7473 - precision: 0.8090 - recall: 0.6831 - auc: 0.9532 - f1_score: 0.7403 - val_loss: 1.0549 - val_accuracy: 0.6373 - val_precision: 0.6934 - val_recall: 0.5868 - val_auc: 0.9056 - val_f1_score: 0.6345
# Epoch 63/75
# 395/395 [==============================] - 41s 105ms/step - loss: 0.6646 - accuracy: 0.7491 - precision: 0.8078 - recall: 0.6880 - auc: 0.9550 - f1_score: 0.7426 - val_loss: 1.0903 - val_accuracy: 0.6410 - val_precision: 0.6872 - val_recall: 0.5884 - val_auc: 0.9002 - val_f1_score: 0.6328
# Epoch 64/75
# 395/395 [==============================] - 41s 105ms/step - loss: 0.6611 - accuracy: 0.7525 - precision: 0.8072 - recall: 0.6911 - auc: 0.9554 - f1_score: 0.7441 - val_loss: 1.2026 - val_accuracy: 0.5973 - val_precision: 0.6521 - val_recall: 0.5442 - val_auc: 0.8819 - val_f1_score: 0.5924
# Epoch 65/75
# 395/395 [==============================] - 41s 105ms/step - loss: 0.6453 - accuracy: 0.7595 - precision: 0.8146 - recall: 0.6998 - auc: 0.9574 - f1_score: 0.7523 - val_loss: 1.1380 - val_accuracy: 0.6402 - val_precision: 0.6834 - val_recall: 0.5967 - val_auc: 0.9010 - val_f1_score: 0.6367
# Epoch 66/75
# 395/395 [==============================] - 41s 105ms/step - loss: 0.6362 - accuracy: 0.7626 - precision: 0.8189 - recall: 0.7038 - auc: 0.9586 - f1_score: 0.7566 - val_loss: 1.1437 - val_accuracy: 0.6321 - val_precision: 0.6729 - val_recall: 0.5903 - val_auc: 0.8972 - val_f1_score: 0.6286
# Epoch 67/75
# 395/395 [==============================] - 42s 105ms/step - loss: 0.6257 - accuracy: 0.7690 - precision: 0.8226 - recall: 0.7137 - auc: 0.9599 - f1_score: 0.7637 - val_loss: 1.1547 - val_accuracy: 0.6383 - val_precision: 0.6782 - val_recall: 0.5957 - val_auc: 0.8983 - val_f1_score: 0.6337
# Epoch 68/75
# 395/395 [==============================] - 41s 105ms/step - loss: 0.6238 - accuracy: 0.7685 - precision: 0.8221 - recall: 0.7112 - auc: 0.9600 - f1_score: 0.7621 - val_loss: 1.1308 - val_accuracy: 0.6261 - val_precision: 0.6784 - val_recall: 0.5763 - val_auc: 0.8958 - val_f1_score: 0.6229
# Epoch 69/75
# 395/395 [==============================] - 41s 105ms/step - loss: 0.6188 - accuracy: 0.7714 - precision: 0.8188 - recall: 0.7160 - auc: 0.9607 - f1_score: 0.7635 - val_loss: 1.1364 - val_accuracy: 0.6349 - val_precision: 0.6773 - val_recall: 0.5855 - val_auc: 0.8973 - val_f1_score: 0.6278
# Epoch 70/75
# 395/395 [==============================] - 41s 105ms/step - loss: 0.6032 - accuracy: 0.7751 - precision: 0.8260 - recall: 0.7248 - auc: 0.9625 - f1_score: 0.7717 - val_loss: 1.2122 - val_accuracy: 0.6372 - val_precision: 0.6723 - val_recall: 0.6046 - val_auc: 0.8953 - val_f1_score: 0.6361
# Epoch 71/75
# 395/395 [==============================] - 41s 104ms/step - loss: 0.5997 - accuracy: 0.7762 - precision: 0.8249 - recall: 0.7250 - auc: 0.9630 - f1_score: 0.7713 - val_loss: 1.1794 - val_accuracy: 0.6372 - val_precision: 0.6749 - val_recall: 0.6021 - val_auc: 0.8955 - val_f1_score: 0.6367
# Epoch 72/75
# 395/395 [==============================] - 41s 105ms/step - loss: 0.5906 - accuracy: 0.7795 - precision: 0.8262 - recall: 0.7299 - auc: 0.9640 - f1_score: 0.7747 - val_loss: 1.1845 - val_accuracy: 0.6208 - val_precision: 0.6702 - val_recall: 0.5762 - val_auc: 0.8926 - val_f1_score: 0.6193
# Epoch 73/75
# 395/395 [==============================] - 41s 105ms/step - loss: 0.5710 - accuracy: 0.7874 - precision: 0.8328 - recall: 0.7392 - auc: 0.9662 - f1_score: 0.7828 - val_loss: 1.1578 - val_accuracy: 0.6359 - val_precision: 0.6779 - val_recall: 0.5986 - val_auc: 0.8989 - val_f1_score: 0.6356
# Epoch 74/75
# 395/395 [==============================] - 41s 105ms/step - loss: 0.5673 - accuracy: 0.7874 - precision: 0.8328 - recall: 0.7423 - auc: 0.9667 - f1_score: 0.7845 - val_loss: 1.1723 - val_accuracy: 0.6380 - val_precision: 0.6777 - val_recall: 0.6003 - val_auc: 0.8980 - val_f1_score: 0.6358
# Epoch 75/75
# 395/395 [==============================] - 41s 105ms/step - loss: 0.5685 - accuracy: 0.7892 - precision: 0.8328 - recall: 0.7429 - auc: 0.9665 - f1_score: 0.7849 - val_loss: 1.1729 - val_accuracy: 0.6304 - val_precision: 0.6799 - val_recall: 0.5860 - val_auc: 0.8954 - val_f1_score: 0.6288

# %% [markdown]
# <h2>Saving the Model</h2>

# %%
# !mkdir /content/git5
# %cd /content/git5
# create the git folder
# !git init
# !git config --global user.email "samkht3327@gmail.com"
# !git config --global user.name "Ash3327"
# !git remote remove origin
# !git remote add origin "https://HEP-Dexan3327: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@github.com/HEP-Dexan3327/AI-Diary-1-Vanilla-CNN-"
# !git pull origin main
# Out:
# /content/git5
# Initialized empty Git repository in /content/git5/.git/
# fatal: No such remote: origin
# remote: Enumerating objects: 347, done.
# remote: Total 347 (delta 0), reused 0 (delta 0), pack-reused 347
# Receiving objects: 100% (347/347), 131.54 MiB | 33.99 MiB/s, done.
# Resolving deltas: 100% (170/170), done.
# From https://github.com/HEP-Dexan3327/AI-Diary-1-Vanilla-CNN-
#  * branch            main       -> FETCH_HEAD
#  * [new branch]      main       -> origin/main

# %%
# %cd models
# navigate to git/models
# Out:
# /content/git5/models

# %%
#Saving the visualization of model
visualfile = version+"_shape.png"
# !pip install visualkeras
import visualkeras
from tensorflow.keras.layers import BatchNormalization, ZeroPadding2D, Activation, MaxPool2D

# Visualizing our model architecture
visualkeras.layered_view(model, 
                         legend=True, 
                         to_file=visualfile,
                         type_ignore=[MaxPool2D,Activation,ZeroPadding2D,BatchNormalization,Dropout,Flatten])  # font is optional!
                         
# !git add $visualfile
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting visualkeras
#   Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from visualkeras) (7.1.2)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.7/dist-packages (from visualkeras) (1.21.6)
# Collecting aggdraw>=1.3.11
#   Downloading aggdraw-1.3.14-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (992 kB)
#      |████████████████████████████████| 992 kB 5.2 MB/s
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.14 visualkeras-0.0.2

# %%
#Saving the model
modelfile = version+'_model.h5'
model.save(modelfile)

# !git add $modelfile

# %%
errorrate = "0.6304"

# %%
# %cd /content/git5/_trials
mdfile = version+".md"
# navigate to git/_trials
nameline = "name: " + name
datetime = "datetime: " + version
errorate = "errorrate: " + errorrate
imagelin = "img: " + visualfile
datasetn = "dataset: " + dataset
# !echo --- > $mdfile
# !echo $nameline >> $mdfile
# !echo $datetime >> $mdfile
# !echo $errorate >> $mdfile
# !echo $imagelin >> $mdfile
# !echo $datasetn >> $mdfile
# !echo --- >> $mdfile

# !git add $mdfile
# Out:
# /content/git5/_trials

# %%
# pushing back to git repo
# %cd /content/git5
# !git commit -m $version
# Out:
# /content/git5
# [master a09d2f2] 202206111421
#  2 files changed, 7 insertions(+)
#  create mode 100644 _trials/202206111421.md

# %%
# !pwd
# Out:
# /content/git5

# %%
# !git push -u origin master
# Out:
# Counting objects: 6, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (6/6), 16.80 MiB | 6.10 MiB/s, done.
# Total 6 (delta 4), reused 0 (delta 0)
# remote: Resolving deltas: 100% (4/4), completed with 4 local objects.
# remote: warning: See http://git.io/iEPt8g for more information.
# remote: warning: File models/202206111316_model.h5 is 69.12 MB; this is larger than GitHub's recommended maximum file size of 50.00 MB
# remote: warning: GH001: Large files detected. You may want to try Git Large File Storage - https://git-lfs.github.com.
# To https://github.com/HEP-Dexan3327/AI-Diary-1-Vanilla-CNN-
#    fdf2d6d..a09d2f2  master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.

# %%
def plt_acc_loss(model,num_epochs):
    acc = model.history['accuracy'] # new change for TF changes
    val_acc = model.history['val_accuracy'] # new change for TF changes

    loss = model.history['loss']
    val_loss = model.history['val_loss']

    epochs_range = range(num_epochs)

    plt.figure(figsize=(8, 8))
    plt.subplot(1, 2, 1)
    plt.ylim(0.3,1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.show()

# %%
import matplotlib.pyplot as plt
plt_acc_loss(model_info,75)

# %% [markdown]
# <h2>Loading the Model</h2>
# Loading the model named "model.h5". If you don't have enough time to train, just use the file I gave.
# The accuracy of my model is around 60% only. The accuracy can be slightly improved by training with 200 iterations.

# %%
#from keras.models import load_model
#emotion_model = load_model('model.h5',custom_objects={'f1_score':f1_score})

# %% [markdown]
# <h2>Confusion Matrix</h2>

# %%
# %cd /content
import tensorflow as tf
import numpy as np
from keras.models import model_from_json
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report,ConfusionMatrixDisplay


emotion_dict = {0: "Angry", 1: "Fear", 2: "Happy", 3: "Neutral", 4: "Sad", 5: "Surprised"}

# do prediction on test data


predictions = np.array([])
labels =  np.array([])

I = 0
for x, y in val_data:
  predictions = np.concatenate([predictions, np.argmax(model.predict(x),axis=-1)])
  labels = np.concatenate([labels, np.argmax(y,axis=-1)])
  I += 1
  if I > 200:
    break
ConfusionMatrixDisplay(
    confusion_matrix=tf.math.confusion_matrix(
        labels=labels, predictions=predictions)
    .numpy(), display_labels=emotion_dict).plot(cmap=plt.cm.Blues)
plt.show()
print(tf.math.confusion_matrix(labels=labels, predictions=predictions).numpy())
# Out:
# /content
# [[1088  145   29  146  278   40]
#  [ 320  703   36  183  436  176]
#  [ 185  110 2507  157  119  132]
#  [ 244  130  144 1266  434   49]
#  [ 334  179   59  371 1275   38]
#  [  76  115   34   29   19 1241]]

# %%
# Classification report
print("-----------------------------------------------------------------")
print(classification_report(labels, predictions))
# Out:
# -----------------------------------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.63      0.55      1726
#          1.0       0.51      0.38      0.43      1854
#          2.0       0.89      0.78      0.83      3210
#          3.0       0.59      0.56      0.57      2267
#          4.0       0.50      0.57      0.53      2256
#          5.0       0.74      0.82      0.78      1514
#
#     accuracy                           0.63     12827
#    macro avg       0.62      0.62      0.62     12827
# weighted avg       0.64      0.63      0.63     12827

# %% [markdown]
# <h1>Photo Emotion Analysis</h1>

# %%
def emotion_analysis(emotions):
    objects = ('Angry', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise')
    y_pos = np.arange(len(objects))
    
    plt.bar(y_pos, emotions, align='center', alpha=0.5)
    plt.xticks(y_pos, objects)
    plt.ylabel('percentage')
    plt.title('emotion')
    
    plt.show()

# %%
import cv2
            
def facecrop(image):  
    facedata = cv2.data.haarcascades + 'haarcascade_frontalface_alt.xml'
    cascade = cv2.CascadeClassifier(facedata)

    img = cv2.imread(image)

    try:
    
        minisize = (img.shape[1],img.shape[0])
        miniframe = cv2.resize(img, minisize)

        faces = cascade.detectMultiScale(miniframe)

        for f in faces:
            x, y, w, h = [ v for v in f ]
            cv2.rectangle(img, (x,y), (x+w,y+h), (0,255,0), 2)

            sub_face = img[y:y+h, x:x+w]

            
            cv2.imwrite('capture.jpg', sub_face)
            print ("Writing: " + image)

    except Exception as e:
        print (e)

   


if __name__ == '__main__':
    facecrop(root+"facialexpression/fear.jpg") ###############the file path here is your image

#Testing a file.

from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator

import numpy as np
import matplotlib.pyplot as plt


file = 'capture.jpg'
true_image = image.load_img(file)
img = image.load_img(file, color_mode="grayscale", target_size=(48, 48))

x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)

x /= 255

custom = model.predict(x)
emotion_analysis(custom[0])

x = np.array(x, 'float32')
x = x.reshape([48, 48])


plt.imshow(true_image)
plt.show()
# Out:
# Writing: /content/drive/MyDrive/Colab/facialexpression/fear.jpg
