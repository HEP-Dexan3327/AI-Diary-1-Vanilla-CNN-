# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
root = "/content/drive/MyDrive/Colab/"
version = "202206111238"
name = "ResNet batch normalized 50-layers _ lr=0.003 6 x ResBlock4"
dataset = "emojify"

# %%
# Import data source
from zipfile import ZipFile
file_name = root+"facialexpression/emojify.zip"

with ZipFile(file_name, 'r') as zip:
  zip.extractall()
  print("Done")
# Out:
# Done

# %%
import numpy as np
import cv2
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, BatchNormalization, MaxPooling2D, Add
from tensorflow.keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# <h2>Importing Data</h2>

# %%
from tensorflow import keras
# Model / data parameters
num_classes = 6
input_shape = (48, 48, 1)

train_dir = 'train'
val_dir = 'test'
train_datagen = ImageDataGenerator(
        rotation_range=30,## data augmentation, able to increase the accuracy of the training.
        zoom_range=0.2,
        rescale=1./255,
        fill_mode='nearest') # Split 0.2 of the train data to validation data
val_datagen = ImageDataGenerator(rescale=1./255)

train_data = train_datagen.flow_from_directory(
        train_dir,
        target_size=(48,48),
        batch_size=64,
        color_mode="grayscale",
        class_mode='categorical')

val_data = val_datagen.flow_from_directory(
        val_dir,
        target_size=(48,48),
        batch_size=64,
        color_mode="grayscale",
        class_mode='categorical')
# Out:
# Found 25269 images belonging to 6 classes.
# Found 7067 images belonging to 6 classes.

# %% [markdown]
# <h2>Defining the Model</h2>

# %%
from keras import initializers
def conv(filter: int, kernel_size: int, zero: bool, stride: int) -> Conv2D:
  if zero:
    return Conv2D(filters=filter, kernel_size=kernel_size, activation="relu", padding="same", strides=stride, kernel_initializer=initializers.Zeros())
  else:
    return Conv2D(filters=filter, kernel_size=kernel_size, activation="relu", padding="same", strides=stride)
class Residual(keras.layers.Layer):
  def __init__(self, downsample: bool, filters: int, zero: bool, kernel_size: int = 3):
    super(Residual, self).__init__()
    self.conv1 = conv(filters, kernel_size, zero, (1 if not downsample else 2))
    self.bn1 = BatchNormalization()
    self.conv2 = conv(filters, kernel_size, zero, 1)
    self.bn2 = BatchNormalization()
    self.conv3 = conv(filters, kernel_size, zero, 1)
    self.bn3 = BatchNormalization()
    self.conv4 = conv(filters, kernel_size, zero, 1)
    self.convx = Conv2D(kernel_size=1, strides=2, filters=filters, padding="same")
    self.downsample = downsample
    self.add = Add()
    self.bnO = BatchNormalization()

  def call(self, inputs):
    x = inputs
    y = self.bn1(self.conv1(x))
    y = self.bn2(self.conv2(y))
    y = self.bn3(self.conv3(y))
    y = self.conv4(y)
    if self.downsample:
      x = self.convx(x)
    out = self.add([x,y])
    out = self.bnO(out)
    return out

  def get_config(self):
    return {
        "downsample": self.downsample,
        "conv1": self.conv1,
        "bn1": self.bn1,
        "conv2": self.conv2,
        "bn2": self.bn2,
        "conv3": self.conv3,
        "bn3": self.bn3,
        "conv4": self.conv4,
        "convx": self.convx,
        "add": self.add,
        "bnO": self.bnO
    }

# %%
B1 = BatchNormalization()
C = Conv2D(filters=32, kernel_size=3, activation="relu", padding="same")
B2 = BatchNormalization()
R11 = Residual(False, 32, False, 3)
R12 = Residual(False, 32, False, 3)
R21 = Residual(True, 64, False, 3)
R22 = Residual(False, 64, False, 3)
R31 = Residual(True, 128, False, 3)
R32 = Residual(False, 128, False, 3)
F = Flatten()
D = Dense(num_classes, activation="softmax")

model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        B1,
        C,
        B2,
        R11,
        R12,
        R21,
        R22,
        R31,
        R32,
        F,
        D,
    ]
)

# %% [markdown]
# <h3>F1 Score: a method for evaluating the accuracy of a model</h3>
# The block below should be runned before loading the model.

# %%
import keras.backend as K
def f1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %% [markdown]
# <h3>Training the Model</h3>
# The accuracy of my model is around 60% only. The accuracy can be slightly improved by training with 200 iterations. Use Google Colab with a GPU to speed up the training to around 10~12s per epoch.
# Note that the accuracy of the model for random guessing is 16.67% (1/6); While the accuracy for a binary classification model for random guessing is 50% (1/2), so the accuracies of binary classification model and this kind of model cannot be compared directly.

# %%
model.compile(loss='categorical_crossentropy',optimizer=Adam(learning_rate=0.003, decay=1e-6),
      metrics=['accuracy',tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),f1_score])
batch_size = 128
model_info = model.fit(
        train_data, validation_data=val_data, batch_size=batch_size, epochs=50)
# Out:
# Epoch 1/50
# 395/395 [==============================] - 50s 86ms/step - loss: 4.5437 - accuracy: 0.1913 - precision: 0.1917 - recall: 0.0585 - auc: 0.5304 - f1_score: 0.0751 - val_loss: 44.8524 - val_accuracy: 0.1559 - val_precision: 0.1529 - val_recall: 0.0375 - val_auc: 0.4763 - val_f1_score: 0.0600
# Epoch 2/50
# 395/395 [==============================] - 34s 86ms/step - loss: 2.0680 - accuracy: 0.2297 - precision: 0.2542 - recall: 0.0084 - auc: 0.5883 - f1_score: 0.0160 - val_loss: 1.7083 - val_accuracy: 0.2905 - val_precision: 0.3372 - val_recall: 0.0041 - val_auc: 0.6396 - val_f1_score: 0.0079
# Epoch 3/50
# 395/395 [==============================] - 34s 85ms/step - loss: 1.7047 - accuracy: 0.2720 - precision: 0.4921 - recall: 0.0074 - auc: 0.6388 - f1_score: 0.0144 - val_loss: 1.7096 - val_accuracy: 0.2629 - val_precision: 0.3333 - val_recall: 5.6601e-04 - val_auc: 0.6340 - val_f1_score: 0.0011
# Epoch 4/50
# 395/395 [==============================] - 34s 87ms/step - loss: 1.6827 - accuracy: 0.2883 - precision: 0.5768 - recall: 0.0159 - auc: 0.6541 - f1_score: 0.0304 - val_loss: 1.6772 - val_accuracy: 0.3146 - val_precision: 0.5600 - val_recall: 0.0139 - val_auc: 0.6657 - val_f1_score: 0.0267
# Epoch 5/50
# 395/395 [==============================] - 34s 85ms/step - loss: 1.6676 - accuracy: 0.2978 - precision: 0.5678 - recall: 0.0211 - auc: 0.6642 - f1_score: 0.0399 - val_loss: 1.9759 - val_accuracy: 0.3208 - val_precision: 0.5333 - val_recall: 0.0374 - val_auc: 0.6755 - val_f1_score: 0.0689
# Epoch 6/50
# 395/395 [==============================] - 34s 86ms/step - loss: 1.6486 - accuracy: 0.3152 - precision: 0.5971 - recall: 0.0308 - auc: 0.6762 - f1_score: 0.0575 - val_loss: 1.5793 - val_accuracy: 0.3661 - val_precision: 0.7047 - val_recall: 0.0446 - val_auc: 0.7143 - val_f1_score: 0.0829
# Epoch 7/50
# 395/395 [==============================] - 34s 86ms/step - loss: 1.6172 - accuracy: 0.3318 - precision: 0.6327 - recall: 0.0494 - auc: 0.6936 - f1_score: 0.0903 - val_loss: 1.5711 - val_accuracy: 0.3709 - val_precision: 0.7364 - val_recall: 0.0688 - val_auc: 0.7153 - val_f1_score: 0.1246
# Epoch 8/50
# 395/395 [==============================] - 34s 85ms/step - loss: 1.5928 - accuracy: 0.3446 - precision: 0.6383 - recall: 0.0633 - auc: 0.7072 - f1_score: 0.1139 - val_loss: 7.5467 - val_accuracy: 0.3920 - val_precision: 0.6492 - val_recall: 0.1191 - val_auc: 0.7357 - val_f1_score: 0.1992
# Epoch 9/50
# 395/395 [==============================] - 34s 86ms/step - loss: 1.5715 - accuracy: 0.3618 - precision: 0.6259 - recall: 0.0765 - auc: 0.7179 - f1_score: 0.1343 - val_loss: 1.5074 - val_accuracy: 0.3962 - val_precision: 0.6862 - val_recall: 0.1504 - val_auc: 0.7438 - val_f1_score: 0.2452
# Epoch 10/50
# 395/395 [==============================] - 34s 86ms/step - loss: 1.5489 - accuracy: 0.3715 - precision: 0.6434 - recall: 0.0917 - auc: 0.7288 - f1_score: 0.1588 - val_loss: 1.6212 - val_accuracy: 0.3407 - val_precision: 0.6368 - val_recall: 0.0754 - val_auc: 0.6979 - val_f1_score: 0.1331
# Epoch 11/50
# 395/395 [==============================] - 34s 85ms/step - loss: 1.5325 - accuracy: 0.3791 - precision: 0.6367 - recall: 0.1005 - auc: 0.7357 - f1_score: 0.1717 - val_loss: 1.4304 - val_accuracy: 0.4297 - val_precision: 0.6947 - val_recall: 0.1881 - val_auc: 0.7756 - val_f1_score: 0.2932
# Epoch 12/50
# 395/395 [==============================] - 34s 86ms/step - loss: 1.5004 - accuracy: 0.3923 - precision: 0.6451 - recall: 0.1214 - auc: 0.7499 - f1_score: 0.2023 - val_loss: 1.4611 - val_accuracy: 0.4354 - val_precision: 0.6383 - val_recall: 0.2110 - val_auc: 0.7718 - val_f1_score: 0.3156
# Epoch 13/50
# 395/395 [==============================] - 34s 86ms/step - loss: 1.4697 - accuracy: 0.4048 - precision: 0.6590 - recall: 0.1368 - auc: 0.7619 - f1_score: 0.2243 - val_loss: 1.5443 - val_accuracy: 0.3743 - val_precision: 0.6141 - val_recall: 0.1162 - val_auc: 0.7366 - val_f1_score: 0.1939
# Epoch 14/50
# 395/395 [==============================] - 34s 85ms/step - loss: 1.4461 - accuracy: 0.4184 - precision: 0.6654 - recall: 0.1541 - auc: 0.7716 - f1_score: 0.2482 - val_loss: 1.4644 - val_accuracy: 0.4173 - val_precision: 0.6828 - val_recall: 0.1398 - val_auc: 0.7670 - val_f1_score: 0.2298
# Epoch 15/50
# 395/395 [==============================] - 34s 86ms/step - loss: 1.4104 - accuracy: 0.4339 - precision: 0.6585 - recall: 0.1772 - auc: 0.7852 - f1_score: 0.2771 - val_loss: 1.4102 - val_accuracy: 0.4606 - val_precision: 0.6275 - val_recall: 0.2918 - val_auc: 0.7960 - val_f1_score: 0.3960
# Epoch 16/50
# 395/395 [==============================] - 34s 85ms/step - loss: 1.3828 - accuracy: 0.4477 - precision: 0.6685 - recall: 0.1953 - auc: 0.7948 - f1_score: 0.3001 - val_loss: 1.3897 - val_accuracy: 0.4565 - val_precision: 0.6473 - val_recall: 0.2597 - val_auc: 0.7994 - val_f1_score: 0.3692
# Epoch 17/50
# 395/395 [==============================] - 34s 85ms/step - loss: 1.3597 - accuracy: 0.4557 - precision: 0.6725 - recall: 0.2163 - auc: 0.8034 - f1_score: 0.3254 - val_loss: 1.3071 - val_accuracy: 0.4828 - val_precision: 0.6980 - val_recall: 0.2813 - val_auc: 0.8180 - val_f1_score: 0.3992
# Epoch 18/50
# 395/395 [==============================] - 34s 86ms/step - loss: 1.3190 - accuracy: 0.4771 - precision: 0.6808 - recall: 0.2425 - auc: 0.8164 - f1_score: 0.3557 - val_loss: 1.2664 - val_accuracy: 0.5087 - val_precision: 0.7086 - val_recall: 0.3310 - val_auc: 0.8318 - val_f1_score: 0.4501
# Epoch 19/50
# 395/395 [==============================] - 34s 85ms/step - loss: 1.2894 - accuracy: 0.4847 - precision: 0.6787 - recall: 0.2674 - auc: 0.8255 - f1_score: 0.3817 - val_loss: 1.2866 - val_accuracy: 0.4934 - val_precision: 0.6844 - val_recall: 0.3051 - val_auc: 0.8274 - val_f1_score: 0.4195
# Epoch 20/50
# 395/395 [==============================] - 34s 86ms/step - loss: 1.2674 - accuracy: 0.5036 - precision: 0.6813 - recall: 0.2854 - auc: 0.8325 - f1_score: 0.4000 - val_loss: 1.2417 - val_accuracy: 0.5190 - val_precision: 0.6605 - val_recall: 0.3604 - val_auc: 0.8442 - val_f1_score: 0.4652
# Epoch 21/50
# 395/395 [==============================] - 34s 87ms/step - loss: 1.2354 - accuracy: 0.5146 - precision: 0.6903 - recall: 0.3023 - auc: 0.8414 - f1_score: 0.4187 - val_loss: 1.2247 - val_accuracy: 0.5246 - val_precision: 0.7008 - val_recall: 0.3521 - val_auc: 0.8465 - val_f1_score: 0.4680
# Epoch 22/50
# 395/395 [==============================] - 34s 86ms/step - loss: 1.2045 - accuracy: 0.5257 - precision: 0.6945 - recall: 0.3312 - auc: 0.8500 - f1_score: 0.4467 - val_loss: 1.1399 - val_accuracy: 0.5605 - val_precision: 0.7187 - val_recall: 0.3927 - val_auc: 0.8680 - val_f1_score: 0.5065
# Epoch 23/50
# 395/395 [==============================] - 34s 85ms/step - loss: 1.1825 - accuracy: 0.5390 - precision: 0.6995 - recall: 0.3428 - auc: 0.8558 - f1_score: 0.4580 - val_loss: 1.1496 - val_accuracy: 0.5633 - val_precision: 0.6848 - val_recall: 0.4252 - val_auc: 0.8675 - val_f1_score: 0.5228
# Epoch 24/50
# 395/395 [==============================] - 34s 85ms/step - loss: 1.1597 - accuracy: 0.5490 - precision: 0.7026 - recall: 0.3605 - auc: 0.8618 - f1_score: 0.4749 - val_loss: 1.1540 - val_accuracy: 0.5635 - val_precision: 0.6809 - val_recall: 0.4269 - val_auc: 0.8677 - val_f1_score: 0.5224
# Epoch 25/50
# 395/395 [==============================] - 34s 86ms/step - loss: 1.1466 - accuracy: 0.5576 - precision: 0.7049 - recall: 0.3717 - auc: 0.8654 - f1_score: 0.4853 - val_loss: 1.1266 - val_accuracy: 0.5680 - val_precision: 0.6869 - val_recall: 0.4433 - val_auc: 0.8744 - val_f1_score: 0.5376
# Epoch 26/50
# 395/395 [==============================] - 34s 87ms/step - loss: 1.1190 - accuracy: 0.5664 - precision: 0.7119 - recall: 0.3908 - auc: 0.8721 - f1_score: 0.5032 - val_loss: 1.1030 - val_accuracy: 0.5773 - val_precision: 0.7022 - val_recall: 0.4438 - val_auc: 0.8778 - val_f1_score: 0.5431
# Epoch 27/50
# 395/395 [==============================] - 34s 86ms/step - loss: 1.1043 - accuracy: 0.5726 - precision: 0.7170 - recall: 0.4043 - auc: 0.8756 - f1_score: 0.5153 - val_loss: 1.2046 - val_accuracy: 0.5439 - val_precision: 0.6537 - val_recall: 0.4244 - val_auc: 0.8594 - val_f1_score: 0.5125
# Epoch 28/50
# 395/395 [==============================] - 34s 86ms/step - loss: 1.0904 - accuracy: 0.5785 - precision: 0.7146 - recall: 0.4124 - auc: 0.8789 - f1_score: 0.5215 - val_loss: 1.1089 - val_accuracy: 0.5792 - val_precision: 0.6882 - val_recall: 0.4663 - val_auc: 0.8785 - val_f1_score: 0.5544
# Epoch 29/50
# 395/395 [==============================] - 34s 85ms/step - loss: 1.0739 - accuracy: 0.5813 - precision: 0.7146 - recall: 0.4195 - auc: 0.8827 - f1_score: 0.5272 - val_loss: 1.2320 - val_accuracy: 0.5712 - val_precision: 0.7037 - val_recall: 0.4423 - val_auc: 0.8760 - val_f1_score: 0.5413
# Epoch 30/50
# 395/395 [==============================] - 34s 86ms/step - loss: 1.0651 - accuracy: 0.5864 - precision: 0.7176 - recall: 0.4330 - auc: 0.8851 - f1_score: 0.5385 - val_loss: 1.0575 - val_accuracy: 0.5946 - val_precision: 0.7236 - val_recall: 0.4627 - val_auc: 0.8871 - val_f1_score: 0.5638
# Epoch 31/50
# 395/395 [==============================] - 34s 86ms/step - loss: 1.0633 - accuracy: 0.5885 - precision: 0.7121 - recall: 0.4344 - auc: 0.8855 - f1_score: 0.5383 - val_loss: 1.0728 - val_accuracy: 0.5950 - val_precision: 0.7128 - val_recall: 0.4763 - val_auc: 0.8878 - val_f1_score: 0.5706
# Epoch 32/50
# 395/395 [==============================] - 34s 87ms/step - loss: 1.0368 - accuracy: 0.6011 - precision: 0.7227 - recall: 0.4494 - auc: 0.8911 - f1_score: 0.5529 - val_loss: 1.1219 - val_accuracy: 0.5674 - val_precision: 0.6949 - val_recall: 0.4429 - val_auc: 0.8747 - val_f1_score: 0.5397
# Epoch 33/50
# 395/395 [==============================] - 34s 86ms/step - loss: 1.0183 - accuracy: 0.6081 - precision: 0.7348 - recall: 0.4624 - auc: 0.8951 - f1_score: 0.5666 - val_loss: 1.0788 - val_accuracy: 0.5892 - val_precision: 0.7181 - val_recall: 0.4534 - val_auc: 0.8835 - val_f1_score: 0.5551
# Epoch 34/50
# 395/395 [==============================] - 34s 86ms/step - loss: 1.0155 - accuracy: 0.6075 - precision: 0.7261 - recall: 0.4638 - auc: 0.8958 - f1_score: 0.5649 - val_loss: 1.0553 - val_accuracy: 0.5997 - val_precision: 0.6956 - val_recall: 0.4996 - val_auc: 0.8912 - val_f1_score: 0.5803
# Epoch 35/50
# 395/395 [==============================] - 34s 86ms/step - loss: 1.0022 - accuracy: 0.6136 - precision: 0.7305 - recall: 0.4780 - auc: 0.8986 - f1_score: 0.5771 - val_loss: 1.0682 - val_accuracy: 0.6025 - val_precision: 0.6896 - val_recall: 0.5052 - val_auc: 0.8882 - val_f1_score: 0.5820
# Epoch 36/50
# 395/395 [==============================] - 34s 86ms/step - loss: 0.9904 - accuracy: 0.6143 - precision: 0.7299 - recall: 0.4764 - auc: 0.9007 - f1_score: 0.5752 - val_loss: 1.0468 - val_accuracy: 0.6004 - val_precision: 0.7078 - val_recall: 0.4868 - val_auc: 0.8918 - val_f1_score: 0.5764
# Epoch 37/50
# 395/395 [==============================] - 34s 87ms/step - loss: 0.9826 - accuracy: 0.6232 - precision: 0.7360 - recall: 0.4915 - auc: 0.9025 - f1_score: 0.5884 - val_loss: 1.0744 - val_accuracy: 0.6010 - val_precision: 0.7010 - val_recall: 0.4910 - val_auc: 0.8879 - val_f1_score: 0.5763
# Epoch 38/50
# 395/395 [==============================] - 34s 86ms/step - loss: 0.9694 - accuracy: 0.6289 - precision: 0.7368 - recall: 0.4943 - auc: 0.9051 - f1_score: 0.5906 - val_loss: 1.0875 - val_accuracy: 0.6052 - val_precision: 0.6929 - val_recall: 0.5169 - val_auc: 0.8893 - val_f1_score: 0.5921
# Epoch 39/50
# 395/395 [==============================] - 34s 86ms/step - loss: 0.9537 - accuracy: 0.6358 - precision: 0.7398 - recall: 0.5099 - auc: 0.9084 - f1_score: 0.6028 - val_loss: 1.0978 - val_accuracy: 0.5945 - val_precision: 0.6916 - val_recall: 0.4968 - val_auc: 0.8837 - val_f1_score: 0.5763
# Epoch 40/50
# 395/395 [==============================] - 34s 86ms/step - loss: 0.9471 - accuracy: 0.6371 - precision: 0.7437 - recall: 0.5124 - auc: 0.9095 - f1_score: 0.6057 - val_loss: 1.0590 - val_accuracy: 0.6034 - val_precision: 0.6871 - val_recall: 0.5083 - val_auc: 0.8905 - val_f1_score: 0.5826
# Epoch 41/50
# 395/395 [==============================] - 34s 86ms/step - loss: 0.9445 - accuracy: 0.6400 - precision: 0.7430 - recall: 0.5150 - auc: 0.9102 - f1_score: 0.6072 - val_loss: 1.0743 - val_accuracy: 0.6082 - val_precision: 0.6774 - val_recall: 0.5285 - val_auc: 0.8911 - val_f1_score: 0.5924
# Epoch 42/50
# 395/395 [==============================] - 34s 86ms/step - loss: 0.9293 - accuracy: 0.6443 - precision: 0.7440 - recall: 0.5252 - auc: 0.9129 - f1_score: 0.6149 - val_loss: 1.0752 - val_accuracy: 0.6076 - val_precision: 0.6863 - val_recall: 0.5329 - val_auc: 0.8921 - val_f1_score: 0.5998
# Epoch 43/50
# 395/395 [==============================] - 34s 87ms/step - loss: 0.9256 - accuracy: 0.6477 - precision: 0.7449 - recall: 0.5305 - auc: 0.9139 - f1_score: 0.6187 - val_loss: 1.0426 - val_accuracy: 0.6222 - val_precision: 0.7118 - val_recall: 0.5212 - val_auc: 0.8954 - val_f1_score: 0.6012
# Epoch 44/50
# 395/395 [==============================] - 34s 86ms/step - loss: 0.9146 - accuracy: 0.6510 - precision: 0.7478 - recall: 0.5349 - auc: 0.9158 - f1_score: 0.6229 - val_loss: 1.0529 - val_accuracy: 0.6237 - val_precision: 0.6898 - val_recall: 0.5533 - val_auc: 0.8989 - val_f1_score: 0.6132
# Epoch 45/50
# 395/395 [==============================] - 34s 86ms/step - loss: 0.9001 - accuracy: 0.6550 - precision: 0.7515 - recall: 0.5430 - auc: 0.9183 - f1_score: 0.6295 - val_loss: 1.0505 - val_accuracy: 0.6170 - val_precision: 0.6893 - val_recall: 0.5411 - val_auc: 0.8985 - val_f1_score: 0.6056
# Epoch 46/50
# 395/395 [==============================] - 34s 86ms/step - loss: 0.8903 - accuracy: 0.6590 - precision: 0.7520 - recall: 0.5478 - auc: 0.9200 - f1_score: 0.6332 - val_loss: 1.0588 - val_accuracy: 0.6168 - val_precision: 0.7028 - val_recall: 0.5294 - val_auc: 0.8953 - val_f1_score: 0.6031
# Epoch 47/50
# 395/395 [==============================] - 34s 86ms/step - loss: 0.8950 - accuracy: 0.6573 - precision: 0.7513 - recall: 0.5522 - auc: 0.9196 - f1_score: 0.6357 - val_loss: 1.0316 - val_accuracy: 0.6247 - val_precision: 0.7114 - val_recall: 0.5412 - val_auc: 0.9001 - val_f1_score: 0.6145
# Epoch 48/50
# 395/395 [==============================] - 34s 86ms/step - loss: 0.8738 - accuracy: 0.6660 - precision: 0.7553 - recall: 0.5580 - auc: 0.9231 - f1_score: 0.6411 - val_loss: 1.1054 - val_accuracy: 0.6148 - val_precision: 0.6694 - val_recall: 0.5595 - val_auc: 0.8950 - val_f1_score: 0.6095
# Epoch 49/50
# 395/395 [==============================] - 34s 86ms/step - loss: 0.8680 - accuracy: 0.6688 - precision: 0.7587 - recall: 0.5694 - auc: 0.9242 - f1_score: 0.6496 - val_loss: 1.0372 - val_accuracy: 0.6188 - val_precision: 0.6937 - val_recall: 0.5298 - val_auc: 0.8985 - val_f1_score: 0.6003
# Epoch 50/50
# 395/395 [==============================] - 34s 85ms/step - loss: 0.8570 - accuracy: 0.6743 - precision: 0.7599 - recall: 0.5734 - auc: 0.9261 - f1_score: 0.6526 - val_loss: 1.0005 - val_accuracy: 0.6361 - val_precision: 0.7200 - val_recall: 0.5437 - val_auc: 0.9038 - val_f1_score: 0.6192

# %% [markdown]
# <h2>Saving the Model</h2>

# %%
# !mkdir /content/git5
# %cd /content/git5
# create the git folder
# !git init
# !git config --global user.email "samkht3327@gmail.com"
# !git config --global user.name "Ash3327"
# !git remote remove origin
# !git remote add origin "https://HEP-Dexan3327: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@github.com/HEP-Dexan3327/AI-Diary-1-Vanilla-CNN-"
# !git pull origin main
# Out:
# /content/git5
# Initialized empty Git repository in /content/git5/.git/
# fatal: No such remote: origin
# remote: Enumerating objects: 319, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 319 (delta 3), reused 7 (delta 0), pack-reused 304
# Receiving objects: 100% (319/319), 98.19 MiB | 13.55 MiB/s, done.
# Resolving deltas: 100% (151/151), done.
# From https://github.com/HEP-Dexan3327/AI-Diary-1-Vanilla-CNN-
#  * branch            main       -> FETCH_HEAD
#  * [new branch]      main       -> origin/main

# %%
# %cd models
# navigate to git/models
# Out:
# /content/git5/models

# %%
#Saving the visualization of model
visualfile = version+"_shape.png"
# !pip install visualkeras
import visualkeras
from tensorflow.keras.layers import BatchNormalization, ZeroPadding2D, Activation, MaxPool2D

# Visualizing our model architecture
visualkeras.layered_view(model, 
                         legend=True, 
                         to_file=visualfile,
                         type_ignore=[MaxPool2D,Activation,ZeroPadding2D,BatchNormalization,Dropout,Flatten])  # font is optional!
                         
# !git add $visualfile
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting visualkeras
#   Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.7/dist-packages (from visualkeras) (1.21.6)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from visualkeras) (7.1.2)
# Collecting aggdraw>=1.3.11
#   Downloading aggdraw-1.3.14-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (992 kB)
#      |████████████████████████████████| 992 kB 34.6 MB/s
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.14 visualkeras-0.0.2

# %%
#Saving the model
modelfile = version+'_model.h5'
model.save(modelfile)

# !git add $modelfile

# %%
errorrate = "0.6361"

# %%
# %cd /content/git5/_trials
mdfile = version+".md"
# navigate to git/_trials
nameline = "name: " + name
datetime = "datetime: " + version
errorate = "errorrate: " + errorrate
imagelin = "img: " + visualfile
datasetn = "dataset: " + dataset
# !echo --- > $mdfile
# !echo $nameline >> $mdfile
# !echo $datetime >> $mdfile
# !echo $errorate >> $mdfile
# !echo $imagelin >> $mdfile
# !echo $datasetn >> $mdfile
# !echo --- >> $mdfile

# !git add $mdfile
# Out:
# /content/git5/_trials

# %%
# pushing back to git repo
# %cd /content/git5
# !git commit -m $version
# Out:
# /content/git5
# [master c6cd5d4] 202206111238
#  3 files changed, 7 insertions(+)
#  create mode 100644 _trials/202206111238.md
#  create mode 100644 models/202206111238_model.h5
#  create mode 100644 models/202206111238_shape.png

# %%
# !pwd
# Out:
# /content/git5

# %%
# !git push -u origin master
# Out:
# Counting objects: 6, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (6/6), 16.84 MiB | 4.50 MiB/s, done.
# Total 6 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/HEP-Dexan3327/AI-Diary-1-Vanilla-CNN-
#    7d9fe59..c6cd5d4  master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.

# %%
def plt_acc_loss(model,num_epochs):
    acc = model.history['accuracy'] # new change for TF changes
    val_acc = model.history['val_accuracy'] # new change for TF changes

    loss = model.history['loss']
    val_loss = model.history['val_loss']

    epochs_range = range(num_epochs)

    plt.figure(figsize=(8, 8))
    plt.subplot(1, 2, 1)
    plt.ylim(0.3,1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.show()

# %%
import matplotlib.pyplot as plt
plt_acc_loss(model_info,50)

# %% [markdown]
# <h2>Loading the Model</h2>
# Loading the model named "model.h5". If you don't have enough time to train, just use the file I gave.
# The accuracy of my model is around 60% only. The accuracy can be slightly improved by training with 200 iterations.

# %%
#from keras.models import load_model
#emotion_model = load_model('model.h5',custom_objects={'f1_score':f1_score})

# %% [markdown]
# <h2>Confusion Matrix</h2>

# %%
# %cd /content
import tensorflow as tf
import numpy as np
from keras.models import model_from_json
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report,ConfusionMatrixDisplay


emotion_dict = {0: "Angry", 1: "Fear", 2: "Happy", 3: "Neutral", 4: "Sad", 5: "Surprised"}

# do prediction on test data


predictions = np.array([])
labels =  np.array([])

I = 0
for x, y in val_data:
  predictions = np.concatenate([predictions, np.argmax(model.predict(x),axis=-1)])
  labels = np.concatenate([labels, np.argmax(y,axis=-1)])
  I += 1
  if I > 200:
    break
ConfusionMatrixDisplay(
    confusion_matrix=tf.math.confusion_matrix(
        labels=labels, predictions=predictions)
    .numpy(), display_labels=emotion_dict).plot(cmap=plt.cm.Blues)
plt.show()
print(tf.math.confusion_matrix(labels=labels, predictions=predictions).numpy())
# Out:
# /content
# [[ 986  180   54  202  295   23]
#  [ 274  728   51  211  407  187]
#  [ 128   55 2697  183   87   78]
#  [ 161  113  144 1380  375   62]
#  [ 242  237   85  450 1222   35]
#  [  74  164   66   26   35 1130]]

# %%
# Classification report
print("-----------------------------------------------------------------")
print(classification_report(labels, predictions))
# Out:
# -----------------------------------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.57      0.55      1740
#          1.0       0.49      0.39      0.44      1858
#          2.0       0.87      0.84      0.85      3228
#          3.0       0.56      0.62      0.59      2235
#          4.0       0.50      0.54      0.52      2271
#          5.0       0.75      0.76      0.75      1495
#
#     accuracy                           0.63     12827
#    macro avg       0.62      0.62      0.62     12827
# weighted avg       0.64      0.63      0.63     12827

# %% [markdown]
# <h1>Photo Emotion Analysis</h1>

# %%
def emotion_analysis(emotions):
    objects = ('Angry', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise')
    y_pos = np.arange(len(objects))
    
    plt.bar(y_pos, emotions, align='center', alpha=0.5)
    plt.xticks(y_pos, objects)
    plt.ylabel('percentage')
    plt.title('emotion')
    
    plt.show()

# %%
import cv2
            
def facecrop(image):  
    facedata = cv2.data.haarcascades + 'haarcascade_frontalface_alt.xml'
    cascade = cv2.CascadeClassifier(facedata)

    img = cv2.imread(image)

    try:
    
        minisize = (img.shape[1],img.shape[0])
        miniframe = cv2.resize(img, minisize)

        faces = cascade.detectMultiScale(miniframe)

        for f in faces:
            x, y, w, h = [ v for v in f ]
            cv2.rectangle(img, (x,y), (x+w,y+h), (0,255,0), 2)

            sub_face = img[y:y+h, x:x+w]

            
            cv2.imwrite('capture.jpg', sub_face)
            print ("Writing: " + image)

    except Exception as e:
        print (e)

   


if __name__ == '__main__':
    facecrop(root+"facialexpression/fear.jpg") ###############the file path here is your image

#Testing a file.

from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator

import numpy as np
import matplotlib.pyplot as plt


file = 'capture.jpg'
true_image = image.load_img(file)
img = image.load_img(file, color_mode="grayscale", target_size=(48, 48))

x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)

x /= 255

custom = model.predict(x)
emotion_analysis(custom[0])

x = np.array(x, 'float32')
x = x.reshape([48, 48])


plt.imshow(true_image)
plt.show()
# Out:
# Writing: /content/drive/MyDrive/Colab/facialexpression/fear.jpg
